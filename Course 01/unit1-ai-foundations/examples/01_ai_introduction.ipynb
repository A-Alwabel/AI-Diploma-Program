# %% [markdown]
# # 01 Ai Introduction
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Define AI and its main goals; distinguish AI, ML, and DL
# - Identify typical AI applications and ethical considerations
#
# ## 🔗 Prerequisites
#
# - ✅ Basic Python
# - ✅ Basic NumPy/Pandas (when applicable)
#
# ---
#
# ## Official Structure Reference
#
# This notebook supports **Course 01, Unit 1** requirements from `DETAILED_UNIT_DESCRIPTIONS.md`.
#
# ---

# %% [markdown]
# # 01 Ai Introduction
#
# ## 📚 Learning Objectives | أهداف التعلم
#
# This notebook demonstrates key concepts through hands-on examples.
#
# By completing this notebook, you will:
# - Understand the core concepts
# - See practical implementations
# - Be ready for exercises
#
# ## 🔗 Prerequisites | المتطلبات الأساسية
#
# - ✅ Python 3.8+ installed
# - ✅ Required libraries (see `requirements.txt`)
# - ✅ Basic Python knowledge
#
# ---
#
# ## Code Example | مثال الكود
#
# Run the code below to see the demonstration:

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Visualization: Progress Chart
# تصور: مخطط التقدم
try:
    import matplotlib.pyplot as plt
    
    # Example progress visualization
    steps = ['Step 1', 'Step 2', 'Step 3', 'Step 4']
    progress = [25, 50, 75, 100]
    
    plt.figure(figsize=(10, 6))
    plt.barh(steps, progress, color='green', alpha=0.7)
    plt.xlabel('Progress % | النسبة المئوية للتقدم', fontsize=12)
    plt.title('Learning Progress | تقدم التعلم', fontsize=14, pad=20)
    plt.xlim(0, 100)
    for i, v in enumerate(progress):
        plt.text(v + 2, i, f'{v}%', va='center', fontsize=11)
    plt.tight_layout()
    plt.show()
    print("✅ Progress visualization displayed")
except ImportError:
    print("Note: Install matplotlib for visualizations")
    print("ملاحظة: قم بتثبيت matplotlib للتصورات")

"""
Unit 1 - Example 1: Introduction to Artificial Intelligence
الوحدة 1 - مثال 1: مقدمة في الذكاء الاصطناعي

This example demonstrates:
1. Basic AI concepts and definitions
2. Types of AI systems
3. Real-world AI applications
4. Simple AI decision-making example
"""

print("=" * 60)
print("Example 1: Introduction to Artificial Intelligence")
print("مثال 1: مقدمة في الذكاء الاصطناعي")
print("=" * 60)

# 1. What is AI?
# ما هو الذكاء الاصطناعي؟
print("\n1. What is Artificial Intelligence?")
print("ما هو الذكاء الاصطناعي؟")
print("-" * 60)

ai_definition = """
Artificial Intelligence (AI) is the simulation of human intelligence 
in machines that are programmed to think and learn like humans.

الذكاء الاصطناعي هو محاكاة الذكاء البشري في الآلات المبرمجة 
للتفكير والتعلم مثل البشر.
"""

print(ai_definition)

# 2. Types of AI Systems
# أنواع أنظمة الذكاء الاصطناعي
print("\n2. Types of AI Systems")
print("أنواع أنظمة الذكاء الاصطناعي")
print("-" * 60)

ai_types = {
    "Narrow AI (Weak AI)": {
        "description": "AI designed for specific tasks", "examples": ["Siri", "Google Translate", "Image Recognition"],
        "arabic": "ذكاء اصطناعي ضيق (ضعيف) - مصمم لمهام محددة"
    },
    "General AI (Strong AI)": {
        "description": "AI with human-level intelligence across all domains",
        "examples": ["Not yet achieved", "Theoretical"],
        "arabic": "ذكاء اصطناعي عام (قوي) - ذكاء على مستوى البشر"
    },
    "Superintelligent AI": {
        "description": "AI that surpasses human intelligence",
        "examples": ["Future concept", "Theoretical"],
        "arabic": "ذكاء اصطناعي فائق - يتجاوز الذكاء البشري"
    }
}

for ai_type, info in ai_types.items():
    print(f"\n{ai_type}:")
    print(f"  {info['arabic']}")
    print(f"  Description: {info['description']}")
    print(f"  Examples: {', '.join(info['examples'])}")

# 3. Simple AI Decision-Making Example
# مثال بسيط على اتخاذ القرار بالذكاء الاصطناعي
print("\n" + "=" * 60)
print("3. Simple AI Decision-Making Example")
print("مثال بسيط على اتخاذ القرار بالذكاء الاصطناعي")
print("=" * 60)

def simple_ai_decision(temperature, humidity, time_of_day):
    """
    Simple rule-based AI system for weather-based activity recommendation.
    نظام ذكاء اصطناعي بسيط قائم على القواعد لتوصية نشاط بناءً على الطقس.
    
    Args:
        temperature: Temperature in Celsius
        humidity: Humidity percentage (0-100)
        time_of_day: 'morning', 'afternoon', or 'evening'
    
    Returns:
        Recommended activity
    """
    # Decision rules | قواعد القرار
    if temperature > 25 and humidity < 60:
        if time_of_day == 'morning':
            return "Go for a jog in the park | اذهب للجري في الحديقة"
        elif time_of_day == 'afternoon':
            return "Go swimming | اذهب للسباحة"
        else:
            return "Take an evening walk | اذهب لنزهة مسائية"
    
    elif temperature < 15:
        return "Stay indoors, read a book | ابق في الداخل واقرأ كتاباً"
    
    elif humidity > 80:
        return "Stay indoors, watch a movie | ابق في الداخل وشاهد فيلماً"
    
    else:
        return "Moderate weather, any outdoor activity is fine | طقس معتدل، أي نشاط خارجي مناسب"

# Test the AI system
# اختبار نظام الذكاء الاصطناعي
print("\nTesting AI Decision System:")
print("اختبار نظام اتخاذ القرار:")

test_cases = [
    (28, 50, 'morning'),
    (30, 45, 'afternoon'),
    (12, 70, 'evening'),
    (20, 85, 'afternoon')
]

for temp, hum, time in test_cases:
    decision = simple_ai_decision(temp, hum, time)
    print(f"\nTemperature: {temp}°C, Humidity: {hum}%, Time: {time}")
    print(f"Recommendation: {decision}")

# 4. AI Applications in Real World
# تطبيقات الذكاء الاصطناعي في العالم الحقيقي
print("\n" + "=" * 60)
print("4. AI Applications in Real World")
print("تطبيقات الذكاء الاصطناعي في العالم الحقيقي")
print("=" * 60)

applications = {
    "Healthcare": [
        "Medical image analysis", "Drug discovery",
        "Personalized treatment plans"
    ],
    "Transportation": [
        "Autonomous vehicles",
        "Traffic optimization",
        "Route planning"
    ],
    "Finance": [
        "Fraud detection",
        "Algorithmic trading",
        "Credit scoring"
    ],
    "Education": [
        "Personalized learning",
        "Automated grading",
        "Intelligent tutoring systems"
    ]
}

for domain, apps in applications.items():
    print(f"\n{domain}:")
    for app in apps:
        print(f"  - {app}")

print("\n" + "=" * 60)
print("Example completed successfully!")
print("تم إكمال المثال بنجاح!")
print("=" * 60)
# Out:
# ✅ Progress visualization displayed
# ============================================================
# Example 1: Introduction to Artificial Intelligence
# مثال 1: مقدمة في الذكاء الاصطناعي
# ============================================================
#
# 1. What is Artificial Intelligence?
# ما هو الذكاء الاصطناعي؟
# ------------------------------------------------------------
#
# Artificial Intelligence (AI) is the simulation of human intelligence
# in machines that are programmed to think and learn like humans.
#
# الذكاء الاصطناعي هو محاكاة الذكاء البشري في الآلات المبرمجة
# للتفكير والتعلم مثل البشر.
#
#
# 2. Types of AI Systems
# أنواع أنظمة الذكاء الاصطناعي
# ------------------------------------------------------------
#
# Narrow AI (Weak AI):
#   ذكاء اصطناعي ضيق (ضعيف) - مصمم لمهام محددة
#   Description: AI designed for specific tasks
#   Examples: Siri, Google Translate, Image Recognition
#
# General AI (Strong AI):
#   ذكاء اصطناعي عام (قوي) - ذكاء على مستوى البشر
#   Description: AI with human-level intelligence across all domains
#   Examples: Not yet achieved, Theoretical
#
# Superintelligent AI:
#   ذكاء اصطناعي فائق - يتجاوز الذكاء البشري
#   Description: AI that surpasses human intelligence
#   Examples: Future concept, Theoretical
#
# ============================================================
# 3. Simple AI Decision-Making Example
# مثال بسيط على اتخاذ القرار بالذكاء الاصطناعي
# ============================================================
#
# Testing AI Decision System:
# اختبار نظام اتخاذ القرار:
#
# Temperature: 28°C, Humidity: 50%, Time: morning
# Recommendation: Go for a jog in the park | اذهب للجري في الحديقة
#
# Temperature: 30°C, Humidity: 45%, Time: afternoon
# Recommendation: Go swimming | اذهب للسباحة
#
# Temperature: 12°C, Humidity: 70%, Time: evening
# Recommendation: Stay indoors, read a book | ابق في الداخل واقرأ كتاباً
#
# Temperature: 20°C, Humidity: 85%, Time: afternoon
# Recommendation: Stay indoors, watch a movie | ابق في الداخل وشاهد فيلماً
#
# ============================================================
# 4. AI Applications in Real World
# تطبيقات الذكاء الاصطناعي في العالم الحقيقي
# ============================================================
#
# Healthcare:
#   - Medical image analysis
#   - Drug discovery
#   - Personalized treatment plans
#
# Transportation:
#   - Autonomous vehicles
#   - Traffic optimization
#   - Route planning
#
# Finance:
#   - Fraud detection
#   - Algorithmic trading
#   - Credit scoring
#
# Education:
#   - Personalized learning
#   - Automated grading
#   - Intelligent tutoring systems
#
# ============================================================
# Example completed successfully!
# تم إكمال المثال بنجاح!
# ============================================================

# %% [markdown]
# ---
#
# ## ✅ Summary | الملخص
#
# Great job completing this example!
#
# ### What You Learned:
#
# **Key Concepts:**
# - **Artificial Intelligence Definition**: AI is the simulation of human intelligence in machines - systems that can think, learn, and make decisions like humans
#
# - **Types of AI Systems**:
#   - **Narrow AI (Weak AI)**: Task-specific AI like Siri, Google Translate, image recognition
#   - **General AI (Strong AI)**: Human-level intelligence across all domains (still theoretical)
#   - **Superintelligent AI**: AI that surpasses human intelligence (future concept)
#
# - **Real-World Applications**: AI is used in healthcare (medical image analysis, drug discovery), transportation (autonomous vehicles), finance (fraud detection), education (personalized learning), and many more domains
#
# - **AI Decision-Making**: Simple AI systems use rules and logic to make decisions based on input conditions, demonstrating how machines can process information and respond intelligently
#
# ### 🔗 How This Connects:
#
# **This example is the foundation for:**
# - **Unit 2: Search Algorithms** - AI systems need algorithms to solve problems (search is fundamental to AI problem-solving)
# - **Unit 3: Knowledge Representation** - AI systems need to store and organize information to make decisions
# - **Unit 4: Neural Networks** - Modern AI uses neural networks for learning (advanced AI that builds on these basics)
#
# **Why this example first?**
# 1. **Foundation**: Understanding what AI is helps you understand everything that follows
# 2. **Context**: Knowing AI applications motivates learning the technical concepts
# 3. **Big Picture**: Seeing the end goal (intelligent systems) helps you understand why each concept matters
#
# ### Next Steps:
# - Complete the exercises in `exercises/` folder to practice AI concepts hands-on
# - Review the quiz materials in `quizzes/` folder to test your understanding
# - Proceed to the next example: **02_ai_history.ipynb** to learn about AI development over time
#
# ---
#
# **💡 Tips for Success:**
# - **Install libraries**: Make sure all libraries are installed: `pip install -r requirements.txt`
# - **Python version**: Use Python 3.8+ for compatibility with all libraries
# - **Execute in order**: Run cells sequentially - later cells depend on earlier ones
# - **Experiment**: Try modifying the code (e.g., change temperature values) to see how changes affect AI decisions
