# %% [markdown]
# # Working with Pre-trained Word Embeddings (GloVe, FastText)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Load pre-trained GloVe embeddings
# - Load pre-trained FastText embeddings
# - Use embeddings for similarity
# - Apply embeddings to NLP tasks
# - Compare embedding methods
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of word embeddings
# - ✅ Understanding of Word2Vec
# - ✅ Gensim knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 07, Unit 2**:
# - Working with pre-trained word embeddings (GloVe, FastText)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **Pre-trained word embeddings** like GloVe and FastText provide rich semantic representations learned from large corpora, useful for various NLP tasks.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install gensim -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
try:
    from gensim.models import KeyedVectors
    GENSIM_AVAILABLE = True
except ImportError:
    KeyedVectors = None
    GENSIM_AVAILABLE = False
    print("Gensim not available. Install with: pip install gensim")
