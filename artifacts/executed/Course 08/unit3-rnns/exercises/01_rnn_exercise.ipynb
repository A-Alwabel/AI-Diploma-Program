# %% [markdown]
# # Exercise: Building RNNs for Sequence Prediction
# ## AIAT 122 - Deep Learning
#
# ## Learning Objectives
#
# - Implement RNN from scratch
# - Apply RNN to time series prediction
# - Compare vanilla RNN vs LSTM
# - Understand vanishing gradient problem
#
# ## Real-World Context
#
# You're building a stock price prediction system for a fintech company.

# %%
if 'TRANSFORMERS_AVAILABLE' in globals() and TRANSFORMERS_AVAILABLE:
    if 'TORCH_AVAILABLE' in globals() and TORCH_AVAILABLE:
        # if 'TRANSFORMERS_AVAILABLE' in globals() and TRANSFORMERS_AVAILABLE:
        #     if 'TORCH_AVAILABLE' in globals() and TORCH_AVAILABLE:
                # NOTE: Auto-suppressed invalid cell

                # import torch.nn as nn
                # import numpy as np
                # import pandas as pd
                # import matplotlib.pyplot as plt
                # print('✅ Setup complete!')
        pass

# %% [markdown]
# ## Task 1: Generate Synthetic Time Series (15 points)
#
# Create a synthetic stock price dataset with trend and seasonality.

# %%
# NOTE: Auto-suppressed invalid cell
# # TODO: Generate synthetic time series data
# # :
 


# # = generate_stock_data()
# # plt.plot(data[:100])
# # plt.title('Stock Price Data')
# plt.show()
print("Cell skipped due to execution error.")
# Out:
# Cell skipped due to execution error.

# %% [markdown]
# ## Task 2: Implement Simple RNN (25 points)
#
# Build a simple RNN model using PyTorch.

# %%
if 'TORCH_AVAILABLE' in globals() and TORCH_AVAILABLE:
    # if 'TORCH_AVAILABLE' in globals() and TORCH_AVAILABLE:
        # TODO: Implement SimpleRNN classclass SimpleRNN(nn.Module):
        #  def __init__(self, input_size, hidden_size, output_size):
        #  super().__init__()


 
        #  def forward(self, x):
 


        # Test

        # model = SimpleRNN(input_size=1, hidden_size=32, output_size=1)




        print(model)

# %% [markdown]
# ## Task 3: Train RNN (30 points)
#
# Train the RNN on stock data and evaluate performance.

# %%
# NOTE: Auto-suppressed invalid cell
# # :
 


# # = train_rnn(model, data)
# plt.plot(losses)
# # plt.title('Training Loss')
# plt.show()
print("Cell skipped due to execution error.")
# Out:
# Cell skipped due to execution error.

# %% [markdown]
# ## Task 4: Compare with LSTM (30 points)
#
# Implement LSTM and compare with vanilla RNN.

# %%
if 'TORCH_AVAILABLE' in globals() and TORCH_AVAILABLE:
    if 'TF_AVAILABLE' in globals() and TF_AVAILABLE:
        # if 'TORCH_AVAILABLE' in globals() and TORCH_AVAILABLE:
        #     if 'TF_AVAILABLE' in globals() and TF_AVAILABLE:
                # TODO: Implement LSTM modelclass LSTMModel(nn.Module):
                #  def __init__(self, input_size, hidden_size, output_size):
                #  super().__init__()


 
                #  def forward(self, x):
 


                # Train and comparelstm_

                # model = LSTMModel(1, 32, 1)
                # lstm_losses = train_rnn(lstm_model, data)


                # plt.plot(lstm_losses, label='LSTM')
                plt.legend()
                # plt.title('RNN vs LSTM')
                plt.show()

# %% [markdown]
# ## Submission
#
# **Total: 100 points**
#
# Submit completed notebook with:
# 1. All implementations
# 2. Training plots
# 3. Comparison analysis (2-3 sentences)
#
# **Real-World Application**: Stock prediction, weather forecasting, sales forecasting
