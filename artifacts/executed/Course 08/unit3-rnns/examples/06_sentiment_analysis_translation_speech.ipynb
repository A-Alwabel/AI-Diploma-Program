# %% [markdown]
# # Performing Sentiment Analysis, Machine Translation, and Speech Recognition
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Perform sentiment analysis
# - Implement machine translation
# - Work with speech recognition
# - Apply RNN/Transformer models
# - Evaluate task performance
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of NLP tasks
# - ✅ Understanding of sequence models
# - ✅ Hugging Face Transformers knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 08, Unit 3**:
# - Performing sentiment analysis, machine translation, and speech recognition
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **Sentiment analysis, machine translation, and speech recognition** are key NLP applications that benefit from RNN and Transformer architectures.

# %%
if 'TF_AVAILABLE' in globals() and TF_AVAILABLE:
    TRANSFORMERS_AVAILABLE = True
    try:
                    from transformers import pipeline
    except Exception as e:
        TRANSFORMERS_AVAILABLE = False
        print('WARN: transformers unavailable:', e)
    if TRANSFORMERS_AVAILABLE:
        TORCH_AVAILABLE = True
        try:
                                import torch
        except Exception as e:
            TORCH_AVAILABLE = False
            print('WARN: torch unavailable:', e)
        # if 'TF_AVAILABLE' in globals() and TF_AVAILABLE:
        #     TRANSFORMERS_AVAILABLE = True
        #     try:
        #     except Exception as e:
        #         TRANSFORMERS_AVAILABLE = False
        #         print('WARN: transformers unavailable:', e)
        #     if TRANSFORMERS_AVAILABLE:
        #         TORCH_AVAILABLE = True
        #         try:
        #         except Exception as e:
        #             TORCH_AVAILABLE = False
        #             print('WARN: torch unavailable:', e)
                # TRANSFORMERS_AVAILABLE = True
                # try:
                # except Exception as e:
                #     TRANSFORMERS_AVAILABLE = False
                #     print('WARN: transformers unavailable:', e)
                # if TRANSFORMERS_AVAILABLE:
                #     TORCH_AVAILABLE = True
                #     try:
                #     except Exception as e:
                #         TORCH_AVAILABLE = False
                #         print('WARN: torch unavailable:', e)
            
                #     print("✅ Libraries imported!")
                #     print("\nSentiment Analysis, Translation, and Speech Recognition")
                #     print("=" * 60)
            
                #     print("\nSentiment Analysis:")
                #     print("  - Classify text sentiment")
                #     print("  - Positive/negative/neutral")
                #     print("  - Use BERT or LSTM")
            
                #     print("\nMachine Translation:")
                #     print("  - Translate between languages")
                #     print("  - Seq2seq models")
                #     print("  - Attention mechanisms")
            
                #     print("\nSpeech Recognition:")
                #     print("  - Convert speech to text")
                #     print("  - Audio processing")
                #     print("  - CTC or attention models")
            
                #     print("\nModels:")
                #     print("  - Pre-trained transformers")
                #     print("  - Fine-tuned models")
                #     print("  - Task-specific architectures")
            
                #     print("\n✅ NLP applications concepts understood!")
