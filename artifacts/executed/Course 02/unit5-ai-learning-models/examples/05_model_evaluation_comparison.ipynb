# %% [markdown]
# # Performing Model Evaluation and Comparison using Cross-Validation
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Perform cross-validation
# - Evaluate model performance
# - Compare different models
# - Use evaluation metrics
# - Apply to model selection
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of model evaluation
# - ✅ Understanding of cross-validation
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 02, Unit 5**:
# - Performing model evaluation and comparison using cross-validation
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 5 Practical Content
#
# ---
#
# ## Introduction
#
# **Model evaluation and comparison** using cross-validation provides robust estimates of model performance and enables fair comparison between models.

# %%
import numpy as np

print("✅ Libraries imported!")
print("\nModel Evaluation and Comparison using Cross-Validation")
print("=" * 60)

print("\nCross-Validation:")
print("  - k-fold CV: Split into k folds")
print("  - Stratified CV: Preserve class distribution")
print("  - Leave-one-out: Each sample as test")

print("\nEvaluation Metrics:")
print("  - Classification: Accuracy, Precision, Recall, F1")
print("  - Regression: MSE, RMSE, MAE, R²")
print("  - Compare across folds")

print("\nModel Comparison:")
print("  - Compare CV scores")
print("  - Statistical significance")
print("  - Select best model")

print("\n✅ Model evaluation concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Model Evaluation and Comparison using Cross-Validation
# ...
#
# Cross-Validation:
#   - k-fold CV: Split into k folds
#   - Stratified CV: Preserve class distribution
#   - Leave-one-out: Each sample as test
#
# Evaluation Metrics:
#   - Classification: Accuracy, Precision, Recall, F1
#   - Regression: MSE, RMSE, MAE, R²
#   - Compare across folds
#
# Model Comparison:
#   - Compare CV scores
#   - Statistical significance
#   - Select best model
#
# ✅ Model evaluation concepts understood!
