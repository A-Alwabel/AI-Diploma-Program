# %% [markdown]
# # Implementing Logical Operators (AND, OR, NOT, IMPLIES, BICONDITIONAL)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement logical operators in Python
# - Understand truth tables for operators
# - Apply logical operators to problems
# - Build logical expressions
# - Validate logical statements
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of Boolean logic
# - ✅ Python knowledge
# - ✅ Understanding of truth tables
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 02, Unit 2**:
# - Implementing logical operators (AND, OR, NOT, IMPLIES, BICONDITIONAL)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **Logical operators** are fundamental to knowledge representation in AI, enabling reasoning about truth values and logical relationships.

# %%
print("✅ Libraries imported!")
print("\nImplementing Logical Operators")
print("=" * 60)

print("\nLogical Operators:")
print("  - AND (∧): Both must be True")
print("  - OR (∨): At least one True")
print("  - NOT (¬): Negation")
print("  - IMPLIES (→): If-then")
print("  - BICONDITIONAL (↔): If and only if")

print("\nPython Implementation:")
print("  - AND: and, &")
print("  - OR: or, |")
print("  - NOT: not, ~")
print("  - IMPLIES: not p or q")
print("  - BICONDITIONAL: p == q")

print("\n✅ Logical operators concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Implementing Logical Operators
# ...
#
# Logical Operators:
#   - AND (∧): Both must be True
#   - OR (∨): At least one True
#   - NOT (¬): Negation
#   - IMPLIES (→): If-then
#   - BICONDITIONAL (↔): If and only if
#
# Python Implementation:
#   - AND: and, &
#   - OR: or, |
#   - NOT: not, ~
#   - IMPLIES: not p or q
#   - BICONDITIONAL: p == q
#
# ✅ Logical operators concepts understood!
