# %% [markdown]
# # Implementing a Single Neuron with Different Activation Functions
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement a single neuron from scratch
# - Understand activation functions
# - Compare different activation functions
# - Visualize activation function outputs
# - Apply to classification problems
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of neurons and perceptrons
# - ✅ Python, NumPy knowledge
# - ✅ Understanding of functions
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 4**:
# - Implementing a single neuron with different activation functions using Python
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 4 Practical Content
#
# ---
#
# ## Introduction
#
# A **single neuron** is the building block of neural networks. Different **activation functions** enable neurons to model different types of relationships.

# %%
import numpy as np
import matplotlib.pyplot as plt

print("✅ Libraries imported!")
print("\nImplementing a Single Neuron with Activation Functions")
print("=" * 60)

print("\nActivation Functions:")
print("  - Sigmoid: S-shaped, outputs 0-1")
print("  - Tanh: S-shaped, outputs -1 to 1")
print("  - ReLU: Rectified Linear Unit, outputs >= 0")
print("  - Linear: No transformation")

print("\nPurpose:")
print("  - Introduce non-linearity")
print("  - Enable complex mappings")
print("  - Control output range")

print("\n✅ Activation functions concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Implementing a Single Neuron with Activation Functions
# ...
#
# Activation Functions:
#   - Sigmoid: S-shaped, outputs 0-1
#   - Tanh: S-shaped, outputs -1 to 1
#   - ReLU: Rectified Linear Unit, outputs >= 0
#   - Linear: No transformation
#
# Purpose:
#   - Introduce non-linearity
#   - Enable complex mappings
#   - Control output range
#
# ✅ Activation functions concepts understood!
