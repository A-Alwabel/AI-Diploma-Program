# %% [markdown]
# # Implementing Search Algorithms (Uninformed, Heuristic, Greedy)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement uninformed search algorithms
# - Implement heuristic search algorithms
# - Implement greedy search
# - Compare search strategies
# - Apply to problem-solving
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of search algorithms
# - ✅ Understanding of graph traversal
# - ✅ Python programming knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 01, Unit 1**:
# - Implementing search algorithms (uninformed, heuristic, greedy)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## Introduction
#
# **Search algorithms** are fundamental to AI problem-solving, including uninformed (BFS, DFS), heuristic (A*), and greedy search strategies.

# %%
from collections import deque
import heapq

print("✅ Libraries imported!")
print("\nImplementing Search Algorithms")
print("=" * 60)

print("\nUninformed Search:")
print("  - BFS (Breadth-First Search)")
print("  - DFS (Depth-First Search)")
print("  - No heuristic information")
print("  - Systematic exploration")

print("\nHeuristic Search:")
print("  - A* algorithm")
print("  - Uses heuristic function")
print("  - Optimal path finding")
print("  - Informed search")

print("\nGreedy Search:")
print("  - Greedy best-first")
print("  - Uses heuristic only")
print("  - Fast but not optimal")
print("  - Local optimization")

print("\n✅ Search algorithms concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Implementing Search Algorithms
# ...
#
# Uninformed Search:
#   - BFS (Breadth-First Search)
#   - DFS (Depth-First Search)
#   - No heuristic information
#   - Systematic exploration
#
# Heuristic Search:
#   - A* algorithm
#   - Uses heuristic function
#   - Optimal path finding
#   - Informed search
#
# Greedy Search:
#   - Greedy best-first
#   - Uses heuristic only
#   - Fast but not optimal
#   - Local optimization
#
# ✅ Search algorithms concepts understood!
