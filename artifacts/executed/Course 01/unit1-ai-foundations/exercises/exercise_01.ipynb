# %% [markdown]
# # Exercise 1: AI Fundamentals and Python Basics for AI
# # تمرين 1: أساسيات الذكاء الاصطناعي وأساسيات بايثون للذكاء الاصطناعي
#
# **Unit:** Unit 1: Introduction to AI and Applications
# **Practical Content Alignment:** See `../../../DETAILED_UNIT_DESCRIPTIONS.md` for complete requirements
#
# ## 📝 Instructions | التعليمات
#
# Complete the following exercises to practice what you've learned in Unit 1.
#
# **Required Practical Activities (from official structure):**
# - Applied workshops on Python basics for AI
# - Working with NumPy for data processing in AI applications
# - Exercises on knowledge representation and rule-based systems
#
# **Steps:**
# 1. Read each problem statement below
# 2. Write your solution in the code cells
# 3. Run the code to test your solution
# 4. Check your output matches the expected results
# 5. Compare with solutions in `../solutions/` folder
#
# ---

# %%
"""
Unit 1 - Exercise 1: AI Fundamentals and Python Basics
الوحدة 1 - تمرين 1: أساسيات الذكاء الاصطناعي وأساسيات بايثون

Complete the following exercises to practice AI fundamentals and Python for AI.
أكمل التمارين التالية لممارسة أساسيات الذكاء الاصطناعي وبايثون للذكاء الاصطناعي.

Required Practical Activities (from official structure):
- Applied workshops on Python basics for AI
- Working with NumPy for data processing in AI applications
- Exercises on knowledge representation and rule-based systems
"""

import numpy as np

# Exercise 1: Define AI
# التمرين 1: تعريف الذكاء الاصطناعي
print("Exercise 1: Define AI")
print("التمرين 1: تعريف الذكاء الاصطناعي")
print("-" * 60)

# TODO: Write your own definition of AI in 2-3 sentences
# TODO: اكتب تعريفك الخاص للذكاء الاصطناعي في 2-3 جمل
ai_definition = """
Your definition here / تعريفك هنا:
"""

print(ai_definition)

# Exercise 2: Identify AI Types
# التمرين 2: تحديد أنواع الذكاء الاصطناعي
print("\nExercise 2: Identify AI Types")
print("التمرين 2: تحديد أنواع الذكاء الاصطناعي")
print("-" * 60)

# TODO: Classify each system as Narrow AI, General AI, or Superintelligent AI
# TODO: صنف كل نظام كذكاء اصطناعي ضيق، عام، أو فائق
systems = [
    "Siri voice assistant",
    "Self-driving car",
    "Chess-playing computer",
    "Human-like robot that can do any task",
    "AI that is smarter than all humans combined"
]

# TODO: Create a dictionary mapping each system to its AI type
# TODO: أنشئ قاموس يربط كل نظام بنوع الذكاء الاصطناعي
system_types = {}

for system in systems:
    # TODO: Classify the system
    # system_types[system] = "Your classification here"
    pass

# Exercise 3: AI Application Research
# التمرين 3: بحث عن تطبيقات الذكاء الاصطناعي
print("\nExercise 3: AI Application Research")
print("التمرين 3: بحث عن تطبيقات الذكاء الاصطناعي")
print("-" * 60)

# TODO: Research and list 3 AI applications in a field of your choice
# TODO: ابحث واذكر 3 تطبيقات للذكاء الاصطناعي في مجال من اختيارك
chosen_field = "Your field here / المجال الذي اخترته:"
applications = [
    "Application 1 / التطبيق 1:", "Application 2 / التطبيق 2:",
    "Application 3 / التطبيق 3:"
]

print(f"\nField: {chosen_field}")
for app in applications:
    print(f"  - {app}")

# Exercise 4: Simple Rule-Based System
# التمرين 4: نظام بسيط قائم على القواعد
print("\nExercise 4: Simple Rule-Based System")
print("التمرين 4: نظام بسيط قائم على القواعد")
print("-" * 60)

def recommend_movie(age, genre_preference, mood):
    """
    TODO: Create a rule-based system that recommends a movie
    based on age, genre preference, and mood.
    
    TODO: أنشئ نظاماً قائماً على القواعد يوصي بفيلم
    بناءً على العمر، تفضيل النوع، والمزاج.
    
    Args:
        age: Person's age
        genre_preference: 'action', 'comedy', 'drama', 'horror'
        mood: 'happy', 'sad', 'excited', 'relaxed'
    
    Returns:
        Movie recommendation
    """
    # TODO: Implement your recommendation logic
    # TODO: نفذ منطق التوصية الخاص بك
    pass

# Test your function
# اختبر دالتك
print("\nTesting movie recommendation system:")
test_cases = [
    (25, 'action', 'excited'),
    (15, 'comedy', 'happy'),
    (30, 'drama', 'sad')
]

for age, genre, mood in test_cases:
    recommendation = recommend_movie(age, genre, mood)
    print(f"Age: {age}, Genre: {genre}, Mood: {mood}")
    print(f"Recommendation: {recommendation}")

print("\n" + "=" * 60)
print("Exercises completed! Check solutions/ folder for answers.")
print("تم إكمال التمارين! راجع مجلد solutions/ للإجابات.")
print("=" * 60)
# Out:
# Exercise 1: Define AI
# التمرين 1: تعريف الذكاء الاصطناعي
# ------------------------------------------------------------
#
# Your definition here / تعريفك هنا:
#
#
# Exercise 2: Identify AI Types
# التمرين 2: تحديد أنواع الذكاء الاصطناعي
# ------------------------------------------------------------
#
# Exercise 3: AI Application Research
# التمرين 3: بحث عن تطبيقات الذكاء الاصطناعي
# ------------------------------------------------------------
#
# Field: Your field here / المجال الذي اخترته:
#   - Application 1 / التطبيق 1:
#   - Application 2 / التطبيق 2:
#   - Application 3 / التطبيق 3:
#
# Exercise 4: Simple Rule-Based System
# التمرين 4: نظام بسيط قائم على القواعد
# ------------------------------------------------------------
#
# Testing movie recommendation system:
# Age: 25, Genre: action, Mood: excited
# Recommendation: None
# Age: 15, Genre: comedy, Mood: happy
# Recommendation: None
# Age: 30, Genre: drama, Mood: sad
# Recommendation: None
#
# ...

# %% [markdown]
# ## Exercise 5: NumPy for AI Data Processing
# ## تمرين 5: NumPy لمعالجة بيانات الذكاء الاصطناعي
#
# **Required Practical Activity:** Working with NumPy for data processing in AI applications
# See `../../../DETAILED_UNIT_DESCRIPTIONS.md` for detailed requirements.

# %%
# Exercise 5: NumPy for AI Data Processing
# تمرين 5: NumPy لمعالجة بيانات الذكاء الاصطناعي

print("Exercise 5: NumPy for AI Data Processing")
print("التمرين 5: NumPy لمعالجة بيانات الذكاء الاصطناعي")
print("-" * 60)

# Task 1: Create NumPy arrays for AI data
# TODO: Create a 2D array representing image pixels (10x10 grayscale image)
# Each pixel value should be between 0-255
# TODO: أنشئ مصفوفة ثنائية الأبعاد تمثل بكسل الصورة (صورة 10x10 بتدرج رمادي)
image_pixels = None  # Your code here

# Task 2: Perform matrix operations common in AI
# TODO: Create two matrices A (3x3) and B (3x3) with random values
# Perform matrix multiplication (A @ B) and element-wise multiplication (A * B)
# TODO: أنشئ مصفوفتين A (3x3) و B (3x3) بقيم عشوائية
# نفذ ضرب المصفوفات (A @ B) والضرب العنصر ب العنصر (A * B)
matrix_A = None  # Your code here
matrix_B = None  # Your code here
matrix_mult = None  # Your code here
element_wise = None  # Your code here

# Task 3: Vector operations for feature vectors
# TODO: Create two feature vectors (1D arrays) of length 5
# Calculate dot product, cosine similarity
# TODO: أنشئ متجهين ميزة (مصفوفات أحادية البعد) بطول 5
# احسب الضرب النقطي والتشابه الجيبي
feature_vector_1 = None  # Your code here
feature_vector_2 = None  # Your code here
dot_product = None  # Your code here

# Calculate cosine similarity: dot_product / (||v1|| * ||v2||)
# احسب التشابه الجيبي: dot_product / (||v1|| * ||v2||)
cosine_similarity = None  # Your code here

print("\nMatrix operations completed!")
print("تم إكمال عمليات المصفوفات!")
# Out:
# Exercise 5: NumPy for AI Data Processing
# التمرين 5: NumPy لمعالجة بيانات الذكاء الاصطناعي
# ------------------------------------------------------------
#
# Matrix operations completed!
# تم إكمال عمليات المصفوفات!

# %% [markdown]
# ## Exercise 6: Knowledge Representation and Rule-Based System
# ## تمرين 6: تمثيل المعرفة والنظام القائم على القواعد
#
# **Required Practical Activity:** Exercises on knowledge representation and rule-based systems
# See `../../../DETAILED_UNIT_DESCRIPTIONS.md` for detailed requirements.

# %%
# Exercise 6: Knowledge Representation and Rule-Based System
# تمرين 6: تمثيل المعرفة والنظام القائم على القواعد

print("\nExercise 6: Knowledge Representation")
print("التمرين 6: تمثيل المعرفة")
print("-" * 60)

# Task 1: Create a simple knowledge base using Python dictionaries
# TODO: Create a knowledge base that represents facts about AI concepts
# Structure: {concept: {type: ..., description: ..., related: [...]}}
# TODO: أنشئ قاعدة معرفة بسيطة باستخدام قاموس بايثون
# يمثل حقائق عن مفاهيم الذكاء الاصطناعي
knowledge_base = {}
# Example structure:
# knowledge_base['Neural Network'] = {
#     'type': 'Deep Learning',
#     'description': 'Computing system inspired by biological neural networks',
#     'related': ['Perceptron', 'Backpropagation', 'Activation Function']
# }

# TODO: Add at least 5 AI concepts to the knowledge base
# TODO: أضف 5 مفاهيم على الأقل للذكاء الاصطناعي إلى قاعدة المعرفة

print("Knowledge base created with", len(knowledge_base), "concepts")
print("تم إنشاء قاعدة المعرفة مع", len(knowledge_base), "مفهوم")

# Task 2: Implement a simple rule-based inference system
# TODO: Create rules that can infer new knowledge
# Example: IF concept has type 'Deep Learning' THEN it uses neural networks
# TODO: أنشئ قواعد يمكنها استنتاج معرفة جديدة
def infer_type(concept, kb):
    """
    TODO: Implement rule-based inference
    Given a concept, infer its type based on rules
    """
    # Your inference logic here
    return None

# Test your inference system
# اختبر نظام الاستنتاج الخاص بك
print("\nTesting inference system:")
test_concept = "Neural Network"  # Example
inferred = infer_type(test_concept, knowledge_base)
print(f"Concept: {test_concept}, Inferred: {inferred}")
# Out:
# Exercise 6: Knowledge Representation
# التمرين 6: تمثيل المعرفة
# ------------------------------------------------------------
# Knowledge base created with 0 concepts
# تم إنشاء قاعدة المعرفة مع 0 مفهوم
#
# Testing inference system:
# Concept: Neural Network, Inferred: None

# %% [markdown]
# ---
#
# ## ✅ Check Your Solution | تحقق من حلك
#
# After completing the exercise:
# - ✅ Does your code run without errors?
# - ✅ Does it produce the expected output?
# - ✅ Have you tested with different inputs?
#
# **Next Steps:**
# - Review the solution (if available)
# - Move to the next exercise
# - Complete the quiz to test your understanding
