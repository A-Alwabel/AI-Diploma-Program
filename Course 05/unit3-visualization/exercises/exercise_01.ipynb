# %% [markdown]
# # Unit 3 - Exercise 1: Data Visualization Practice
#
# **Instructions:** Complete the tasks in `exercise_01.py` in this folder.
#
# You can run the script below, or work through the same tasks in cells. Use **Kernel → Restart & Run All** to execute.

# %% [markdown]
# ---

# %% [markdown]
# ## The Story
#
# **BEFORE**: You know basic visualization but don't understand Unit 3 - Exercise 1: Data Visualization Practice deeply.
#
# **AFTER**: You'll master Unit 3 - Exercise 1: Data Visualization Practice and create professional, effective visualizations!
#
# **Why this matters**: Unit 3 - Exercise 1: Data Visualization Practice is essential for building complete, professional data science solutions!
#
# ---

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Instructions and four tasks (`exercise_01.py` in this folder)
# - **Real data:** `montgomery_911_calls` — real 911 dispatches in Montgomery County,
#   Pennsylvania (Dec 2015 – Jul 2020). The full log holds 663,522 of them and is not in
#   this repository; the script loads the **25,000-call sample that is**
#   (`load("montgomery_911_calls", prefer="sample")`, 1 call in 27, same date window, all
#   100 call types, all 68 townships). It hands you `calls` (call-level), `df` (monthly
#   volume per service) and `sample` (2,000 calls for scatter plots). Every *count* you
#   plot is about a twenty-seventh of the county's real counts; every *shape* — seasonality,
#   hour-of-day, service mix, the 12% missing-ZIP rate — is the real one. The missing ZIP
#   codes are genuine gaps.
# - matplotlib, seaborn, (optional) plotly
#
# **Outputs:** What you'll see when you run the cells
#
# - Visualizations of real emergency-call patterns
# - Captions and insights you write from what the charts actually show
#
# ---

# %%
# %run exercise_01.py
# Out:
# montgomery_911_calls: bundled 25,000-row sample of the 663,522-row original (the full file is on this machine but was not used, because prefer='sample') — every number below is for the sample, not the full file. How it was drawn: 1 row in every 27, evenly spread, so the sample covers the same 2015-12-10 to 2020-07-29 window with all 100 call types and 68 townships.
# Loaded 25,000 real 911 calls (2015-12-10 to 2020-07-29)
# Services: {'EMS': 12613, 'Traffic': 8678, 'Fire': 3709}
# Missing ZIP codes (real gaps): 3,025
# ...
# Task 1: Basic Plots
# ...
#
# ...
# Task 2: Statistical Plots
# ...
#
# ...
# Task 3: Plot Customization
# ...
#
# ...
# Task 4: Multiple Subplots
# ...
#
# ...
# Exercise 1 Complete!
# ...
