# %% [markdown]
# # Unit 4 - Exercise 1: Machine Learning Practice
#
# **Instructions:** Complete the tasks in `exercise_01.py` in this folder.
#
# You can run the script below, or work through the same tasks in cells. Use **Kernel → Restart & Run All** to execute.

# %% [markdown]
# ---

# %% [markdown]
# ## The Story
#
# **BEFORE**: You know basic ML but don't understand Unit 4 - Exercise 1: Machine Learning Practice deeply.
#
# **AFTER**: You'll master Unit 4 - Exercise 1: Machine Learning Practice and understand how it fits into the ML workflow!
#
# **Why this matters**: Unit 4 - Exercise 1: Machine Learning Practice is essential for building complete, professional data science solutions!
#
# ---

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Instructions and three tasks (`exercise_01.py` in this folder)
# - **Real regression data:** California Housing — 20,640 census block groups from
#   the 1990 U.S. census (5,000 sampled). The target is capped at $500,001, a real
#   artefact of the census release.
# - **Real classification data:** `titanic.csv` — 891 passengers, 177 genuinely
#   missing ages, target = survived.
# - sklearn, pandas
#
# **Outputs:** What you'll see when you run the cells
#
# - Trained models scored against an honest baseline
# - Evaluations (MSE, R², accuracy, precision, recall)
# - Plots
#
# ---

# %%
# %run exercise_01.py
# Out:
# Regression data: 5,000 California census block groups x 8 features
# Classification data: 891 Titanic passengers (177 missing ages median-filled, 38.4% survived)
# Majority-class baseline to beat: 61.6%
# ...
# Task 1: Linear Regression
# ...
#
# ...
# Task 2: Classification
# ...
#
# ...
# Task 3: Model Comparison
# ...
#
# ...
# Exercise 1 Complete!
# ...
