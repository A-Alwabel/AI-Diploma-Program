# %% [markdown]
# # Exercise 01: Text Preprocessing
# ## AIAT 121 - Natural Language Processing
#
# ---
#
# ## Learning Objectives
#
# In this exercise, you will:
# - Apply text preprocessing techniques to the sample social-media posts provided below
# - Clean and normalize noisy text (URLs, mentions, hashtags, emoji, casing)
# - Compare different preprocessing strategies
# - Evaluate the impact of preprocessing on a word-frequency analysis
#
# ---
#
# ## Real-World Context
#
# You are working for a social media analytics company that needs to analyze customer feedback about a
# food-delivery app. The **sample posts below are your dataset** — they are defined right in this notebook,
# so there is nothing to download.
#
# Your task is to preprocess this data so it is ready for sentiment analysis.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** 12 sample social-media posts defined in the data cell below.
#
# **Outputs:** your cleaning functions, a comparison of preprocessing strategies, and a short written
# conclusion about their impact.
#
# ---

# %%
# %pip install nltk pandas -q
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## The Dataset
#
# Run this cell first — every task below works on `sample_posts`.

# %%
# Dataset cell: the raw social-media posts every task below works on.
# The mess is deliberate — URLs, @mentions, hashtags, emoji, and SHOUTING are
# exactly the noise your cleaning functions must learn to handle.

# Sample customer posts about a (fictional) food-delivery app.
sample_posts = [
    "Just tried @QuickBites and WOW the delivery was so fast!! 🚀 #foodie #happy",
    "@QuickBites worst experience EVER... order arrived cold :( https://qb.example.com/order/123",
    "Loving the new update! Check it out: https://quickbites.example.com #app #update",
    "why does @QuickBites keep CRASHING every time i open it?!? so annoying!!!",
    "Great discount codes today 🎉🎉 use SAVE20 at checkout #deals #QuickBites",
    "honestly @QuickBites support was super helpful, fixed my refund in 10 minutes 👍",
    "The app charged me TWICE for one order... not ok @QuickBites #fail",
    "best pizza in town delivered in 20 mins!!! 🍕🍕 thank you @QuickBites",
    "Uninstalling. The new UI is confusing & slow. #QuickBites #disappointed",
    "Can't believe the driver called me to confirm the address, great service! 😊",
    "ETA said 15 min, food came after AN HOUR. never again http://qb.example.com/track",
    "the veggie bowl is amazing 🥗 10/10 would order again #healthy #QuickBites",
]
# Peek at a few raw posts so you know what you are about to clean.
print(f"Dataset loaded: {len(sample_posts)} posts")
for p in sample_posts[:3]:
    print(" -", p)
# Out:
# Dataset loaded: 12 posts
#  - Just tried @QuickBites and WOW the delivery was so fast!! 🚀 #foodie #happy
#  - @QuickBites worst experience EVER... order arrived cold :( https://qb.example.com/order/123
#  - Loving the new update! Check it out: https://quickbites.example.com #app #update

# %% [markdown]
# ## Task 1: Clean Text (20 points)
#
# Write a function to clean a post by removing URLs, mentions (`@user`), hashtag symbols (keep the word,
# drop the `#`), emoji/special characters, and extra whitespace. Then apply it to every post in
# `sample_posts` and print the results.

# %%
# TODO: Implement clean_text() and apply it to sample_posts

def clean_text(text):
    # YOUR CODE HERE (hint: the re module — re.sub with patterns for URLs, @mentions, #)
    pass

# for post in sample_posts:
#     print(clean_text(post))

# %% [markdown]
# ## Task 2: Compare Preprocessing Strategies (40 points)
#
# Build **two** preprocessing pipelines and run both on `sample_posts`:
#
# 1. **Minimal**: cleaning (Task 1) + lowercasing + whitespace tokenization
# 2. **Aggressive**: minimal + stop-word removal + punctuation stripping
#
# For each pipeline report: total token count, vocabulary size, and the 10 most frequent tokens
# (`collections.Counter` helps). Print the two results side by side.

# %%
# Task 3 scaffold: build two competing preprocessing pipelines and compare them.
# The point of the comparison: aggressive cleaning shrinks the vocabulary but can
# also destroy signal (negations, emphasis) — measure the trade-off, don't guess.

from collections import Counter

# TODO: Implement both pipelines and compare their outputs

def pipeline_minimal(text):
    # YOUR CODE HERE
    pass

def pipeline_aggressive(text):
    # YOUR CODE HERE (a small stop-word list like {"the","a","is","in","and","to"} is fine)
    pass

# TODO: run both over sample_posts, then print token counts, vocabulary sizes,
#       and Counter(...).most_common(10) for each

# %% [markdown]
# ## Task 3: Evaluate the Impact (40 points)
#
# Using your Task 2 results:
#
# 1. Which tokens dominate the top-10 list under the *minimal* pipeline but disappear under the
#    *aggressive* one?
# 2. Which pipeline gives a top-10 list that better reflects what customers are actually talking about?
# 3. Write a 3–5 sentence conclusion in the markdown cell below: which strategy would you use before
#    sentiment analysis, and what information does it lose?
#
# **Submission**: completed notebook with all code cells executed and your conclusion written.
#
# **Grading**: Task 1 = 20, Task 2 = 40, Task 3 = 40 — **100 points total**.

# %%
# TODO: any additional analysis code for your Task 3 answers

# %% [markdown]
# ### Your conclusion (Task 3)
#
# *Replace this text with your 3–5 sentence conclusion.*
