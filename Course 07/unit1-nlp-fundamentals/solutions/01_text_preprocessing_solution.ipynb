# %% [markdown]
# # INSTRUCTOR SOLUTION: Text Preprocessing
# ## AIAT 121 - Natural Language Processing
#
# **⚠️ INSTRUCTOR USE ONLY**
#
# This solution demonstrates complete text preprocessing for social media analytics.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install nltk pandas -q
import nltk
import pandas as pd


import re
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer, WordNetLemmatizer
from collections import Counter_nltk.download('punkt', quiet=True)
nltk.download('stopwords', quiet=True)
nltk.download('wordnet', quiet=True)
nltk.download('omw-1.4', quiet=True)
print('✅ Setup complete!')

# %%
# Sample tweets
tweets = [
    "Just bought the new iPhone 15! Absolutely LOVING it!!! #Apple https://t.co/xyz",
    "@CustomerService Your service is terrible!!! NOT HAPPY",
]

# %% [markdown]
# ## Solution: Complete Preprocessing Pipeline

# %%
def clean_text(text):
    pass

# %% [markdown]
# ## Teaching Notes
#
# **Key Points:**
# 1. Keep negation words for sentiment analysis
# 2. Regex order matters (URLs before special chars)
# 3. Lemmatization > Stemming for sentiment
# 4. Real-world application: Twitter sentiment, customer feedback
#
# **Common Mistakes:**
# - Removing 'not', 'never' destroys sentiment
# - No error handling for edge cases
# - Forgetting lowercase conversion
#
# **Grading: 100 points total**
# - Clean text: 20 pts
# - Tokenization: 15 pts
# - Stop words: 15 pts (10 pts for keeping negation!)
# - Stemming/Lemma: 20 pts
# - Pipeline: 30 pts
