# %% [markdown]
# # INSTRUCTOR SOLUTION: Multi-Language Text Processing
# ## AIAT 121 - Natural Language Processing
#
# **⚠️ INSTRUCTOR USE ONLY**
#
# Complete solution with teaching notes and grading rubric.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install nltk -q
import nltk
from nltk.tokenize import word_tokenize
import re_nltk.download('punkt', quiet=True)
print('✅ Setup complete!')

# %% [markdown]
# ## Solution: Multi-Language Tokenization

# %%
def tokenize_english(text):
    pass

# %% [markdown]
# ## Teaching Notes
#
# **Key Points:**
# 1. Different languages require different tokenization strategies
# 2. English: Word-based tokenization works well
# 3. Arabic: Use Unicode ranges for Arabic script
# 4. Chinese: Character-level tokenization
#
# **Grading: 100 points**
# - Task 1: 30 pts (10 pts per language)
# - Task 2: 25 pts
# - Task 3: 45 pts
#
# **Common Mistakes:**
# - Not handling Unicode properly
# - Forgetting to normalize text
# - Wrong tokenization method for language
