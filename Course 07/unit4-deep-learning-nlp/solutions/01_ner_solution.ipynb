# %% [markdown]
# # INSTRUCTOR SOLUTION: Named Entity Recognition
# ## AIAT 121 - Natural Language Processing
#
# **⚠️ INSTRUCTOR USE ONLY**
#
# Complete solution with teaching notes.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install spacy -q
# Note: Requires: python -m spacy download en_core_web_sm
import spacy_
print('📝 NER Solution Concept:')
print('\n1. Load spaCy model: nlp = spacy.load("en_core_web_sm")')
print('2. Process text: doc = nlp(text)')
print('3. Extract entities: doc.ents')
print('4. Classify: entity.label_')
print('\n✅ NER solution understood!')
print('\nReal-world: Extract key information from news articles')

# %% [markdown]
# ## Teaching Notes
#
# **Key Points:**
# 1. Use pre-trained models (spaCy)
# 2. Entity types: PERSON, ORG, GPE, etc.
# 3. Visualize entity relationships
#
# **Grading: 100 points**
# - Task 1: 35 pts
# - Task 2: 30 pts
# - Task 3: 35 pts
#
# **Common Mistakes:**
# - Not installing spaCy model
# - Wrong entity extraction
# - Poor visualization
