# %% [markdown]
# # Exercise: Named Entity Recognition for News Articles
# ## AIAT 121 - Natural Language Processing
#
# ## Learning Objectives
#
# - Implement Named Entity Recognition
# - Extract entities from news articles
# - Visualize entity relationships
# - Apply to real-world news data
#
# ## Real-World Context
#
# Extract key information (people, organizations, locations) from news articles. Three sample articles (fictional, written for this exercise) are provided in the data cell below — nothing to download.
#
# **Task**: Build NER system for news article analysis.
#
# ---
#
# ## Task 1: NER Implementation (35 points)
#
# Implement NER using spaCy or NLTK:
# 1. Load pre-trained NER model
# 2. Extract entities
# 3. Classify entity types

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** the three fictional news articles defined in the data cell below — nothing to download. The setup cell installs spaCy; Task 1 also needs its English model `en_core_web_sm` (download command in the Task 1 comments).
#
# **Outputs:** whatever your completed TODO cells print — extracted entities, entity-type counts with a bar chart, and a structured per-article summary. The TODO cells produce no output until you complete them.
#
# ---

# %% [markdown]
# ## The Dataset
#
# Run this cell first — every task below works on `articles`.

# %%
# The dataset for ALL tasks: three short FICTIONAL news snippets written for this
# exercise (any resemblance to real events is coincidental). NER models still
# recognize the entity types.
articles = [
    """GreenTech Arabia announced on Monday that its chief executive, Nora Al-Salem,
    will open a new research center in Riyadh next March. The company, founded in 2019,
    says the center will employ 200 engineers and cost 50 million dollars.""",

    """The Riverdale City Council approved a partnership between Northbridge University
    and Solaris Energy to build a solar farm outside Riverdale. Professor Daniel Okoye,
    who leads the university's energy lab, called the decision a milestone for the region.""",

    """Shares of Meridian Foods rose 4 percent on Thursday after the company reported
    record quarterly sales in Egypt and Jordan. Chief financial officer Laila Hassan told
    reporters that Meridian plans to enter the Moroccan market by 2027.""",
]
print(f"Dataset loaded: {len(articles)} sample articles")
print(articles[0][:120] + "...")
# Out:
# Dataset loaded: 3 sample articles
# GreenTech Arabia announced on Monday that its chief executive, Nora Al-Salem,
#     will open a new research center in Riy...

# %%
# Task 1 scaffold: load spaCy's English model, then write the entity extractor.
# extract_entities() should return (text, label) pairs — the raw material for
# every count and chart in the later tasks.

# %pip install spacy -q
import spacy

# TODO: Load NER model
# nlp = spacy.load('en_core_web_sm')
# If loading fails, the model is not installed yet — download it once with:
#   !python -m spacy download en_core_web_sm

# TODO: Implement NER function
def extract_entities(text):
    # YOUR CODE HERE
    pass
# Out:
# [notice] A new release of pip is available: 26.0.1 -> 26.2.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Task 2: Entity Analysis (30 points)
#
# Analyze extracted entities:
# 1. Count entity types
# 2. Find most common entities
# 3. Visualize results

# %%
# TODO (Task 2): analyze entities extracted from `articles`:
#   1. count entities per type (collections.Counter)
#   2. find the most common entities across all three articles
#   3. visualize the counts with a matplotlib bar chart

# YOUR CODE HERE

# %% [markdown]
# ## Task 3: Real-World Application (35 points)
#
# Process all three provided `articles` and extract key information into a structured summary:
# for each article, print the people, organizations, locations, dates, and monetary amounts it mentions.
#
# **Submission**: Complete notebook with NER system.
#
# **Grading**: 100 points total

# %%
# TODO (Task 3): build the structured per-article summary described above.

# YOUR CODE HERE
