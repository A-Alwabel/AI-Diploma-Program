# %% [markdown]
# # Exercise 01: Implementation Planning
#
# ## AIAT 126
#
# ## 🔗 Builds on (AIAT 111–125)
#
# AIAT 126 is the *graduation* project: it **assembles** what you already built across the diploma, it does not re-teach it. Open what you need:
#
# - **AIAT 115 U2 — the cleaning steps your plan reuses** → [`Course 05/unit2-cleaning/examples/02_missing_values_duplicates.ipynb`](../../../Course%2005/unit2-cleaning/examples/02_missing_values_duplicates.ipynb)
# - **AIAT 114 U5 — the tuning loop your plan schedules** → [`Course 04/unit5-model-selection/examples/01_grid_search.ipynb`](../../../Course%2004/unit5-model-selection/examples/01_grid_search.ipynb)
# - **AIAT 125 U5 — experiment tracking for the runs you are about to start** → [`Course 11/unit5-pipelines-monitoring/examples/05_experiment_tracking_mlflow_wandb.ipynb`](../../../Course%2011/unit5-pipelines-monitoring/examples/05_experiment_tracking_mlflow_wandb.ipynb)
#
# Record every artifact you reuse in **section 6, the Prior Work Inventory**, of [`TEMPLATES/project_proposal_template.md`](../../TEMPLATES/project_proposal_template.md). It is scored at gate 1 (criterion 1.7) and re-checked at the Unit 2 design review — it is this course's **CLO2** evidence, and the official AIAT 126 description requires it.
#
# ---
#
# ## Learning Objectives
#
# In this exercise, you will:
# - Plan the implementation phase of your own capstone project: the data
#   pipeline and the training/tuning workflow
#
# ---
#
# ## Real-World Context
#
# Implementation without a plan produces a tangle of half-finished scripts.
# A short written plan — data first, baseline first, then tuning — is how the
# two lesson notebooks of this unit are structured, and how your project
# should be too.
#
# ---

# %% [markdown]
# ## Task 1: Implementation Planning (100 points)
#
# Plan the implementation of your capstone project: how you will collect and
# prepare your data (as practiced in notebook `01_data_collection_preprocessing`)
# and how you will train and tune your models (as practiced in notebook
# `02_model_training_hyperparameter_optimization`).
#
# **Requirements:**
# - Data plan: source(s), collection method, cleaning/preprocessing steps, and the train/validation/test split
# - Training plan: baseline model first, candidate models, and which hyperparameters you will search and how (grid vs random)
# - Milestones: the order of work with target dates
# - Follow the project guidelines ([PROJECT_GUIDELINES.md](../../PROJECT_GUIDELINES.md)) and document thoroughly

# %%
# Setup: plain Python is enough — fill in the plan below and print it.
# TODO: Replace every placeholder with the plan for YOUR capstone project.

implementation_plan = {
    # Part 1: data — where it comes from and how you make it model-ready (see notebook 01)
    "data_source": "TODO: dataset name / API / collection method",
    "preprocessing_steps": [
        "TODO: e.g. handle missing values (drop or impute?)",
        "TODO: e.g. encode categorical features",
        "TODO: e.g. scale numeric features",
    ],
    "split_strategy": "TODO: e.g. stratified 60/20/20 train/validation/test",
    # Part 2: training — baseline first, then candidates and the tuning method (see notebook 02)
    "baseline_model": "TODO: the simple model you measure everything against",
    "candidate_models": ["TODO", "TODO"],
    "hyperparameter_search": "TODO: grid or random search, over which parameters",
    # Part 3: schedule — the order you will do the work in, with target dates
    "milestones": [
        "TODO: data collected and cleaned — by <date>",
        "TODO: baseline trained and evaluated — by <date>",
        "TODO: tuned model selected — by <date>",
    ],
}

# Print your plan so you (and your instructor) can review it
for key, value in implementation_plan.items():
    print(f"{key}: {value}\n")
# Out:
# data_source: TODO: dataset name / API / collection method
#
# preprocessing_steps: ['TODO: e.g. handle missing values (drop or impute?)', 'TODO: e.g. encode categorical features', 'TODO: e.g. scale numeric features']
#
# split_strategy: TODO: e.g. stratified 60/20/20 train/validation/test
#
# baseline_model: TODO: the simple model you measure everything against
#
# candidate_models: ['TODO', 'TODO']
#
# hyperparameter_search: TODO: grid or random search, over which parameters
#
# milestones: ['TODO: data collected and cleaned — by <date>', 'TODO: baseline trained and evaluated — by <date>', 'TODO: tuned model selected — by <date>']
