# %% [markdown]
# # Exercise 1: Bias and Fairness on Real Data
#
# You will audit and try to mitigate a **real** disparity in the **real** Titanic
# passenger manifest, loaded with `load("titanic")` - 891 real
# people, real missing values, and a real recorded outcome.
#
# **What makes this exercise different from a textbook one:** the disparity here is
# confounded. "Women and children first" was a stated evacuation policy, and ticket
# class is tangled up with it. You are not looking for a clean villain in the data;
# you are practising the harder skill of measuring a gap accurately and then being
# precise about what the measurement does and does not prove.
#
# Expect at least one mitigation technique to fail. Report it.

# %%
# --- Data setup. Works from any folder, and on Google Colab. -------------------------
# WHAT: find the repository root and put it on sys.path, then import the shared loader.
# WHY:  a hard-coded '../../../Course 04/datasets/raw/titanic.csv' only resolves when the
#       kernel's working directory happens to be this notebook's folder. This does not care.
import sys, pathlib

_here = pathlib.Path.cwd().resolve()
_root = next((p for p in [_here, *_here.parents] if (p / "tools" / "data.py").exists()), None)
if _root is None:                     # Google Colab, or a stray copy of the notebook
    import urllib.request
    pathlib.Path("tools").mkdir(exist_ok=True)
    try:
        urllib.request.urlretrieve(
            "https://raw.githubusercontent.com/A-Alwabel/"
            "AI-Diploma-Program/main/tools/data.py", "tools/data.py")
    except Exception as _e:
        raise RuntimeError(
            "Could not find the AI Diploma repository from this folder, and could not "
            "download the data loader either. Open this notebook inside a clone of "
            "https://github.com/A-Alwabel/AI-Diploma-Program, or connect to the internet "
            f"and re-run this cell. (underlying error: {_e})") from None
    _root = pathlib.Path.cwd()
sys.path.insert(0, str(_root))

from tools.data import load        # load("titanic"), load("creditcard_fraud"), ...
# -------------------------------------------------------------------------------------
print("Data loader ready - datasets are loaded by NAME, never by file path.")

# %%
"""
Unit 2: Bias, Justice, and Discrimination in AI
Exercise 1: Bias Mitigation Techniques on REAL Data

You will audit and mitigate a real disparity in a real dataset - the Titanic
passenger manifest (891 real people, a real recorded life-or-death decision).

No synthetic data anywhere in this exercise. Everything you measure is a
property of the historical record, which means your numbers will be messier
than a textbook example - that is the point.
"""

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import accuracy_score
from fairlearn.metrics import demographic_parity_difference, equalized_odds_difference

# ============================================================================
# TASK 1: Load and Prepare the Real Dataset
# ============================================================================

def load_real_dataset():
    """
    TODO: Load the real Titanic manifest and prepare it for a fairness audit.

    Requirements:
    - Get the manifest with `load("titanic")` - the shared loader finds the file
      from any working directory, so you never write a path
    - Handle the REAL missing values honestly: `Age` has 177 missing and
      `Embarked` has 2. Impute them (median / mode) and be ready to say so.
    - Build a `sensitive` column: 1 for female, 0 for male
    - Build a `target` column from `Survived`
    - Build numeric features from Pclass, Age, SibSp, Parch, Fare, Embarked
      (use pd.get_dummies for Embarked)
    - Return a DataFrame containing the feature columns plus 'sensitive' and 'target'
    """
    # TODO: Your code here
    # Hint: df['Age'] = df['Age'].fillna(df['Age'].median())
    # Hint: pd.get_dummies(df[[...]], columns=['Embarked'], drop_first=True)

    pass

# ============================================================================
# TASK 2: Measure the Disparity That Is Already There
# ============================================================================

def describe_disparity(df):
    """
    TODO: Report the disparity present in the DATA, before any model exists.

    Requirements:
    - Print the positive-outcome rate for each group
    - Print the gap between them
    - Print the group sizes (they are NOT balanced - say so)
    - Return a dict with the per-group rates and the gap

    Then answer in a comment: is this gap evidence of discrimination?
    "Women and children first" was a stated evacuation policy. What would you
    need to know to separate the justified part of this gap from the rest?
    """
    # TODO: Your code here

    pass

# ============================================================================
# TASK 3: Implement Pre-processing Bias Mitigation
# ============================================================================

def preprocess_reweighing(X_train, y_train, sensitive_train):
    """
    TODO: Implement reweighing technique.

    Requirements:
    - Calculate weights to balance representation across groups
    - Return array of weights for each training sample

    Prediction to write down BEFORE you run it: reweighing rebalances group
    SIZE. In this dataset the groups differ mainly in OUTCOME rate. Do you
    expect it to help? Check your prediction against your Task 6 output.
    """
    # TODO: Your code here
    # Hint: Calculate weights inversely proportional to group size

    pass

# ============================================================================
# TASK 4: Train Models with Different Mitigation Techniques
# ============================================================================

def train_baseline_model(X_train, y_train):
    """
    TODO: Train a baseline model without any bias mitigation.
    """
    # TODO: Your code here
    # Hint: Use RandomForestClassifier

    pass

def train_reweighed_model(X_train, y_train, sensitive_train):
    """
    TODO: Train a model using reweighing technique.
    """
    # TODO: Your code here
    # Hint: Use the preprocess_reweighing function and pass weights to fit()

    pass

# ============================================================================
# TASK 5: Evaluate Fairness Metrics
# ============================================================================

def evaluate_fairness(y_true, y_pred, sensitive):
    """
    TODO: Evaluate fairness metrics.

    Requirements:
    - Calculate demographic parity difference
    - Calculate equalized odds difference
    - Calculate accuracy
    - Calculate accuracy PER GROUP (real data makes this one essential -
      a model can score well overall and badly for one group)
    - Return a dictionary with these metrics
    """
    # TODO: Your code here
    # Hint: Use fairlearn.metrics functions

    pass

# ============================================================================
# TASK 6: Compare Techniques and Report Honestly
# ============================================================================

def compare_mitigation_techniques(df):
    """
    TODO: Compare baseline vs reweighing techniques.

    Requirements:
    - Split data into train/test (stratify on the target)
    - Train baseline and reweighed models
    - Evaluate fairness metrics for both
    - Print a comparison table INCLUDING the accuracy change vs baseline

    Report honestly: if reweighing did not reduce the disparity, say so and
    explain why. A mitigation that fails is a finding, not a mistake to hide.
    """
    # TODO: Your code here

    pass

# ============================================================================
# MAIN EXECUTION
# ============================================================================

if __name__ == "__main__":
    print("="*80)
    print("Unit 2 - Exercise 1: Bias Mitigation on Real Data")
    print("="*80)

    # Load the real data
    print("\nTask 1: Loading the real Titanic manifest...")
    df = load_real_dataset()
    if df is None:
        print("load_real_dataset() is not implemented yet - complete Task 1 first.")
    else:
        print(f"Dataset shape: {df.shape}")
        print("Sensitive attribute distribution (real, and NOT balanced):")
        print(df['sensitive'].value_counts())

        print("\nTask 2: Measuring the disparity already in the data...")
        describe_disparity(df)

        print("\nTask 6: Comparing mitigation techniques...")
        compare_mitigation_techniques(df)

    print("\n" + "="*80)
    print("Exercise completed! Check your results against the solution.")
    print("="*80)
# Out:
# ...
# Unit 2 - Exercise 1: Bias Mitigation on Real Data
# ...
#
# Task 1: Loading the real Titanic manifest...
# load_real_dataset() is not implemented yet - complete Task 1 first.
#
# ...
# Exercise completed! Check your results against the solution.
# ...
