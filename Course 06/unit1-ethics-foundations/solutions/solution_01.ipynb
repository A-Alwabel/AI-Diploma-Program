# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Unit 1: Foundations of AI Ethics

# %% [markdown]
# Complete solution:# """# Unit 1: Foundations of AI Ethics# Exercise 1: Ethical Framework Application# This exercise helps you practice applying ethical frameworks to AI scenarios.# """# # ============================================================================# # EXERCISE INSTRUCTIONS# # ============================================================================# """# EXERCISE 1: Ethical Framework Analysis# Scenario: A company wants to develop an AI system that monitors employee# productivity by analyzing computer usage patterns, email content, and# keystroke dynamics.# TASKS# 1. Identify the ethical issues in this scenario# 2. Apply at least THREE different ethical frameworks to analyze this scenario:#    - Utilitarianism#    - Deontology#    - Rights-Based Ethics# 3. Identify all stakeholders and their interests# 4. Provide recommendations for ethical AI development# 5. Create a visualization showing:#    - Stakeholder impact matrix#    - Ethical issues severity chart# """# # ============================================================================# # # SOLUTION: Complete the following sections# # ============================================================================# # TASK 1: Identify Ethical Issues# def identify_ethical_issues():#     """#     # SOLUTION: List at least 3 ethical issues in this scenario#     Returns:#         list: List of ethical issues with descriptions#     """#     ethical_issues = [#         # # SOLUTION: Add your analysis here#         # Example format:#         # {#         #     'issue': 'Privacy violation', #         #     'severity': 9,#         #     'description': 'Monitoring employees violates their privacy rights'#         # }#     ]#     return ethical_issues# # TASK 2: Apply Ethical Frameworks# def apply_utilitarianism():#     """#     # SOLUTION: Analyze the scenario from a Utilitarian perspective#     Consider:#     - What are the benefits?#     - What are the harms?#     - Who is affected?#     - Overall utility calculation#     Returns:#         dict: Analysis with benefits, harms, and conclusion#     """#     analysis = {#         'benefits': [],  # # SOLUTION: List benefits#         'harms': [],     # # SOLUTION: List harms#         'overall_utility': None,  # # SOLUTION: Calculate overall utility#         'conclusion': ''  # # SOLUTION: Is it ethical from utilitarian perspective?#     }#     return analysis# def apply_deontology():#     """#     # SOLUTION: Analyze the scenario from a Deontological perspective#     Consider:#     - What moral rules/duties apply?#     - Are any rules violated?#     - What would a deontologist say?#     Returns:#         dict: Analysis with rules, violations, and conclusion#     """#     analysis = {#         'moral_rules': [],  # # SOLUTION: List relevant moral rules#         'violations': [],    # # SOLUTION: List any rule violations#         'conclusion': ''     # # SOLUTION: Is it ethical from deontological perspective?#     }#     return analysis# def apply_rights_based():#     """#     # SOLUTION: Analyze the scenario from a Rights-Based perspective#     Consider:#     - What rights are at stake?#     - Are any rights violated?#     - How can rights be protected?#     Returns:#         dict: Analysis with rights, violations, and conclusion#     """#     analysis = {#         'rights_at_stake': [],  # # SOLUTION: List relevant rights#         'violations': [],        # # SOLUTION: List any rights violations#         'conclusion': ''         # # SOLUTION: Is it ethical from rights-based perspective?#     }#     return analysis# # TASK 3: Identify Stakeholders# def identify_stakeholders():#     """#     # SOLUTION: List all stakeholders and their interests#     Returns:#         dict: Stakeholders with their interests, impact, and influence#     """#     stakeholders = {#         # # SOLUTION: Add stakeholders#         # Example format:#         # 'Employees': {#         #     'interests': ['Privacy', 'Autonomy'],#         #     'impact': 9,  # How much are they affected (1-10)#         #     'influence': 5  # How much influence do they have (1-10)#         # }#     }#     return stakeholders# # TASK 4: Provide Recommendations# def provide_recommendations():#     """#     # SOLUTION: Provide ethical recommendations for this AI system#     Consider:#     - How to address ethical issues#     - How to protect stakeholder rights#     - How to ensure transparency and accountability#     Returns:#         list: List of recommendations#     """#     recommendations = [#         # # SOLUTION: Add your recommendations#         # Example: "Obtain explicit consent from employees before monitoring"#     ]#     return recommendations# # TASK 5: Create Visualizations# def create_visualizations():#     """#     # SOLUTION: Create visualizations for:#     1. Stakeholder impact matrix#     2. Ethical issues severity chart#     Use matplotlib to create the visualizations.#     Save them as PNG files.#     """#     # # SOLUTION: Import matplotlib#     # # SOLUTION: Create stakeholder impact matrix#     # # SOLUTION: Create ethical issues severity chart#     # # SOLUTION: Save visualizations#     pass# # ============================================================================# # MAIN EXECUTION# # ============================================================================# if __name__ == "__main__":#     print("="*80)#     print("Unit 1 - Exercise 1: Ethical Framework Application")#     print("")#     print("="*80)#     print("\n📋 Instructions:")#     print("Complete all # SOLUTION sections in this file.")#     print("Run each function and verify your analysis.")#     print("Create visualizations as specified.")#     print("")#     print("")#     print("")#     print("")#     # Run your completed functions here#     # ethical_issues = identify_ethical_issues()#     # utilitarianism = apply_utilitarianism()#     # deontology = apply_deontology()#     # rights_based = apply_rights_based()#     # stakeholders = identify_stakeholders()#     # recommendations = provide_recommendations()#     # create_visualizations()#     print("\n✅ Exercise template ready. Complete the # SOLUTION sections!")#     print("")#

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
