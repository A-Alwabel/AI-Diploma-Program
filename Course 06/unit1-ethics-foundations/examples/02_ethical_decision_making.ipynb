# %% [markdown]
# # 02. Ethical Decision-Making Framework
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Use structured decision-making processes for AI ethics
# - Identify stakeholders and weigh impacts
# - Document and justify ethical choices
#
# ## 🔗 Where this fits
#
# **Builds on:** Course 01 (AIAT 111) — Unit 1, lesson 04 "Intelligent Agents and Rationality" — a rational agent maximizes its objective; this lesson asks who chooses that objective and who pays for it.
#
# ---

# %% [markdown]
# # 02. Ethical Decision-Making Framework
#
# ## 🚨 THE PROBLEM: Frameworks Conflict - We Need a Decision Process
#
# **Remember the autonomous vehicle problem from the previous notebook?**
#
# We learned five ethical frameworks, but when we applied them to the same problem, **they gave us different answers**:
# - Utilitarianism recommended Option A
# - Virtue Ethics recommended Option C
# - Deontology and Rights-Based found no clear answer
# - Care Ethics recommended Option C
#
# **The Problem**: We have ethical frameworks, but **they conflict with each other**! How do we:
# - Decide which framework to follow?
# - Resolve conflicts between frameworks?
# - Make a final, justified ethical decision?
#
# **We need a systematic decision-making process** that helps us:
# 1. Apply multiple frameworks
# 2. Resolve conflicts between them
# 3. Make a final, justified decision
#
# ---
#
# ## 📚 Prerequisites (What You Need First)
#
# **BEFORE starting this notebook**, you should have completed:
# - ✅ **Example 1: Ethical Frameworks** - You need to understand ethical frameworks first!
# - ✅ **Basic Python knowledge**: Classes, dictionaries, functions
# - ✅ **Understanding of ethical frameworks**: Utilitarianism, Deontology, Rights-Based, etc.
#
# **If you haven't completed these**, you might struggle with:
# - Understanding how to apply ethical frameworks
# - Knowing which framework to use when
# - Making structured ethical decisions
#
# ---
#
# ## 🔗 Where This Notebook Fits
#
# **This is the SECOND example** - it solves the limitation from Example 1!
#
# **Why this example SECOND?**
# - **Before** you can make ethical decisions, you need to know the frameworks (Example 1)
# - **Before** you can resolve framework conflicts, you need a decision-making process (This notebook!)
# - **Before** you can analyze cases, you need a structured approach
#
# **Builds on**:
# - 📓 Example 1: Ethical Frameworks (we learned frameworks, but they conflict - now we solve that!)
#
# **Leads to**:
# - 📓 Example 3: Case Study Analysis (uses this decision-making framework!)
# - 📓 Unit 2: Bias and Justice (uses ethical decision-making to evaluate fairness!)
# - 📓 All ethical analysis (all need structured decision-making!)
#
# **Why this order?**
# 1. Decision-making **solves the framework conflict problem** (addresses limitation from Example 1)
# 2. Decision-making provides **a process** for applying frameworks (needed for all analysis)
# 3. Decision-making teaches you **how to think systematically** (critical for ethics)
#
# ---
#
# ## The Story: Following a Recipe for Ethical Decisions
#
# Imagine you're a chef cooking a complex dish. **Before** you start, you follow a recipe - gather ingredients, prepare them in order, combine them properly, taste and adjust. **After** following the recipe step-by-step, you create a delicious, consistent meal!
#
# Same with ethical decisions: **Before** making decisions, we follow a framework - identify the problem, gather information, apply ethical principles, evaluate options. **After** following the framework step-by-step, we make well-reasoned, consistent ethical decisions!
#
# ---
#
# ## Why Ethical Decision-Making Matters
#
# Structured decision-making is essential for ethical AI:
# - **Consistency**: Same process for all decisions
# - **Thoroughness**: Don't miss important considerations
# - **Transparency**: Can explain how decision was made
# - **Accountability**: Can justify choices to stakeholders
# - **Better Outcomes**: Systematic approach leads to better decisions
#
# ## Learning Objectives
# 1. Understand the 6-step ethical decision-making framework
# 2. Apply ethical frameworks to real scenarios
# 3. Identify stakeholders and their interests
# 4. Evaluate options systematically
# 5. Make justified ethical decisions
# 6. Document decision-making process

# %% [markdown]
# ## 📌 The case: the crash that was not a trolley problem
#
# **18 March 2018, Tempe, Arizona.** An Uber Advanced Technologies Group test vehicle struck
# and killed **Elaine Herzberg** as she pushed a bicycle across a road at night. She is the
# first pedestrian killed by an automated driving system.
#
# The US National Transportation Safety Board investigated (HWY18MH010) and found **no
# dilemma**. It found a decision process with no owner at any step:
#
# - the system **first detected her 5.6 seconds before impact** — an enormous amount of time —
#   but **never classified her as a pedestrian at all**, alternating between "vehicle",
#   "bicycle" and "other"; because the design excluded tracking history for objects whose
#   classification changed, each reclassification threw away the motion history that would have
#   predicted where she was going, and the system recognised an imminent collision only
#   **1.2 seconds** before impact;
# - Volvo's **factory automatic emergency braking was disabled** whenever the Uber system was
#   driving;
# - Uber's own software **suppressed braking for one second** to avoid erratic behaviour from
#   false alarms, relying on the human operator instead;
# - the **operator was looking away** from the road, returning her gaze to it about **1 second**
#   before impact;
# - the NTSB gave the probable cause as the operator's failure to monitor the road because she
#   was visually distracted by her personal phone, and listed among the **contributing factors**
#   Uber ATG's inadequate safety risk assessment procedures, ineffective oversight of operators
#   and lack of mechanisms for addressing automation complacency — "all a consequence of its
#   **inadequate safety culture**".
#
# Every item on that list was a decision a person made, for a reason they could have defended
# at the time. Not one of them was ever recorded as a decision with a name attached to it.
#
# **The WHY — what goes wrong without a process.** Notebook 01 ended with frameworks that
# disagree, and this notebook answers with a **six-step process**. Tempe shows why a process
# beats a verdict: five individually reasonable engineering choices combined into a fatality,
# and afterwards there was no document saying who had accepted which risk. A structured
# process forces you to name the stakeholders (Herzberg was not a customer and never consented
# to the risk), state the alternatives, and record who signed. Its output is not a right
# answer. It is a **record** — which is precisely what the NTSB needed and what Uber ATG could
# not produce.
#
# ---

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Step 1: Import necessary libraries
# These libraries help us create visualizations of the decision-making framework

import matplotlib.pyplot as plt  # For creating visualizations: Charts, diagrams, flowcharts
import matplotlib.patches as mpatches  # For drawing shapes: Boxes, arrows, legends
from matplotlib.patches import FancyBboxPatch, FancyArrowPatch  # For styled shapes: Rounded boxes, curved arrows
import numpy as np  # For numerical operations: Arrays, calculations
import os  # For file operations: Saving images

# Configure matplotlib settings: Set default figure size and font size for better visualizations
plt.rcParams['font.size'] = 10  # Font size: Make text readable (10pt is good for most displays)
plt.rcParams['figure.figsize'] = (14, 10)  # Figure size: 14 inches wide, 10 inches tall (good for detailed flowcharts)

print(" Libraries imported successfully!")
print("\n📚 What each library does:")
print("   - matplotlib: Create visualizations (flowcharts, diagrams)")
print("   - matplotlib.patches: Draw shapes (boxes, arrows)")
print("   - numpy: Numerical operations (arrays, calculations)")
print("   - os: File operations (saving images)")
# Out:
#  Libraries imported successfully!
#
# 📚 What each library does:
#    - matplotlib: Create visualizations (flowcharts, diagrams)
#    - matplotlib.patches: Draw shapes (boxes, arrows)
#    - numpy: Numerical operations (arrays, calculations)
#    - os: File operations (saving images)

# %% [markdown]
# ## 📉 The 5.6 seconds, drawn
#
# The case above is a list of five bullet points. Bullet points hide the one thing that
# matters most about that crash: **how much time there was**. Every number in the figure
# below is taken from the case description you just read (NTSB HWY18MH010) — nothing is
# added, and nothing is estimated.

# %%
# Step 1b: Draw the final 5.6 seconds in Tempe as three parallel lanes
# WHY this figure: the NTSB findings are usually read as a list, and a list makes 5.6 seconds
# look like the same size as 1.2 seconds. Put on a shared time axis, the gap between "the
# system saw her" and "the system acted" becomes a physical distance you can point at.
# EVERY number below appears verbatim in the case text at the top of this notebook.

fig, ax = plt.subplots(figsize=(12, 4.8))

# Three lanes = the three parties whose decisions combined into the outcome.
LANE = {'ADS': 2.6, 'CAR': 1.6, 'HUMAN': 0.6}   # y position of each lane
H = 0.42                                        # lane bar height

# --- Lane 1: the automated driving system -----------------------------------------------
# 5.6 s -> 1.2 s : object tracked, but never classified as a pedestrian.
ax.barh(LANE['ADS'], 5.6 - 1.2, left=1.2, height=H, color='#f7c948',
        edgecolor='black', linewidth=0.8)
ax.text(3.4, LANE['ADS'], 'tracked, but classified as\n"vehicle" / "bicycle" / "other" -\n'
        'each change threw away her motion history',
        ha='center', va='center', fontsize=8.5)
# 1.2 s -> 0.2 s : collision recognised, but braking held back for one second by design.
ax.barh(LANE['ADS'], 1.0, left=0.2, height=H, color='#e74c3c',
        edgecolor='black', linewidth=0.8, hatch='//')

# --- Lane 2: the vehicle's own safety system --------------------------------------------
# Volvo's factory AEB was off for the whole time the Uber system was driving.
ax.barh(LANE['CAR'], 6.0, left=0.0, height=H, color='#95a5a6',
        edgecolor='black', linewidth=0.8, alpha=0.85)
ax.text(3.0, LANE['CAR'], "Volvo factory automatic emergency braking: DISABLED "
        "whenever the Uber system was driving",
        ha='center', va='center', fontsize=8.5, color='white', fontweight='bold')

# --- Lane 3: the human the design was relying on ----------------------------------------
# Eyes off the road until about 1 second before impact.
ax.barh(LANE['HUMAN'], 6.0 - 1.0, left=1.0, height=H, color='#8e44ad',
        edgecolor='black', linewidth=0.8, alpha=0.85)
ax.text(3.5, LANE['HUMAN'], 'operator looking away from the road',
        ha='center', va='center', fontsize=8.5, color='white', fontweight='bold')

# --- The four published instants ---------------------------------------------------------
# t, label, colour, and the y at which the label is written. The 1.0 s and 1.2 s marks are
# only 0.2 s apart, so their labels are parked on different lanes instead of on top of
# each other: the gaze event belongs to the human lane anyway.
events = [
    (5.6, 'first detected\n5.6 s before impact', '#b45309', 3.24),
    (1.2, 'collision recognised\n1.2 s before impact', '#b91c1c', 3.24),
    (1.0, 'gaze returns ~1.0 s before', '#6b21a8', 1.02),
    (0.0, 'IMPACT', 'black', 3.24),
]
for t, label, colr, ylab in events:
    ax.axvline(t, color=colr, linestyle='--' if t else '-',
               linewidth=2.0 if t == 0 else 1.2, zorder=0)
    ax.text(t, ylab, label, ha='center', va='bottom',
            fontsize=8.5, color=colr, fontweight='bold')

# The span the whole lesson is about: warning time that produced no braking.
ax.annotate('', xy=(5.6, 0.06), xytext=(0.2, 0.06),
            arrowprops=dict(arrowstyle='<->', color='#111827', linewidth=1.6))
ax.text(2.9, -0.16, '5.4 of the 5.6 seconds: object detected, no autonomous braking',
        ha='center', va='top', fontsize=9.5, fontweight='bold', color='#111827')

ax.set_xlim(6.0, -0.45)                      # time runs left to right, TOWARDS impact
ax.set_xticks([6, 5, 4, 3, 2, 1, 0])
ax.set_xlabel('seconds before impact  (0 = impact)', fontsize=11, fontweight='bold')
ax.set_ylim(-0.85, 3.95)
ax.set_yticks([LANE['ADS'], LANE['CAR'], LANE['HUMAN']])
ax.set_yticklabels(['Uber automated\ndriving system', "Volvo's own\nemergency braking",
                    'Human safety\noperator'], fontsize=9.5)
ax.set_title('Tempe, 18 March 2018 - the last 5.6 seconds (NTSB HWY18MH010)',
             fontsize=13, fontweight='bold', pad=26)
ax.grid(axis='x', alpha=0.25, linestyle=':')
for side in ('top', 'right'):
    ax.spines[side].set_visible(False)

# Name the hatched band where it sits, rather than in a legend box that would have to
# be parked on top of one of the event labels.
ax.annotate('1-second braking suppression\n(deliberate, to avoid false alarms)',
            xy=(0.52, 2.45), xytext=(2.35, 2.06), ha='center', va='center',
            fontsize=8.5, color='#b91c1c', fontweight='bold',
            arrowprops=dict(arrowstyle='->', color='#b91c1c', linewidth=1.2))
plt.tight_layout()
plt.show()

# Print the same timeline as a table, so figure and numbers can never drift apart.
print("Published instants (all from the case description above):")
for t, label, _c, _y in events:
    print(f"  t = -{t:>4.1f} s : {label.splitlines()[0]}")
print()
print("Gap between 'system had the object' and 'system was allowed to brake':")
print(f"  5.6 s - 0.2 s = {5.6 - 0.2:.1f} s of detection with no autonomous braking.")
print("Not one of those seconds was lost to a hard ethical dilemma.")
print("They were lost to four separate design decisions that nobody had to sign.")
# Out:
# Published instants (all from the case description above):
#   t = - 5.6 s : first detected
#   t = - 1.2 s : collision recognised
#   t = - 1.0 s : gaze returns ~1.0 s before
#   t = - 0.0 s : IMPACT
#
# Gap between 'system had the object' and 'system was allowed to brake':
#   5.6 s - 0.2 s = 5.4 s of detection with no autonomous braking.
# Not one of those seconds was lost to a hard ethical dilemma.
# They were lost to four separate design decisions that nobody had to sign.

# %% [markdown]
# ### 👁️ Read the figure
#
# **What you should see.** Three lanes on one time axis that runs from 6 seconds before
# impact (left) to impact (right).
#
# - **Top lane:** a long yellow bar from **5.6 s to 1.2 s** — the pedestrian is being tracked
#   but is never classified as a person — followed by a short red hatched bar from **1.2 s to
#   0.2 s**, the one second in which the software had recognised the collision and was
#   deliberately not allowed to brake.
# - **Middle lane:** a grey bar across the *entire* width — Volvo's own emergency braking was
#   switched off for all 6 seconds.
# - **Bottom lane:** a purple bar that stops at **1.0 s** — the operator's eyes come back to
#   the road with one second left.
# - The black arrow underneath spans **5.4 of the 5.6 seconds**.
#
# **What it proves.** Notebook 01 left you with frameworks that disagree about an impossible
# choice. This figure shows that the crash that actually happened contained **no impossible
# choice at all**. There were 5.4 seconds of warning, and they were consumed by four ordinary
# engineering decisions — a classifier that discarded history, a disabled factory safety
# system, a deliberate braking delay, and a supervision model that assumed an attentive human.
# Each was defensible on its own; none was ever written down as a decision with a name against
# it. That is the gap a six-step process is meant to close, and it is why the rest of this
# notebook is about producing a **record** rather than a verdict.
#
# ---

# %% [markdown]
# ## Part 2: Understanding the Framework
#
# ### 📚 Prerequisites (What You Need First)
# - **Library imports** (from Part 1) - Understanding visualization tools
# - **Python classes** - Understanding object-oriented programming
#
# ### 🔗 Relationship: What This Builds On
# This is the **CORE** of ethical decision-making - we define the framework we'll use!
# - Builds on: Python basics, ethical frameworks knowledge
# - Comes BEFORE: Scenario analysis (we need the framework first)
#
# ### 📖 The Story
# **Before framework**: We make ethical decisions based on intuition or gut feeling.
# **After framework**: We follow a systematic 6-step process that ensures we consider all important factors!

# %%
# Step 2: Create the Ethical Decision-Making Framework class
# This class implements a 6-step process for making ethical decisions in AI

# BEFORE: No structured decision-making process
# AFTER: A complete framework with 6 steps, each with questions to guide us

class EthicalDecisionFramework:
    """
    A framework for making ethical decisions in AI development.

    HOW IT WORKS:
    1. Defines 6 steps for ethical decision-making
    2. Each step has questions to guide thinking
    3. Provides structure for systematic ethical analysis
    4. Can be applied to any AI ethical dilemma
    """
    def __init__(self):
        # Store the 6 steps as data (a list of dicts) rather than code:
        # the same loop can then print, plot, or apply any step uniformly.
        self.steps = [
            {'step': 1, 'name_en': 'Identify the Problem',
             'description_en': 'Clearly define the ethical issue or dilemma',
             'questions': ['What is the AI system supposed to do?',
                           'What ethical concerns might arise?',
                           'Who are the stakeholders?']},
            {'step': 2, 'name_en': 'Gather Information',
             'description_en': 'Collect relevant facts and context',
             'questions': ['What data will be used?',
                           'How will the system be deployed?',
                           'What are the potential impacts?']},
            {'step': 3, 'name_en': 'Identify Stakeholders',
             'description_en': 'List all affected parties',
             'questions': ['Who will use the system?',
                           'Who might be affected?',
                           'Who has decision-making power?']},
            {'step': 4, 'name_en': 'Apply Ethical Frameworks',
             'description_en': 'Analyze using multiple ethical perspectives',
             'questions': ['What would utilitarianism suggest?',
                           'What would deontology require?',
                           'What rights are at stake?']},
            {'step': 5, 'name_en': 'Evaluate Options',
             'description_en': 'Consider different approaches and their consequences',
             'questions': ['What are the alternative approaches?',
                           'What are the trade-offs?',
                           'What are the risks and benefits?']},
            {'step': 6, 'name_en': 'Make Decision',
             'description_en': 'Choose the most ethical course of action',
             'questions': ['Which option best balances ethical considerations?',
                           'Can the decision be justified?',
                           'Is it transparent and accountable?']},
        ]
        print("Framework created with 6 steps!")
        print("   Each step has guiding questions to help you think through ethical decisions")

    def analyze_scenario(self, scenario_name, scenario_data):
        """Walk through all 6 steps for one scenario, printing the analysis."""
        print(f"\n{'='*80}")
        print(f"ETHICAL ANALYSIS: {scenario_name}")
        print(f"{'='*80}")
        for step in self.steps:
            print(f"\nStep {step['step']}: {step['name_en']}")
            print("-" * 60)
            print(f"Description: {step['description_en']}")
            print("Key Questions:")
            for i, question in enumerate(step['questions'], 1):
                print(f"  {i}. {question}")
            if scenario_data and step['step'] in scenario_data:
                print("Analysis:")
                print(f"  {scenario_data[step['step']]}")

# Create framework instance to demonstrate
print("Creating framework instance...")
framework = EthicalDecisionFramework()
print("Framework ready to use!")
# Out:
# Creating framework instance...
# Framework created with 6 steps!
#    Each step has guiding questions to help you think through ethical decisions
# Framework ready to use!

# %% [markdown]
# ## Part 3: Visualizing the Framework
#
# ### 📚 Prerequisites (What You Need First)
# - ✅ **Framework defined** (from Part 2) - Understanding the 6-step framework
# - ✅ **Visualization libraries** (from Part 1) - Understanding matplotlib
#
# ### 🔗 Relationship: What This Builds On
# This builds on Part 2 - we now visualize the framework we created!
# - Builds on: Framework definition, matplotlib knowledge
# - Shows: How the 6 steps flow together
#
# ### 📖 The Story
# **Before visualization**: We have a framework but can't easily see the flow.
# **After visualization**: We can see the complete decision-making process as a flowchart!

# %%
# Step 3: Create decision-making flowchart visualization
# This shows the 6-step process as a visual flowchart

print("\n" + "="*80)
print("📊 CREATING DECISION-MAKING FLOWCHART")
print("="*80)

fig, ax = plt.subplots(figsize=(7.5, 9))
ax.set_xlim(2.6, 7.4)   # crop the empty margins so the boxes fill the picture
ax.set_ylim(0.6, 14)
ax.axis('off')

# Color code by role: green = start, blue = analysis steps, orange = judgment steps, purple = end.
# Color tells the reader which steps need human ethical judgment (orange) vs fact-gathering (blue).
start_color, process_color = '#2ecc71', '#3498db'
decision_color, end_color = '#f39c12', '#9b59b6'

# Lay out the boxes on an invisible grid: same x (centered column), decreasing y (top to bottom flow).
steps = [
    {'x': 5, 'y': 13,   'w': 2,   'color': start_color,    'text': 'Start'},
    {'x': 5, 'y': 11.5, 'w': 2.5, 'color': process_color,  'text': '1. Identify\nProblem'},
    {'x': 5, 'y': 10,   'w': 2.5, 'color': process_color,  'text': '2. Gather\nInformation'},
    {'x': 5, 'y': 8.5,  'w': 2.5, 'color': process_color,  'text': '3. Identify\nStakeholders'},
    {'x': 5, 'y': 7,    'w': 2.5, 'color': decision_color, 'text': '4. Apply Ethical\nFrameworks'},
    {'x': 5, 'y': 5.5,  'w': 2.5, 'color': decision_color, 'text': '5. Evaluate\nOptions'},
    {'x': 5, 'y': 4,    'w': 2.5, 'color': process_color,  'text': '6. Make\nDecision'},
    {'x': 5, 'y': 2.5,  'w': 2,   'color': end_color,      'text': 'End'},
]
H = 0.6  # box height
# Draw each step as a rounded box with its label - one patch + one text per step.
for s in steps:
    box = FancyBboxPatch((s['x'] - s['w']/2, s['y'] - H/2), s['w'], H,
                         boxstyle="round,pad=0.1", edgecolor='black',
                         facecolor=s['color'], linewidth=2, alpha=0.8)
    ax.add_patch(box)
    ax.text(s['x'], s['y'], s['text'], ha='center', va='center', fontsize=9,
            fontweight='bold',
            color='white' if s['color'] != '#f39c12' else 'black')
# Connect consecutive boxes with arrows so the eye follows the mandatory order of the process.
for i in range(len(steps) - 1):
    arrow = FancyArrowPatch((steps[i]['x'], steps[i]['y'] - H/2),
                            (steps[i+1]['x'], steps[i+1]['y'] + H/2),
                            arrowstyle='->', mutation_scale=20, linewidth=2,
                            color='black')
    ax.add_patch(arrow)
ax.set_title('Ethical Decision-Making Framework for AI',
             fontsize=14, fontweight='bold', pad=20)
# The colour code carries real information (which steps need human ethical judgment),
# so it must appear IN the figure and not only in these comments.
legend_handles = [
    mpatches.Patch(facecolor=start_color, edgecolor='black', label='Start / entry point'),
    mpatches.Patch(facecolor=process_color, edgecolor='black',
                   label='Fact-gathering step (what IS the case)'),
    mpatches.Patch(facecolor=decision_color, edgecolor='black',
                   label='Human ethical judgment (what OUGHT to be)'),
    mpatches.Patch(facecolor=end_color, edgecolor='black',
                   label='End / recorded decision'),
]
ax.legend(handles=legend_handles, loc='lower center', fontsize=8.5,
          ncol=2, framealpha=0.95, bbox_to_anchor=(0.5, -0.02))
plt.tight_layout()
plt.show()
print("Flowchart displayed - the 6 steps flow top to bottom from Start to End.")
print("Orange boxes (steps 4 and 5) are the two steps a human must judge;")
print("blue boxes are steps that can be answered with facts.")
# Out:
# ...
# 📊 CREATING DECISION-MAKING FLOWCHART
# ...
# Flowchart displayed - the 6 steps flow top to bottom from Start to End.
# Orange boxes (steps 4 and 5) are the two steps a human must judge;
# blue boxes are steps that can be answered with facts.

# %% [markdown]
# ### 👁️ Read the flowchart
#
# **What you should see.** Eight boxes in a single column, joined top to bottom by arrows,
# with a four-entry legend at the foot of the figure. The colour is not decoration: **blue
# steps (1, 2, 3, 6) are answerable with facts** — what the system does, what data it uses,
# who is affected — while the **two orange steps (4 "Apply Ethical Frameworks" and 5 "Evaluate
# Options") are the ones no fact settles**; a human has to judge them and put a name to the
# judgement.
#
# **What it proves.** The process does not remove the hard part. It **isolates** it: two steps
# out of six, clearly marked, where an argument is required. In Tempe the equivalent of steps 4
# and 5 was never performed by anyone with a name — which is exactly the failure the NTSB
# recorded as "inadequate safety culture".
#
# ---

# %% [markdown]
# ## Part 4: Applying the Framework
#
# ### 📚 Prerequisites (What You Need First)
# - ✅ **Framework defined** (from Part 2) - Understanding the 6-step framework
# - ✅ **Visualization created** (from Part 3) - Understanding the flow
#
# ### 🔗 Relationship: What This Builds On
# This shows how to actually USE the framework we created!
# - Builds on: Framework definition, visualization understanding
# - Shows: Real-world application to AI scenarios
#
# ### 📖 The Story
# **Before application**: We have a framework but haven't seen it used.
# **After application**: We'll analyze a real AI scenario step-by-step using our framework!

# %% [markdown]
# ## 🎯 Solving the Autonomous Vehicle Problem
#
# **Remember**: In the previous notebook, we saw that different frameworks gave different answers to the autonomous vehicle problem. Now let's use our **decision-making framework** to resolve this conflict!
#
# **The Problem**: Autonomous vehicle must choose between:
# - Option A: Swerve and hit wall (kill passenger)
# - Option B: Continue forward (kill pedestrians)
# - Option C: Try to minimize harm (risk both)
#
# **Framework Conflicts**:
# - Utilitarianism → Option A
# - Virtue Ethics → Option C
# - Deontology → No clear answer
# - Rights-Based → No clear answer
# - Care Ethics → Option C
#
# **How the Decision-Making Framework Solves This**: We'll go through all 6 steps systematically to resolve the conflict!

# %%
# Step 4: Solve the autonomous vehicle problem using the decision-making framework
# This demonstrates how the framework resolves framework conflicts

# Map step number -> our written analysis for that step of the framework.
# This is the 'filled-in worksheet' for the autonomous-vehicle dilemma from Notebook 1.
av_scenario = {
    1: "An autonomous vehicle must choose between options that all cause harm "
       "(hit wall / continue forward / swerve to minimize harm).",
    2: "Sensor data is reliable; outcomes are probabilistic. Passengers chose the "
       "vehicle; pedestrians did not choose the risk.",
    3: "Passenger, pedestrians, manufacturer, regulators, and society "
       "(future riders whose trust depends on this policy).",
    4: "Utilitarianism -> Option A (fewest total deaths). Virtue/Care Ethics -> "
       "Option C (responsible effort to protect everyone). Deontology and "
       "Rights-Based -> no option fully respects every duty/right.",
    5: "Option A minimizes expected deaths but sacrifices the passenger by design. "
       "Option B protects the passenger but ignores pedestrians. Option C spreads "
       "risk and reflects a defensible, careful policy.",
    6: "Choose Option C: it is justifiable to every stakeholder group, survives "
       "the transparency test (it can be published as policy), and balances the "
       "frameworks instead of letting one override the others."
}

# Walk the scenario through all 6 steps - the framework prints each step next to our analysis.
framework.analyze_scenario("Autonomous Vehicle Dilemma", av_scenario)

# Summarize the key teaching point: the process (not any single framework) broke the deadlock.
print("\n" + "="*80)
print("HOW THE FRAMEWORK RESOLVED THE CONFLICT")
print("="*80)
print("""
Individual frameworks disagreed (Unit 1, Notebook 1). The 6-step process
resolved the deadlock because it:
  1. Forced us to state the problem and gather facts BEFORE judging
  2. Surfaced ALL stakeholders (not just passenger vs pedestrians)
  3. Used the frameworks as inputs (Step 4), not as final verdicts
  4. Made the final decision explicit and justifiable (Step 6)
Decision reached: Option C, with a written justification we can defend.
""")
# Out:
# ...
# ETHICAL ANALYSIS: Autonomous Vehicle Dilemma
# ...
#
# Step 1: Identify the Problem
# ------------------------------------------------------------
# Description: Clearly define the ethical issue or dilemma
# Key Questions:
#   1. What is the AI system supposed to do?
#   2. What ethical concerns might arise?
#   3. Who are the stakeholders?
# Analysis:
#   An autonomous vehicle must choose between options that all cause harm (hit wall / continue forward / swerve to minimize harm).
#
# Step 2: Gather Information
# ------------------------------------------------------------
# Description: Collect relevant facts and context
# Key Questions:
#   1. What data will be used?
#   2. How will the system be deployed?
#   3. What are the potential impacts?
# Analysis:
#   Sensor data is reliable; outcomes are probabilistic. Passengers chose the vehicle; pedestrians did not choose the risk.
#
# Step 3: Identify Stakeholders
# ------------------------------------------------------------
# ...

# %% [markdown]
# ## 💬 Discuss
#
# The framework you just ran produced a documented recommendation for the hypothetical
# vehicle. Now point it at the crash that actually happened.
#
# 1. **Step 3 on a bystander.** Elaine Herzberg was not a passenger, not a customer, and
#    never agreed to be near that vehicle. Every stakeholder-weighting scheme in this notebook
#    counts people who are *in* the decision. How do you weight someone who is only ever a
#    bystander to it? And does your answer change if the technology eventually saves more
#    pedestrians than it kills — i.e. does it survive contact with Notebook 01's utilitarian
#    framework?
# 2. **Who signs the risky trade-off?** Uber disabled Volvo's emergency braking because it
#    interfered with testing: fewer false alarms and faster development, in exchange for
#    higher tail risk. That is a textbook Step 2 trade-off. Which step of *this* framework
#    should have caught it, which **job title** should have had to sign it — and be honest,
#    would your answer have survived a schedule slip three weeks before a demo?
# 3. **Does documentation increase or decrease accountability?** Suppose you follow all six
#    steps, document your reasoning, and someone is harmed anyway. Has the framework made you
#    *more* accountable — there is now a written record of exactly what you accepted — or
#    *less*, because you can point at a completed process? Argue both sides, then say which
#    risk you would personally rather run and why.

# %% [markdown]
# ## 🚫 When Decision-Making Framework Hits a Limitation
#
# ### The Limitation We Discovered
#
# We've learned how to use the decision-making framework to resolve framework conflicts. **But there's still a challenge:**
#
# **Theory is good, but how do we apply this to real-world AI systems?**
#
# The decision-making framework works well for:
# - ✅ Structured ethical dilemmas
# - ✅ Scenarios where we have all the information
# - ✅ Cases where we can go through all 6 steps systematically
#
# **But real-world AI ethics cases are often:**
# - Complex and messy
# - Have incomplete information
# - Involve multiple interconnected issues
# - Require analysis of actual deployed systems
#
# ### Why This Is a Problem
#
# When we try to apply our frameworks and decision-making process to real cases, we need:
# - **Real case studies** to practice on
# - **Experience** analyzing actual AI systems
# - **Understanding** of how ethical issues manifest in practice
#
# ### The Solution: Case Study Analysis
#
# We need to **analyze real-world AI ethics cases** to:
# 1. See how frameworks apply to actual problems
# 2. Practice using the decision-making framework on real cases
# 3. Learn from past ethical failures
# 4. Build skills for analyzing future AI systems
#
# **This is exactly what we'll do in the next notebook: Case Study Analysis!**
#
# ---
#
# ## ➡️ Next Steps
#
# **You've completed this notebook!** Now you understand:
# - ✅ How to use the decision-making framework
# - ✅ How to resolve framework conflicts
# - ✅ **The limitation**: Theory needs real-world application!
#
# **Next notebook**: `03_case_study_analysis.ipynb`
# - Analyze real-world AI ethics case (COMPAS)
# - Apply frameworks and decision-making to actual problems
# - Learn from past ethical failures

# %% [markdown]
# ## ⚠️ Where this breaks
#
# **The assumption that has to hold:** that you have time, information, and the authority to
# act on the conclusion. Three places the six-step process fails.
#
# - **Real-time decisions.** The car had 5.6 seconds and no ethics board. Anything this
#   framework decides must be pre-computed and compiled in long beforehand. If your process
#   cannot produce a **rule** — not a deliberation — it cannot govern a system operating at
#   60 km/h, and pretending otherwise is worse than admitting it.
# - **When the uncertainty is in the inputs.** Step 2 says "gather information". Uber's
#   perception stack did not know what it was looking at; more careful reasoning about the
#   *outputs* would not have helped. When the doubt lives in the sensing, the fix is
#   instrumentation and a conservative default, not deliberation.
# - **When the process becomes the product.** A completed six-step document is easy to write
#   and easy to file. The Dutch childcare-benefits administration (Unit 4, Notebook 04) had
#   procedures too, and still wrongly accused about **26,000 families**. A process creates
#   accountability only when a named person signs it and someone with authority reads it.
# - **When the framework has no teeth.** This notebook produces a recommendation. It has no
#   mechanism to stop a launch. If the ethics review cannot say *no* and be obeyed, it is
#   documentation, not governance — which is why Unit 5 spends its time on who holds the veto.
#
# **The cheaper alternative:** for repeated, low-stakes decisions, skip the six steps and
# write a **standing rule plus an escalation trigger** ("defer to a human whenever X"), then
# audit the trigger for disparate impact. That is what Unit 4's HITL notebook builds, and it
# is the kind of artefact that would have kept a disabled emergency-braking system from
# shipping.

# %% [markdown]
# ## 🔭 State of the field (2026)
#
# *Context, not examinable content — the official unit examines the six-step process above, exactly as it is taught. This box says where that process sits on the 2026 map.*
#
# The six steps are still the skeleton of every serious AI risk process; what 2024–2026 added is a standard **shape** for the document they produce. A developer is now expected to assemble a **safety case** — a structured rationale, backed by evidence, that a particular system is unlikely to cause a catastrophe, written *before* deployment rather than reconstructed afterwards by an accident investigator (Clymer *et al.*, 2024). The risk analysis feeding it has become a published, versioned artifact too: *Frontier AI Risk Management Framework in Practice* reached **v1.5** in February 2026, assessing five named dimensions — cyber offense, persuasion and manipulation, strategic deception, uncontrolled AI R&D, and self-replication — proposing mitigations for each, and being re-issued as the models it describes change (Liu *et al.*, 2026). Neither artifact replaces what you built here, because both still need precisely what Steps 1–6 produce: named stakeholders, stated alternatives, a recorded decision, and a person who signs it. That is why this process is the thing to learn — a safety case is this notebook's output with an evidence standard attached and a version number on the front, and the signed record the NTSB could not find at Uber ATG is still the missing input, not the missing template.
#
# **Read:** Clymer *et al.* (2024), <https://arxiv.org/abs/2403.10462> · Liu *et al.* (2026), <https://arxiv.org/abs/2602.14457> (references 5–6 below).
#
# ---

# %% [markdown]
# ## 📚 References
#
# 1. Foot, P. (1967). *The Problem of Abortion and the Doctrine of Double Effect*. Oxford Review, 5. (origin of the trolley problem used in this notebook)
# 2. Awad, E., Dsouza, S., Kim, R., et al. (2018). *The Moral Machine Experiment*. Nature, 563, 59–64. <https://doi.org/10.1038/s41586-018-0637-6>
# 3. Hendrycks, D., Burns, C., Basart, S., et al. (2021). *Aligning AI With Shared Human Values*. ICLR 2021. <https://arxiv.org/abs/2008.02275>
# 4. Russell, S. & Norvig, P. (2021). *Artificial Intelligence: A Modern Approach* (4th ed.), Ch. 27. Pearson.
# 5. Clymer, J., Gabrieli, N., Krueger, D., & Larsen, T. (2024). *Safety Cases: How to Justify the Safety of Advanced AI Systems*. arXiv preprint. <https://arxiv.org/abs/2403.10462> (the standard shape of the document this notebook's six steps produce: a structured, evidence-backed rationale written before deployment)
# 6. Liu, D., Yu, Y., Zhang, J., Chen, G., Lin, Q., Zhu, H., et al. (2026). *Frontier AI Risk Management Framework in Practice: A Risk Analysis Technical Report v1.5*. arXiv preprint. <https://arxiv.org/abs/2602.14457> (a published, versioned risk analysis assessing five named risk dimensions and proposing mitigations for each)
