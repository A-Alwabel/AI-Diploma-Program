# %% [markdown]
# # Unit 4: Interpretability, Transparency, and Accountability

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - The **real Titanic passenger manifest** (`load("titanic")`,
#   891 real people, 177 genuinely missing ages) - the same data the Unit 4
#   examples explain, so you can check your answers against Notebooks 01-02.
#
# **Outputs:** What you'll see when you run the cells
#
# - Your own SHAP and LIME explanations for a model trained on real people, plus a
#   written comparison of what the two methods say about the same passenger.
#
# ---

# %%
# --- Data setup. Works from any folder, and on Google Colab. -------------------------
# WHAT: find the repository root and put it on sys.path, then import the shared loader.
# WHY:  a hard-coded '../../../Course 04/datasets/raw/titanic.csv' only resolves when the
#       kernel's working directory happens to be this notebook's folder. This does not care.
import sys, pathlib

_here = pathlib.Path.cwd().resolve()
_root = next((p for p in [_here, *_here.parents] if (p / "tools" / "data.py").exists()), None)
if _root is None:                     # Google Colab, or a stray copy of the notebook
    import urllib.request
    pathlib.Path("tools").mkdir(exist_ok=True)
    try:
        urllib.request.urlretrieve(
            "https://raw.githubusercontent.com/A-Alwabel/"
            "AI-Diploma-Program/main/tools/data.py", "tools/data.py")
    except Exception as _e:
        raise RuntimeError(
            "Could not find the AI Diploma repository from this folder, and could not "
            "download the data loader either. Open this notebook inside a clone of "
            "https://github.com/A-Alwabel/AI-Diploma-Program, or connect to the internet "
            f"and re-run this cell. (underlying error: {_e})") from None
    _root = pathlib.Path.cwd()
sys.path.insert(0, str(_root))

from tools.data import load        # load("titanic"), load("creditcard_fraud"), ...
# -------------------------------------------------------------------------------------
print("Data loader ready - datasets are loaded by NAME, never by file path.")

# %%
# Exercise template: implement SHAP and LIME explanations yourself.
# Why: writing the explanation code (not just reading it) is how the XAI workflow sticks.

"""
Unit 4: Interpretability, Transparency, and Accountability
Exercise 1: SHAP and LIME Explanations on REAL Data

You explain a model trained on the real Titanic manifest - 891 real people, a
real recorded outcome. No synthetic data anywhere in this exercise.

That raises the bar in a useful way: with invented data you know the true rule
you built in, so any explanation that recovers it looks good. With real data
nobody knows the true rule, so you have to judge explanations the way a
practitioner does - by cross-checking methods and against what you know about
the situation.
"""

import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score

# ============================================================================
# TASK 1: Load the real data and train the model you will explain
# ============================================================================

def load_real_dataset():
    """
    TODO: Load the real Titanic manifest and build the features to explain.

    Requirements:
    - Get the manifest with `load("titanic")` - the shared loader finds the file
      from any working directory, so you never write a path
    - Handle the REAL missing values honestly: `Age` has 177 missing and
      `Embarked` has 2. Impute them (median / mode) and be ready to say so -
      an imputed value that later shows up in an explanation is YOUR value,
      not the passenger's.
    - Build numeric features: Pclass, Age, SibSp, Parch, Fare, is_female
    - Return (X, y) where y is `Survived`
    """
    # TODO: Your code here
    # Hint: df['Age'] = df['Age'].fillna(df['Age'].median())
    # Hint: (df['Sex'] == 'female').astype(float)
    pass

def train_model(X, y):
    """
    TODO: Split the data and train the classifier you will explain.

    Requirements:
    - train_test_split with stratify=y and a fixed random_state
    - Fit a RandomForestClassifier
    - Print the test accuracy - an explanation of a bad model explains nothing
    - Return (model, X_train, X_test, y_train, y_test)
    """
    # TODO: Your code here
    pass

# ============================================================================
# TASK 2: SHAP - additive attributions (see examples/01 for the pattern)
# ============================================================================

def calculate_shap_values(model, X_test):
    """
    TODO: Calculate SHAP values for the test passengers.

    Requirements:
    - Use shap.TreeExplainer for this tree model
    - Reduce to the "survived" class (shap versions differ - handle list/3-D)
    - Print the global ranking (mean |SHAP| per feature)
    - Return the SHAP value matrix

    Then answer in a comment: which feature comes out on top, and is it a
    protected attribute? What does that mean for deploying such a system?
    """
    # TODO: Your code here
    pass

# ============================================================================
# TASK 3: LIME - a local surrogate around one instance (see examples/02)
# ============================================================================

def calculate_lime_explanation(model, X_train, X_test, index=0):
    """
    TODO: Explain ONE real passenger's prediction with LIME.

    Requirements:
    - Build a LimeTabularExplainer over X_train
    - Explain the passenger at `index` of X_test
    - Print the model's predicted probability and the LIME weights
    - Return the explanation object
    """
    # TODO: Your code here
    pass

# ============================================================================
# TASK 4: Compare the two explanations honestly
# ============================================================================

def compare_methods(shap_values, lime_explanation, X_test, index=0):
    """
    TODO: Put SHAP and LIME side by side for the SAME passenger.

    Requirements:
    - Print both local rankings
    - Count how many positions of the ranking agree
    - State plainly where they disagree - do NOT smooth it over

    Then answer in a comment: if the two methods disagree about why this real
    person was scored the way they were, what would you tell that person?
    """
    # TODO: Your code here
    pass

# Runner: prints instructions until you fill in the TODOs above.
if __name__ == "__main__":
    print("="*80)
    print("Unit 4 - Exercise 1: SHAP and LIME Explanations on Real Data")
    print("="*80)

    data = load_real_dataset()
    if data is None:
        print("\nload_real_dataset() is not implemented yet - start with Task 1.")
    print("\nComplete the TODO sections in this file.")
    print("="*80)
# Out:
# ...
# Unit 4 - Exercise 1: SHAP and LIME Explanations on Real Data
# ...
#
# load_real_dataset() is not implemented yet - start with Task 1.
#
# Complete the TODO sections in this file.
# ...
