# %% [markdown]
# # Unit 5: AI Governance, Regulations, and Future Challenges

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Exercise template: analyze AI regulations yourself (see examples/01-02 for models).
# Why: regulation reading is a working skill - map each rule to a concrete system duty.

"""
Unit 5: AI Governance, Regulations, and Future Challenges
Exercise 1: Regulations

This exercise requires you to analyze AI regulations.
"""

# TODO: Complete the exercise
if __name__ == "__main__":
    print("="*80)
    print("Unit 5 - Exercise 1: Regulations")
    print("="*80)
    print("\nComplete the TODO sections in this file.")
    print("="*80)
# Out:
# ================================================================================
# Unit 5 - Exercise 1: Regulations
# ================================================================================
#
# Complete the TODO sections in this file.
# ================================================================================
