# %% [markdown]
# # Unit 1 - Exercise 1: Data Processing Practice
#
# # Instructions:
# # 1. Load the sample dataset provided below
# # 2. Explore the data (shape, info, statistics)
# # 3. Handle missing values appropriately
# # 4. Remove any duplicates
# # 5. Create visualizations (at least 2 different plots)

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Import the analysis toolkit: pandas/numpy handle the data,
# matplotlib/seaborn draw the plots you will use to explore it.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Dataset:** Sales data for a retail store

# %%
# Build a reproducible fake sales table to practice exploration on.
# WHY: a fixed seed (42) means everyone generates the SAME numbers,
# so your answers can be checked against the solution.
# Sample dataset - Sales data
np.random.seed(42)
data = { 'product_id': range(1, 101), 'product_name': [f'Product_{i}' for i in range(1, 101)], 'category': np.random.choice(['Electronics', 'Clothing', 'Food', 'Books', 'Sports'], 100), 'price': np.random.uniform(10, 500, 100), 'quantity_sold': np.random.randint(10, 1000, 100), 'customer_rating': np.random.uniform(1, 5, 100), 'month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 100)}
df = pd.DataFrame(data)

# %% [markdown]
# Introduce some missing values and duplicates for exercise

# %%
df.loc[10:15, 'customer_rating'] = np.nan
df.loc[5:7, 'price'] = np.nan
df = pd.concat([df, df.iloc[[0, 1, 2]]], ignore_index=True)

# %% [markdown]
# TODO: Write your code here

# %% [markdown]
# ## Task 1: Load and explore the data

# %%
print("Task 1: Explore the data")
# Your code here...
# Out:
# Task 1: Explore the data

# %% [markdown]
# ## Task 2: Handle missing values

# %%
print("Task 2: Handle missing values")
# Your code here...
# Out:
# Task 2: Handle missing values

# %% [markdown]
# ## Task 3: Remove duplicates

# %%
print("Task 3: Remove duplicates")
# Your code here...
# Out:
# Task 3: Remove duplicates

# %% [markdown]
# ## Task 4: Create visualizations

# %%
print("Task 4: Create visualizations")
# Your code here...
print("Exercise 1 Complete!")
# Out:
# Task 4: Create visualizations
# Exercise 1 Complete!
