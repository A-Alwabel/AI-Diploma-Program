# %% [markdown]
# # Unit 1 - Exercise 1: Data Processing Practice
#
# **Dataset:** the real Montgomery County (PA) 911 dispatch log, loaded with
# `load("montgomery_911_calls")` — no file path, and it works on Colab too. We take the
# first 5,000 rows of the 25,000-row sample that ships with the repository. Its missing
# values are genuine: 634 of these 5,000 calls have no ZIP code recorded and two have no
# township. Nobody added those gaps for this exercise.
#
# **About duplicates.** The full 663,522-row log does contain duplicate rows — the same
# call written twice. The bundled sample keeps one row in every 27, so a duplicate pair
# only survives if *both* copies land on that stride, and none does: **this slice has 0
# exact duplicates.** Task 3 still matters. Checking and finding none is a result you write
# down; assuming none is the mistake. (Download the full file — see
# `Course 04/datasets/DATA.md` — and the first 5,000 rows hold 14 of them.)
#
# # Instructions:
# # 1. Load the real dataset provided below
# # 2. Explore the data (shape, info, statistics)
# # 3. Handle missing values appropriately
# # 4. Remove any duplicates
# # 5. Create visualizations (at least 2 different plots)

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# --- Data setup. Works from any folder, and on Google Colab. -------------------------
# WHAT: find the repository root, put it on sys.path, then import the shared data loader.
# WHY:  a hard-coded relative path such as ../../datasets/raw/<file>.csv only resolves when
#       the kernel's working directory happens to be this notebook's folder. Open it from the
#       repository root, from JupyterLab at another level, or on Colab where there is no
#       repository at all, and it breaks. load() finds the data wherever you are, downloads
#       it if this machine has none, and says out loud which copy it used.
import sys, pathlib

_here = pathlib.Path.cwd().resolve()
_root = next((p for p in [_here, *_here.parents] if (p / "tools" / "data.py").exists()), None)
if _root is None:                     # Google Colab, or a stray copy of the notebook
    import urllib.request
    pathlib.Path("tools").mkdir(exist_ok=True)
    try:
        urllib.request.urlretrieve(
            "https://raw.githubusercontent.com/A-Alwabel/"
            "AI-Diploma-Program/main/tools/data.py", "tools/data.py")
    except Exception as _e:
        raise RuntimeError(
            "Could not find the AI Diploma repository from this folder, and could not "
            "download the data loader either. Open this notebook inside a clone of "
            "https://github.com/A-Alwabel/AI-Diploma-Program, or connect to the internet "
            f"and re-run this cell. (underlying error: {_e})") from None
    _root = pathlib.Path.cwd()
sys.path.insert(0, str(_root))

from tools.data import load        # load("titanic"), load("creditcard_fraud", prefer="sample"), ...
# -------------------------------------------------------------------------------------
print("Data loader ready - no file paths needed, and this works on Colab too.")
# Out:
# Data loader ready - no file paths needed, and this works on Colab too.

# %%
# Import the analysis toolkit: pandas/numpy handle the data,
# matplotlib/seaborn draw the plots you will use to explore it.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# **Dataset:** Real 911 emergency dispatch records (Montgomery County, PA)

# %%
# Load a REAL, messy dataset to practise exploration on.
# WHY: this dispatch log arrives with genuine missing values (many calls have no ZIP
# recorded) and genuine duplicate rows (the same call logged twice) — the exact defects
# you are about to learn to find. Nothing below was injected for the exercise.
# prefer="sample" reads the 25,000-row extract that ships with the repository, so this runs
# on any machine and on Colab, and everyone finds the same defects in the same rows.
df = load(
    "montgomery_911_calls", prefer="sample",
    usecols=["lat", "lng", "zip", "title", "timeStamp", "twp", "addr"],
).head(5000)             # the first 5,000 rows, so the notebook stays fast

# Split the free-text "title" into its two real parts: the category before the colon
# (EMS / Fire / Traffic) and the specific emergency type after it.
df["category"] = df["title"].str.split(":").str[0]
df["emergency_type"] = df["title"].str.split(": ").str[1].str.strip()

print("Real dataset loaded from the county dispatch log.")
# Out:
# montgomery_911_calls: bundled 25,000-row sample of the 663,522-row original (the full file is on this machine but was not used, because prefer='sample') — every number below is for the sample, not the full file. How it was drawn: 1 row in every 27, evenly spread, so the sample covers the same 2015-12-10 to 2020-07-29 window with all 100 call types and 68 townships.
# Real dataset loaded from the county dispatch log.

# %% [markdown]
# The defects are already there — go and find them
#
# Run the cell below to see what the real data hands you before you touch it.

# %%
# Show the defects the REAL data already contains. You do not need to create any.
print("Missing values per column (all real — these facts were never recorded):")
print(df.isna().sum())
print()
# WHY print this even when it is 0: "we checked, and there were none" is a finding.
# "we assumed there were none" is how a duplicated row reaches a model.
print(f"Fully duplicated rows (the same call logged twice): {df.duplicated().sum()}")
print()
print("Call categories present:")
print(df["category"].value_counts())
# Out:
# Missing values per column (all real — these facts were never recorded):
# lat                 0
# lng                 0
# zip               634
# title               0
# timeStamp           0
# twp                 2
# addr                0
# category            0
# emergency_type      0
# dtype: int64
#
# Fully duplicated rows (the same call logged twice): 0
#
# Call categories present:
# category
# EMS        2443
# Traffic    1805
# Fire        752
# Name: count, dtype: int64

# %% [markdown]
# TODO: Write your code here

# %% [markdown]
# ## Task 1: Load and explore the data

# %%
print("Task 1: Explore the data")
# Your code here...
# Out:
# Task 1: Explore the data

# %% [markdown]
# ## Task 2: Handle missing values

# %%
print("Task 2: Handle missing values")
# Your code here...
# Out:
# Task 2: Handle missing values

# %% [markdown]
# ## Task 3: Remove duplicates
#
# The cell above already told you how many there are in this slice. Write the
# `drop_duplicates()` step anyway, print the row count before and after, and state in one
# line what you found — including if the answer is "none".

# %%
print("Task 3: Remove duplicates")
# Your code here...
# Out:
# Task 3: Remove duplicates

# %% [markdown]
# ## Task 4: Create visualizations

# %%
print("Task 4: Create visualizations")
# Your code here...
print("Exercise 1 Complete!")
# Out:
# Task 4: Create visualizations
# Exercise 1 Complete!
