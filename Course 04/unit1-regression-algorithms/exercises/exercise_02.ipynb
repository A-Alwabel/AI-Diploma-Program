# %% [markdown]
# # Unit 1 - Exercise 2: Linear Regression Practice
#
# # Instructions:
# # 1. Create a simple linear regression model to predict house prices based on size
# # 2. Evaluate the model using appropriate metrics
# # 3. Visualize the results
# # 4. Make predictions for new data points
#
# # Use the provided dataset

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Import the regression toolkit: data handling, the LinearRegression model,
# a train/test splitter, and the three error metrics you will report.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, mean_absolute_error, r2_score

# %%
# Generate sample housing data
np.random.seed(42)
# Prices follow a KNOWN line (45*size + 80000) plus noise - so you can check what the model recovers.
house_sizes = np.random.uniform(800, 4000, 150)
house_prices = 45 * house_sizes + 80000 + np.random.normal(0, 35000, 150)

df = pd.DataFrame({
    'size': house_sizes,
    'price': house_prices
})

print("Dataset Info:")
print(f"Shape: {df.shape}")
print(df.head())
# Out:
# Dataset Info:
# Shape: (150, 2)
#           size          price
# 0  1998.528380  163201.143347
# 1  3842.285781  263457.017105
# 2  3142.380614  220192.215681
# 3  2715.707149  161303.090408
# 4  1299.259649  178465.482732

# %% [markdown]
# TODO: Write your code here

# %% [markdown]
# ## Task 1: Split the data into train and test sets (80/20)

# %%
print("\nTask 1: Split data")
# Your code here...
# Out:
# Task 1: Split data

# %% [markdown]
# ## Task 2: Create and train a Linear Regression model

# %%
print("\nTask 2: Train Linear Regression model")
# Your code here...
# Out:
# Task 2: Train Linear Regression model

# %% [markdown]
# ## Task 3: Make predictions and evaluate the model

# %%
print("\nTask 3: Evaluate model")
# Your code here...
# Out:
# Task 3: Evaluate model

# %% [markdown]
# ## Task 4: Visualize the results

# %%
print("\nTask 4: Visualize results")
# Your code here...
# Out:
# Task 4: Visualize results

# %% [markdown]
# ## Task 5: Make predictions for new house sizes: [1000, 2000, 3000]

# %%
# Task 5 stub: use your trained model to predict prices for three new house sizes.
print("\nTask 5: Predict for new sizes")
new_sizes = [[1000], [2000], [3000]]
# Your code here...

print("\nExercise 2 Complete!")
# Out:
# Task 5: Predict for new sizes
#
# Exercise 2 Complete!
