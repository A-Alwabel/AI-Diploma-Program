# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Unit 4 - Exercise 1: Clustering Practice# التجميع وتقليل الأبعاد - تمرين 1: ممارسة التجميع# Instructions:# 1. Load the provided dataset# 2. Apply K-Means clustering with different K values# 3. Use the Elbow Method to find optimal K# 4. Apply Hierarchical clustering# 5. Visualize the clusters# 6. Compare results

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Complete solution:
# """Unit 4 - Exercise 1: Clustering Practiceالتجميع وتقليل الأبعاد - تمرين 1: ممارسة التجميعInstructions:1. Load the provided dataset2. Apply K-Means clustering with different K values3. Use the Elbow Method to find optimal K4. Apply Hierarchical clustering5. Visualize the clusters6. Compare result s"""

# %%
# Generate sample datanp.random.seed(42)
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))

# %% [markdown]
# TODO: Write your code here# TODO: اكتب الكود الخاص بك هنا

# %% [markdown]
# ## Task 1: Scale the data

# %% [markdown]
# Complete solution:
# print("\nTask 1: Scale data")# Your code here...

# %% [markdown]
# ## Task 2: Apply K-Means with K

# %% [markdown]
# Complete solution:

# %%
print("\nTask 2: K-Means (K=3)")# Your code here...

# %% [markdown]
# ## Task 3: Elbow Method to find optimal K

# %% [markdown]
# Complete solution:
# print("\nTask 3: Elbow Method")# Your code here...

# %% [markdown]
# ## Task 4: Apply Hierarchical Clustering

# %% [markdown]
# Complete solution:
# print("\nTask 4: Hierarchical Clustering")# Your code here...

# %% [markdown]
# ## Task 5: Visualize clusters

# %%
# Complete solution:
# print("\nTask 5: Visualize")
# Your code here...print("\nExercise 1 Complete!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
# Out:
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
# اكتمل التمرين 1!

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
