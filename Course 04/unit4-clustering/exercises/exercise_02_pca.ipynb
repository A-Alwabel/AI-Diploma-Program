# %% [markdown]
# # Unit 4 - Exercise 2: Principal Component Analysis (PCA) Practice
#
# # Instructions:
# # 1. Load the provided dataset
# # 2. Apply PCA to reduce dimensionality
# # 3. Analyze explained variance
# # 4. Choose optimal number of components
# # 5. Visualize data in reduced dimensions
# # 6. Compare original vs PCA-transformed data

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Import the PCA toolkit: the PCA transformer, a scaler (PCA is
# scale-sensitive!), and the classic Iris dataset to practice on.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.datasets import load_iris

# %% [markdown]
# Load the Iris dataset (4 features, 3 classes) - small and perfect for practicing PCA

# %%
# Load Iris dataset (4 features, 3 classes)
iris = load_iris()
X = iris.data
y = iris.target
feature_names = iris.feature_names

df = pd.DataFrame(X, columns=feature_names)
df['target'] = y

print("Dataset loaded!")
print(f"Shape: {df.shape}")
print(f"Features: {feature_names}")
print("\nClass distribution:")
print(df['target'].value_counts())
# Out:
# Dataset loaded!
# Shape: (150, 5)
# Features: ['sepal length (cm)', 'sepal width (cm)', 'petal length (cm)', 'petal width (cm)']
#
# Class distribution:
# target
# 0    50
# 1    50
# 2    50
# Name: count, dtype: int64

# %% [markdown]
# TODO: Write your code here

# %% [markdown]
# ## Task 1: Scale the data (CRITICAL for PCA!)
#
# - Use `StandardScaler` so every feature has mean 0 and std 1

# %%
print("Task 1: Scale data")
# Your code here...
# Out:
# Task 1: Scale data

# %% [markdown]
# ## Task 2: Apply PCA with all components
#
# - Create a `PCA()` object (no `n_components` = keep all 4)
# - Fit and transform the scaled data

# %%
print("Task 2: Apply PCA (all components)")
# Your code here...
# Out:
# Task 2: Apply PCA (all components)

# %% [markdown]
# ## Task 3: Analyze explained variance
#
# - Get `explained_variance_ratio_` for each component
# - Calculate the cumulative explained variance
# - Print each component's variance and the cumulative variance

# %%
print("Task 3: Explained variance analysis")
# Your code here...
# Out:
# Task 3: Explained variance analysis

# %% [markdown]
# ## Task 4: Visualize explained variance
#
# - Plot: component number vs explained variance (bar or line)
# - Plot: component number vs cumulative explained variance

# %%
print("Task 4: Visualize explained variance")
# Your code here...
# Out:
# Task 4: Visualize explained variance

# %% [markdown]
# ## Task 5: Reduce to 2D for visualization
#
# - Apply `PCA(n_components=2)` and transform the scaled data
# - Scatter-plot the 2D data, colored by the original class labels

# %%
print("Task 5: Reduce to 2D")
# Your code here...
# Out:
# Task 5: Reduce to 2D

# %% [markdown]
# ## Task 6: Find the optimal number of components
#
# - How many components explain 95% of the variance?
# - How many explain 99%?

# %%
print("Task 6: Find optimal number of components")
# Your code here...
# Out:
# Task 6: Find optimal number of components

# %% [markdown]
# ## Task 7: Compare original vs PCA-transformed data
#
# - Show that the original data has 4 features while PCA can reduce it to 2-3
# - Show that PCA preserves most of the information with fewer features

# %%
print("Task 7: Compare original vs PCA")
# Your code here...

print("Exercise 2 Complete!")
# Out:
# Task 7: Compare original vs PCA
# Exercise 2 Complete!
