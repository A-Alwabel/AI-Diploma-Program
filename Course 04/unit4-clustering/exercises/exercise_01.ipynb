# %% [markdown]
# # Unit 4 - Exercise 1: Clustering Practice
#
# **The data:** real US state crime statistics — the 50 states, each with four measured
# rates from the 1973 Uniform Crime Reports (`../../datasets/raw/crime_statistics_original_50.csv`).
# There are no "true" clusters printed anywhere in this file: whatever grouping you find,
# you will have to argue for it from the silhouette score and from what the states in each
# group have in common. That is what clustering is actually like.
#
# # Instructions:
# # 1. Load the provided dataset (done for you in the cell below)
# # 2. Apply K-Means clustering with different K values
# # 3. Use the Elbow Method to find optimal K
# # 4. Apply Hierarchical clustering
# # 5. Visualize the clusters
# # 6. Compare results

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - `../../datasets/raw/crime_statistics_original_50.csv` — the real USArrests table:
#   50 US states, with Murder, Assault and Rape arrests per 100,000 residents plus the
#   percentage of the population living in urban areas
#
# **Outputs:** What you'll see when you run the cells
#
# - Your own clustering of the 50 states, an elbow plot, a silhouette score, and a
#   scatter plot of the groups you found.
#
# ---

# %%
# --- Data setup. Works from any folder, and on Google Colab. -------------------------
# WHAT: find the repository root, put it on sys.path, then import the shared data loader.
# WHY:  a hard-coded relative path such as ../../datasets/raw/<file>.csv only resolves when
#       the kernel's working directory happens to be this notebook's folder. Open it from the
#       repository root, from JupyterLab at another level, or on Colab where there is no
#       repository at all, and it breaks. load() finds the data wherever you are, downloads
#       it if this machine has none, and says out loud which copy it used.
import sys, pathlib

_here = pathlib.Path.cwd().resolve()
_root = next((p for p in [_here, *_here.parents] if (p / "tools" / "data.py").exists()), None)
if _root is None:                     # Google Colab, or a stray copy of the notebook
    import urllib.request
    pathlib.Path("tools").mkdir(exist_ok=True)
    try:
        urllib.request.urlretrieve(
            "https://raw.githubusercontent.com/A-Alwabel/"
            "AI-Diploma-Program/main/tools/data.py", "tools/data.py")
    except Exception as _e:
        raise RuntimeError(
            "Could not find the AI Diploma repository from this folder, and could not "
            "download the data loader either. Open this notebook inside a clone of "
            "https://github.com/A-Alwabel/AI-Diploma-Program, or connect to the internet "
            f"and re-run this cell. (underlying error: {_e})") from None
    _root = pathlib.Path.cwd()
sys.path.insert(0, str(_root))

from tools.data import load        # load("titanic"), load("creditcard_fraud", prefer="sample"), ...
# -------------------------------------------------------------------------------------
print("Data loader ready - no file paths needed, and this works on Colab too.")
# Out:
# Data loader ready - no file paths needed, and this works on Colab too.

# %%
# Import the clustering toolkit: two clusterers (K-Means, Agglomerative),
# a scaler, and the silhouette score you will use to judge cluster quality.
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.cluster import KMeans, AgglomerativeClustering
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score

# %%
# Load the REAL dataset: 50 US states, four crime/urbanisation measurements each.
# WHY it needs scaling (Task 1): Assault runs from 45 to 337 while Murder runs from 0.8
# to 17.4, so an unscaled distance is almost entirely a distance in Assault.
df = load("crime_statistics_original_50")

feature_cols = ["Murder", "Assault", "UrbanPop", "Rape"]
X = df[feature_cols].to_numpy(dtype=float)
state_names = df["State"].to_numpy()

print("Dataset loaded!")
print(f"Shape: {df[feature_cols].shape}  (rows = US states, columns = {feature_cols})")
print(f"Missing values: {int(df[feature_cols].isna().sum().sum())}")
print("\nRange of each column BEFORE scaling:")
print(df[feature_cols].agg(["min", "max"]).round(1).to_string())
print("\nFirst 5 states:")
print(df.head().to_string(index=False))
# Out:
# crime_statistics_original_50: full file, 50 rows.
# Dataset loaded!
# Shape: (50, 4)  (rows = US states, columns = ['Murder', 'Assault', 'UrbanPop', 'Rape'])
# Missing values: 0
#
# Range of each column BEFORE scaling:
#      Murder  Assault  UrbanPop  Rape
# min     0.8       45        32   7.3
# max    17.4      337        91  46.0
#
# First 5 states:
#  Murder  Assault  UrbanPop  Rape      State
#    13.2      236        58  21.2    Alabama
#    10.0      263        48  44.5     Alaska
#     8.1      294        80  31.0    Arizona
#     8.8      190        50  19.5   Arkansas
#     9.0      276        91  40.6 California

# %% [markdown]
# ## Task 1: Scale the data
#
# Use `StandardScaler` on `X`. Then print the mean and standard deviation of each scaled
# column and confirm they are ~0 and ~1. Ask yourself: which state moved the most, and why?

# %%
print("Task 1: Scale data")
# Your code here...
# Out:
# Task 1: Scale data

# %% [markdown]
# ## Task 2: Apply K-Means with K=3
#
# Fit `KMeans(n_clusters=3, n_init=10, random_state=42)` on the SCALED data, print how many
# states landed in each cluster, and print the state names in each cluster. Do the groups
# mean anything to you?

# %%
print("Task 2: K-Means (K=3)")
# Your code here...
# Out:
# Task 2: K-Means (K=3)

# %% [markdown]
# ## Task 3: Elbow Method to find optimal K
#
# Fit K-Means for K = 1..10, collect `kmeans.inertia_`, and plot inertia against K. Also
# print the `silhouette_score` for K = 2..10. Real data rarely gives a sharp elbow — say
# honestly which K you would pick and what the two curves disagree about, if they do.

# %%
print("Task 3: Elbow Method")
# Your code here...
# Out:
# Task 3: Elbow Method

# %% [markdown]
# ## Task 4: Apply Hierarchical Clustering
#
# Fit `AgglomerativeClustering(n_clusters=3)` on the same scaled data and compare its
# labels with the K-Means labels using `pd.crosstab`. Which states do the two methods
# disagree about?

# %%
print("Task 4: Hierarchical Clustering")
# Your code here...
# Out:
# Task 4: Hierarchical Clustering

# %% [markdown]
# ## Task 5: Visualize clusters
#
# Scatter `Murder` against `Assault` (unscaled, so the axes are readable), colour the
# points by cluster, and label a few states with `plt.annotate`. One sentence per cluster:
# what kind of state is in it?

# %%
print("Task 5: Visualize")
# Your code here...

print("Exercise 1 Complete!")
# Out:
# Task 5: Visualize
# Exercise 1 Complete!
