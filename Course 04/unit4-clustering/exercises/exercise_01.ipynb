# %% [markdown]
# # Unit 4 - Exercise 1: Clustering Practice
# # التجميع وتقليل الأبعاد - تمرين 1: ممارسة التجميع
#
# # Instructions:
# # 1. Load the provided dataset
# # 2. Apply K-Means clustering with different K values
# # 3. Use the Elbow Method to find optimal K
# # 4. Apply Hierarchical clustering
# # 5. Visualize the clusters
# # 6. Compare results

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as pltf

# %% [markdown]
# Unit 4 - Exercise 1: Clustering Practiceالتجميع وتقليل الأبعاد - تمرين 1: ممارسة التجميعI_nstructions: 1. Load the provided dataset2. Apply K-Means clustering with different K values3. Use the Elbow Method to find optimal K4. Apply Hierarchical clustering
# 5. Visualize the clusters6. Compare results

# %%
# Generate sample data
np.random.seed(42)
np.random.seed(42)
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster1 = np.random.normal([2, 2], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 =  np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster2 = np.random.normal([6, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))
cluster3 =  np.random.normal([2, 6], 0.6, (80, 2))

# %% [markdown]
# TODO: Write your code here# TODO: اكتب الكود الخاص بك هنا

# %% [markdown]
# ## Task 1: Scale the data

# %%
print("\nTask 1: Scale data")
print("\nTask 1: Scale data")
# Your code here...
# Out:
# Task 1: Scale data
#
# Task 1: Scale data

# %% [markdown]
# ## Task 2: Apply K-Means with K

# %%
print("\nTask 2: K-Means (K=3)")
print("\nTask 2: K-Means (K=3)")
# Your code here...
# Out:
# Task 2: K-Means (K=3)
#
# Task 2: K-Means (K=3)

# %% [markdown]
# ## Task 3: Elbow Method to find optimal K

# %%
print("\nTask 3: Elbow Method")
print("\nTask 3: Elbow Method")
# Your code here...
# Out:
# Task 3: Elbow Method
#
# Task 3: Elbow Method

# %% [markdown]
# ## Task 4: Apply Hierarchical Clustering

# %%
print("\nTask 4: Hierarchical Clustering")
print("\nTask 4: Hierarchical Clustering")
# Your code here...
# Out:
# Task 4: Hierarchical Clustering
#
# Task 4: Hierarchical Clustering

# %% [markdown]
# ## Task 5: Visualize clusters

# %%
print("\nTask 5: Visualize")
print("\nTask 5: Visualize")
# Your code here...
print("\nExercise 1 Complete!")
print("\nExercise 1 Complete!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
# Out:
# Task 5: Visualize
#
# Task 5: Visualize
#
# Exercise 1 Complete!
#
# Exercise 1 Complete!
# اكتمل التمرين 1!
# اكتمل التمرين 1!
