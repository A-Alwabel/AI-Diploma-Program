# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Unit 1 - Exercise 1: Data Processing Practice# أساليب معالجة البيانات - تمرين 1: ممارسة معالجة البيانات# Instructions:# 1. Load the sample dataset provided below# 2. Explore the data (shape, info, statistics)# 3. Handle missing values appropriately# 4. Remove any duplicates# 5. Create visualizations (at least 2 different plots)

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# Complete solution:
# """Unit 1 - Exercise 1: Data Processing Practiceأساليب معالجة البيانات - تمرين 1: ممارسة معالجة البياناتInstructions:1. Load the sample dataset provided below2. Explore the data (shape, info, statistics)3. Handle missing values appropriately4. Remove any duplicates5. Create visualizations (at least 2 different plots)\nDataset: Sales data for a retail stor_e""

# %%
import pandas as pd  # Sample dataset - Salesd
a
t
# البيانات النموذجية - بيانات المبيعات
np.random.seed(42)
(42)
data = { 'product_id': range(1, 101), 'product_name': [f'Product__{i}' for i in range(1, 101)], 'category': np.random.choice(['Electronics', 'Clothing', 'Food', 'Books', 'Sports'], 100), 'price': np.random.uniform(10, 500, 100), 'quantity_sold': np.random.randint(10, 1000, 100), 'customer_rating': np.random.uniform(1, 5, 100), 'month': np.random.choice(['Jan', 'Feb', 'Mar', 'Apr', 'May'], 100)}
df = pd.DataFrame(data)

# %% [markdown]
# Introduce some missing values and duplicates for exercise

# %%
import pandas as pd
df.loc[10:15, 'customer_rating'] = np.nandf.loc[5:7, 'price'] = np.nandf = pd.concat([df, df.iloc[[0, 1, 2]]], ignore_index = True)

# %% [markdown]
# TODO: Write your code here# TODO: اكتب الكود الخاص بك هنا

# %% [markdown]
# ## Task 1: Load and explore the data

# %% [markdown]
# Complete solution:
# print("Task 1: Explore the data")# Your code here...

# %% [markdown]
# ## Task 2: Handle missing values

# %% [markdown]
# Complete solution:
# print("\nTask 2: Handle missing values")# Your code here...

# %% [markdown]
# ## Task 3: Remove duplicates

# %% [markdown]
# Complete solution:
# print("\nTask 3: Remove duplicates")# Your code here...

# %% [markdown]
# ## Task 4: Create visualizations

# %%
# Complete solution:
print(" Task 4: Create visualizations")
print(" Task 4: Create visualizations")
# Your code here...
print("Exercise 1 Complete!")
print("Exercise 1 Complete!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
