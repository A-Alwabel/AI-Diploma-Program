# %% [markdown]
# # Solution: Exercise 02
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Unit 1 - Exercise 2: Linear Regression Practice# أساليب معالجة البيانات - تمرين 2: ممارسة الانحدار الخطي# Instructions:# 1. Create a simple linear regression model to predict house prices based on size# 2. Evaluate the model using appropriate metrics# 3. Visualize the results# 4. Make predictions for new data points# Use the provided dataset

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Complete solution:
# """Unit 1 - Exercise 2: Linear Regression Practiceأساليب معالجة البيانات - تمرين 2: ممارسة الانحدار الخطيInstructions:1. Create a simple linear regression model to predict house prices based on size2. Evaluate the model using appropriate metrics3. Visualize the results4. Make predictions for new data pointsUse the provided datase t"""

# %%
import pandas as pd
# Generate sample housing datanp.random.seed(42)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_sizes = np.random.uniform(800, 4000, 150)
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
house_prices = 45 * house
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)
sizes + 80000 + np.random.normal(0, 35000, 150)

# %% [markdown]
# TODO: Write your code here# TODO: اكتب الكود الخاص بك هنا

# %% [markdown]
# ## Task 1: Split the data into train and test sets (80/20)

# %% [markdown]
# Complete solution:
# print("\nTask 1: Split data")# Your code here...

# %% [markdown]
# ## Task 2: Create and train a Linear Regression model

# %% [markdown]
# Complete solution:
# print("\nTask 2: Train Linear Regression model")# Your code here...

# %% [markdown]
# ## Task 3: Make predictions and evaluate the model

# %% [markdown]
# Complete solution:
# print("\nTask 3: Evaluate model")# Your code here...

# %% [markdown]
# ## Task 4: Visualize the results

# %% [markdown]
# Complete solution:
# print("\nTask 4: Visualize results")# Your code here...

# %% [markdown]
# ## Task 5: Make predictions for new house sizes: [1000, 2000, 3000]

# %%
# Complete solution:
# print("\nTask 5: Predict for new sizes")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
new_sizes = [[1000], [2000], [3000]]# Your code here...print("\nExercise 2 Complete!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")
print("اكتمل التمرين 2!")

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
