# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Unit 2 - Exercise 1: Ridge and Lasso Regression Practice# تقنيات الانحدار المتقدمة - تمرين 1: ممارسة الانحدار ريدج ولاسو# Instructions:# 1. Load the provided dataset# 2. Apply Ridge and Lasso regression with different alpha values# 3. Compare the results with Linear Regression# 4. Visualize the coefficient shrinkage# 5. Find the optimal alpha value for both methods

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Complete solution:
# """Unit 2 - Exercise 1: Ridge and Lasso Regression Practiceتقنيات الانحدار المتقدمة - تمرين 1: ممارسة الانحدار ريدج ولاسوInstructions:1. Load the provided dataset2. Apply Ridge and Lasso regression with different alpha values3. Compare the results with Linear Regression4. Visualize the coefficient shrinkage5. Find the optimal alpha value for both method s"""

# %% [markdown]
# Generate sample data with multicollinearity

# %%
np.random.seed(42)
n_samples = 300
X = np.random.randn(n_samples, 8)  # Make some features correlat
e
d
X[:, 2] = X[:, 0] + 0.3 * np.random.randn(n_samples)

# %% [markdown]
# TODO: Write your code here# TODO: اكتب الكود الخاص بك هنا

# %% [markdown]
# ## Task 1: Split the data and scale features

# %% [markdown]
# Complete solution:
# print("\nTask 1: Split and scale data")# Your code here...

# %% [markdown]
# ## Task 2: Train Linear Regression, Ridge, and Lasso models

# %% [markdown]
# Complete solution:
# print("\nTask 2: Train models")# Your code here...

# %% [markdown]
# ## Task 3: Compare coefficients

# %% [markdown]
# Complete solution:
# print("\nTask 3: Compare coefficients")# Your code here...

# %% [markdown]
# ## Task 4: Find optimal alpha for Ridge and Lasso

# %%
# Complete solution:
print(" Task 4: Find optimal alpha")
print(" Task 4: Find optimal alpha")
# Your code here...
print("Exercise 1 Complete!")
print("Exercise 1 Complete!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
