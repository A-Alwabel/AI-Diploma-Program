# %% [markdown]
# # Implementing Decision Tree and Random Forest Regression
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement decision tree regression
# - Implement random forest regression
# - Understand tree-based regression
# - Compare tree methods
# - Apply to regression problems
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of regression
# - ✅ Understanding of decision trees
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 1**:
# - Implementing decision tree and random forest regression
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## Introduction
#
# **Tree-based regression** methods (decision trees and random forests) can capture non-linear relationships and handle complex patterns in data.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
import pandas as pd
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt_
print("✅ Libraries imported!")
print("\nDecision Tree and Random Forest Regression")
print("=" * 60)

print("\nDecision Tree Regression:")
print("  - Non-parametric method")
print("  - Splits data based on features")
print("  - Can capture non-linear patterns")

print("\nRandom Forest Regression:")
print("  - Ensemble of decision trees")
print("  - Reduces overfitting")
print("  - Better generalization")

print("\n✅ Tree-based regression concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Decision Tree and Random Forest Regression
# ...
#
# Decision Tree Regression:
#   - Non-parametric method
#   - Splits data based on features
#   - Can capture non-linear patterns
#
# Random Forest Regression:
#   - Ensemble of decision trees
#   - Reduces overfitting
#   - Better generalization
#
# ✅ Tree-based regression concepts understood!
