# %% [markdown]
# # Computing Regression Evaluation Metrics (MSE, RMSE, MAE, R²)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Compute MSE (Mean Squared Error)
# - Compute RMSE (Root Mean Squared Error)
# - Compute MAE (Mean Absolute Error)
# - Compute R² (Coefficient of Determination)
# - Interpret regression metrics
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of regression
# - ✅ Understanding of error metrics
# - ✅ Python, NumPy knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 2**:
# - Computing regression evaluation metrics (MSE, RMSE, MAE, R²)
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **Regression evaluation metrics** quantify how well a regression model predicts target values, helping assess model performance and compare different models.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
from sklearn.metrics import mean
squared
squared
error, mean
error, mean
absolute
absolute
error, r2
error, r2
score_
score_
