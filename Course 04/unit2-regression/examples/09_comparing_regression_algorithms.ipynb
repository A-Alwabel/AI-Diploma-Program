# %% [markdown]
# # Comparing Regression Algorithms on Real Datasets
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Compare multiple regression algorithms
# - Evaluate performance metrics
# - Analyze algorithm strengths
# - Select best algorithm
# - Apply to real datasets
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of regression algorithms
# - ✅ Understanding of evaluation metrics
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 1**:
# - Comparing regression algorithms on real datasets
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 1 Practical Content
#
# ---
#
# ## Introduction
#
# **Comparing regression algorithms** helps identify the best model for a specific dataset by evaluating performance across different methods.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LinearRegression
