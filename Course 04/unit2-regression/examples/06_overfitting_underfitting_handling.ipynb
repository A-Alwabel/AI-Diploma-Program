# %% [markdown]
# # Identifying and Handling Overfitting/Underfitting
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Identify overfitting
# - Identify underfitting
# - Apply regularization techniques
# - Use cross-validation
# - Optimize model complexity
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of bias-variance tradeoff
# - ✅ Understanding of model complexity
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 2**:
# - Identifying and handling overfitting/underfitting
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 2 Practical Content
#
# ---
#
# ## Introduction
#
# **Overfitting** (high variance) and **underfitting** (high bias) are common problems in machine learning. Proper identification and handling are crucial for good model performance.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
