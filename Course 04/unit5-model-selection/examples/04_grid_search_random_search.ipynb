# %% [markdown]
# # Using Grid Search and Random Search in Scikit-learn to Optimize Parameters
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement Grid Search
# - Implement Random Search
# - Compare search strategies
# - Optimize hyperparameters
# - Apply to model selection
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of hyperparameter tuning
# - ✅ Understanding of search strategies
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 5**:
# - Using Grid Search and Random Search in scikit-learn to optimize parameters
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 5 Practical Content
#
# ---
#
# ## Introduction
#
# **Grid Search** and **Random Search** are systematic approaches to finding optimal hyperparameters, with different trade-offs in computational cost and coverage.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
