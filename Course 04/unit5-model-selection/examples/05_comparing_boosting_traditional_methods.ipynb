# %% [markdown]
# # Comparing Performance with Traditional Methods
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Compare boosting models with traditional methods
# - Evaluate performance differences
# - Analyze model strengths
# - Select appropriate methods
# - Apply to real datasets
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of boosting
# - ✅ Understanding of traditional ML methods
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 5**:
# - Comparing performance with traditional methods
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 5 Practical Content
#
# ---
#
# ## Introduction
#
# **Comparing boosting with traditional methods** helps understand when advanced ensemble techniques provide significant improvements over simpler approaches.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
import pandas as pd
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier, GradientBoostingClassifier
from sklearn.metrics import accuracy_score, classification_report
import matplotlib.pyplot as plt_
print("✅ Libraries imported!")
print("\nComparing Boosting with Traditional Methods")
print("=" * 60)

print("\nTraditional Methods:")
print("  - Logistic Regression")
print("  - Decision Trees")
print("  - Random Forest")

print("\nBoosting Methods:")
print("  - Gradient Boosting")
print("  - XGBoost")
print("  - LightGBM")

print("\nComparison Metrics:")
print("  - Accuracy")
print("  - Training time")
print("  - Prediction time")
print("  - Model complexity")

print("\n✅ Model comparison concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Comparing Boosting with Traditional Methods
# ...
#
# Traditional Methods:
#   - Logistic Regression
#   - Decision Trees
#   - Random Forest
#
# Boosting Methods:
#   - Gradient Boosting
#   - XGBoost
#   - LightGBM
#
# Comparison Metrics:
#   - Accuracy
#   - Training time
#   - Prediction time
#   - Model complexity
#
# ✅ Model comparison concepts understood!
