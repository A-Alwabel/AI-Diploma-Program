# %% [markdown]
# # Implementing Cross-Validation and Hyperparameter Tuning Using Python
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Implement cross-validation
# - Perform hyperparameter tuning
# - Use validation sets
# - Optimize model parameters
# - Apply to model selection
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of cross-validation
# - ✅ Understanding of hyperparameters
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 5**:
# - Implementing cross-validation and hyperparameter tuning using Python
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 5 Practical Content
#
# ---
#
# ## Introduction
#
# **Cross-validation and hyperparameter tuning** are essential techniques for selecting optimal model parameters and ensuring robust model performance.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
from sklearn.model_selection import cross_val_score, KFold
