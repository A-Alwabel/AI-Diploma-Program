# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Unit 5 - Exercise 1: Model Selection Practice# اختيار النموذج والتعزيز - تمرين 1: ممارسة اختيار النموذج# Instructions:# 1. Load the provided dataset# 2. Use Grid Search to find best hyperparameters for Random Forest# 3. Compare with default Random Forest# 4. (Optional) Try XGBoost if available# 5. Evaluate and compare results

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import np

# %% [markdown]
# Complete solution:
# """Unit 5 - Exercise 1: Model Selection Practiceاختيار النموذج والتعزيز - تمرين 1: ممارسة اختيار النموذجInstructions:1. Load the provided dataset2. Use Grid Search to find best hyperparameters for Random Forest3. Compare with default Random Forest4. (Optional) Try XGBoost if available5. Evaluate and compare result s"""

# %% [markdown]
# Generate sample classification data

# %%
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
classification( n_samples = 1000, n_features = 10, n_informative = 5, random_state = 42)
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(10)])

# %% [markdown]
# TODO: Write your code here# TODO: اكتب الكود الخاص بك هنا

# %% [markdown]
# ## Task 1: Split the data

# %% [markdown]
# Complete solution:
# print("\nTask 1: Split data")# Your code here...

# %% [markdown]
# ## Task 2: Train default Random Forest

# %% [markdown]
# Complete solution:
# print("\nTask 2: Default Random Forest")# Your code here...

# %% [markdown]
# ## Task 3: Grid Search for Random Forest

# %% [markdown]
# Complete solution:
# print("\nTask 3: Grid Search")# Your code here...

# %% [markdown]
# ## Task 4: Compare results

# %%
# Complete solution:
# print("\nTask 4: Compare")
# Your code here...print("\nExercise 1 Complete!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
