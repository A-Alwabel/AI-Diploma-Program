# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Unit 3 - Exercise 1: Classification Practice# تقنيات التصنيف المتقدمة - تمرين 1: ممارسة التصنيف# Instructions:# 1. Load the provided dataset# 2. Train a Decision Tree classifier# 3. Train a Random Forest classifier# 4. Evaluate both models using appropriate metrics# 5. Compare feature importance# 6. Visualize decision boundaries (if 2D) or feature importance

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import pandas as pd
import numpy as np
from sklearn.model_selection import np

# %% [markdown]
# Complete solution:
# """Unit 3 - Exercise 1: Classification Practiceتقنيات التصنيف المتقدمة - تمرين 1: ممارسة التصنيفInstructions:1. Load the provided dataset2. Train a Decision Tree classifier3. Train a Random Forest classifier4. Evaluate both models using appropriate metrics5. Compare feature importance6. Visualize decision boundaries (if 2 D)\nor feature importance"" confusion
# matrix)

# %% [markdown]
# Generate sample classification data

# %%
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
np.random.seed(42)
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
X, y = make
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
classification( n_samples = 800, n_features = 8, n_informative = 5, n_redundant = 2, random_state = 42)
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df =  pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])
df = pd.DataFrame(X, columns=[f'feature _{i}' for i in range(8)])

# %% [markdown]
# TODO: Write your code here# TODO: اكتب الكود الخاص بك هنا

# %% [markdown]
# ## Task 1: Split the data

# %% [markdown]
# Complete solution:
# print("\nTask 1: Split data")# Your code here...

# %% [markdown]
# ## Task 2: Train Decision Tree

# %% [markdown]
# Complete solution:
# print("\nTask 2: Train Decision Tree")# Your code here...

# %% [markdown]
# ## Task 3: Train Random Forest

# %% [markdown]
# Complete solution:
# print("\nTask 3: Train Random Forest")# Your code here...

# %% [markdown]
# ## Task 4: Evaluate both models

# %% [markdown]
# Complete solution:
# print("\nTask 4: Evaluate models")# Your code here...

# %% [markdown]
# ## Task 5: Compare feature importance

# %%
# Complete solution:
# print("\nTask 5: Feature importance")
# Your code here...print("\nExercise 1 Complete!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")
print("اكتمل التمرين 1!")

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
