# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
"""
Unit 3 - Exercise 4: K-Nearest Neighbors (KNN) Practice

Dataset: REAL wine chemistry — 13 chemical measurements taken from wines grown in the
same region of Italy by three different cultivators. We keep the two cultivars that are
hardest to tell apart, giving a binary problem.

Why this dataset for THIS exercise: task 2 asks you to show why scaling is critical for
KNN. Here the reason is real and extreme — proline is measured in the hundreds while hue
sits near 1.0, so an unscaled distance is decided almost entirely by one column. You will
be able to measure the damage, not just be told about it.

Instructions:
1. Load the provided real dataset
2. Scale the features (CRITICAL for KNN!)
3. Train KNN models with different K values
4. Find the optimal K value using validation
5. Evaluate the final model with optimal K
6. Compare KNN with and without feature scaling (demonstrate importance)

⚠️ This is a small dataset (about 130 wines). Expect the "optimal K" curve to be bumpy:
with a test set this size, one or two wines changing sides moves the accuracy by a whole
percentage point. Say so in your conclusion rather than reporting a single lucky K.
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.neighbors import KNeighborsClassifier
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix
)
from sklearn.datasets import load_wine

# Load the REAL wine chemistry data (ships with scikit-learn, works offline).
wine = load_wine()
full = pd.DataFrame(wine.data, columns=wine.feature_names)
full['target'] = wine.target

# Keep cultivars 1 and 2 — the pair that genuinely overlaps — for a binary problem.
df = full[full['target'].isin([1, 2])].copy().reset_index(drop=True)
df['target'] = (df['target'] == 2).astype(int)

print("Dataset loaded!")
print(f"Shape: {df.shape}")
print(f"Source: UCI Wine recognition data — real chemical analyses of Italian wines")
print(f"\nClass distribution:")
print(df['target'].value_counts())
print(f"\nWhy scaling is critical here — the real spread of each measurement:")
ranges = df[wine.feature_names].agg(['min', 'max', 'std']).T.round(2)
print(ranges.sort_values('std', ascending=False).head(5))
print("\nCompare the largest std with the smallest: an unscaled Euclidean distance is")
print("dominated by whichever column happens to be measured in the biggest units.")

# TODO: Write your code here

# Task 1: Split the data
print("\n" + "="*60)
print("Task 1: Split data")
print("="*60)
# Your code here...

# Task 2: Demonstrate why scaling is critical
print("\n" + "="*60)
print("Task 2: Compare KNN with and without scaling")
print("="*60)
# Train KNN WITHOUT scaling (use original data)
# Train KNN WITH scaling (use StandardScaler)
# Compare accuracies - show the difference!
# Your code here...

# Task 3: Find optimal K value
print("\n" + "="*60)
print("Task 3: Find optimal K value")
print("="*60)
# Test K values from 1 to 30 (odd numbers only)
# Plot K vs Accuracy (both train and test)
# Find the K with best test accuracy
# Your code here...

# Task 4: Train final KNN model with optimal K
print("\n" + "="*60)
print("Task 4: Train final model with optimal K")
print("="*60)
# Train KNN with the best K value found
# Evaluate with all metrics (accuracy, precision, recall, F1)
# Your code here...

# Task 5: Create confusion matrix
print("\n" + "="*60)
print("Task 5: Confusion Matrix")
print("="*60)
# Create and visualize confusion matrix
# Your code here...

# Task 6: (Optional) Compare KNN with other classifiers
print("\n" + "="*60)
print("Task 6: (Optional) Compare with other classifiers")
print("="*60)
# Compare KNN with Logistic Regression or Decision Tree
# Show which performs better on this dataset
# Your code here...

print("\n" + "="*60)
print("Exercise 4 Complete!")
print("="*60)
# Out:
# Dataset loaded!
# Shape: (119, 14)
# Source: UCI Wine recognition data — real chemical analyses of Italian wines
#
# Class distribution:
# target
# 0    71
# 1    48
# Name: count, dtype: int64
#
# Why scaling is critical here — the real spread of each measurement:
#                       min    max     std
# proline            278.00  985.0  151.31
# magnesium           70.00  162.0   14.81
# alcalinity_of_ash   10.60   30.0    3.00
# color_intensity      1.28   13.0    2.67
# malic_acid           0.74    5.8    1.25
#
# Compare the largest std with the smallest: an unscaled Euclidean distance is
# dominated by whichever column happens to be measured in the biggest units.
#
# ...
# Task 1: Split data
# ...
#
# ...
# Task 2: Compare KNN with and without scaling
# ...
#
# ...
# Task 3: Find optimal K value
# ...
#
# ...
# Task 4: Train final model with optimal K
# ...
#
# ...
# Task 5: Confusion Matrix
# ...
#
# ...
# Task 6: (Optional) Compare with other classifiers
# ...
#
# ...
# Exercise 4 Complete!
# ...
