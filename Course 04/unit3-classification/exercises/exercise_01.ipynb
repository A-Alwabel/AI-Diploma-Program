# %% [markdown]
# # Unit 3 - Exercise 1: Classification Practice
#
# # Instructions:
# # 1. Load the provided dataset
# # 2. Train a Decision Tree classifier
# # 3. Train a Random Forest classifier
# # 4. Evaluate both models using appropriate metrics
# # 5. Compare feature importance
# # 6. Visualize decision boundaries (if 2D) or feature importance

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Import the classification toolkit: data handling, a synthetic-data maker,
# and the train/test splitter you will use in every task below.
import pandas as pd
import numpy as np
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

# %% [markdown]
# Generate sample classification data

# %%
# Create the practice dataset: 800 samples, 8 features (5 informative, 2 redundant).
# WHY: a fixed random_state means your numbers match the solution notebook.
np.random.seed(42)
X, y = make_classification(
    n_samples=800, n_features=8, n_informative=5, n_redundant=2, random_state=42
)
df = pd.DataFrame(X, columns=[f'feature_{i}' for i in range(8)])

# %% [markdown]
# TODO: Write your code here

# %% [markdown]
# ## Task 1: Split the data

# %%
print("\nTask 1: Split data")
# Your code here...
# Out:
# Task 1: Split data

# %% [markdown]
# ## Task 2: Train Decision Tree

# %%
print("\nTask 2: Train Decision Tree")
# Your code here...
# Out:
# Task 2: Train Decision Tree

# %% [markdown]
# ## Task 3: Train Random Forest

# %%
print("\nTask 3: Train Random Forest")
# Your code here...
# Out:
# Task 3: Train Random Forest

# %% [markdown]
# ## Task 4: Evaluate both models

# %%
print("\nTask 4: Evaluate models")
# Your code here...
# Out:
# Task 4: Evaluate models

# %% [markdown]
# ## Task 5: Compare feature importance

# %%
print("\nTask 5: Feature importance")
# Your code here...

print("\nExercise 1 Complete!")
# Out:
# Task 5: Feature importance
#
# Exercise 1 Complete!
