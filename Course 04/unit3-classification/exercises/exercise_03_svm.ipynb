# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
"""
Unit 3 - Exercise 3: Support Vector Machine (SVM) Practice

Dataset: REAL diagnostic data — the Wisconsin Diagnostic Breast Cancer study, 569
biopsies described by 30 measurements taken from digitised images of cell nuclei, each
labelled with the actual pathology result (malignant or benign).

Why this dataset for THIS exercise: the 30 real features live on wildly different scales
(cell area in the hundreds, smoothness around 0.1). SVM is scale-sensitive, so task 1's
StandardScaler step is not a formality here — skip it and watch the model fall apart.

Instructions:
1. Load the provided real dataset
2. Train SVM models with different kernels (Linear, RBF, Polynomial)
3. Compare their performance
4. Tune hyperparameters (C and gamma for RBF)
5. Visualize decision boundaries (if 2D) or compare metrics
6. Find the best kernel and hyperparameters

⚠️ In a medical setting a missed malignancy costs far more than a false alarm. Report
RECALL on the malignant class alongside accuracy, and say which errors your best model
is making.
"""

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn.model_selection import train_test_split
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import (
    accuracy_score, precision_score, recall_score, f1_score,
    confusion_matrix, roc_auc_score
)

# Load the REAL breast-cancer biopsies (ships with scikit-learn, works offline).
from sklearn.datasets import load_breast_cancer

cancer = load_breast_cancer()
df = pd.DataFrame(cancer.data, columns=cancer.feature_names)
df['target'] = (cancer.target == 0).astype(int)   # 1 = malignant, 0 = benign

print("Dataset loaded!")
print(f"Shape: {df.shape}")
print(f"Source: Wisconsin Diagnostic Breast Cancer study (real biopsies)")
print(f"\nClass distribution (1 = malignant, 0 = benign):")
print(df['target'].value_counts())
print(f"\nWhy scaling matters here — the real feature ranges:")
print(df[cancer.feature_names].agg(['min', 'max']).T.head(6).round(4))

# TODO: Write your code here

# Task 1: Split the data and scale features (CRITICAL for SVM!)
print("\n" + "="*60)
print("Task 1: Split and scale data")
print("="*60)
# Your code here...

# Task 2: Train Linear SVM
print("\n" + "="*60)
print("Task 2: Train Linear SVM")
print("="*60)
# Train SVM with kernel='linear', C=1.0
# Evaluate and print metrics
# Your code here...

# Task 3: Train RBF SVM
print("\n" + "="*60)
print("Task 3: Train RBF SVM")
print("="*60)
# Train SVM with kernel='rbf', C=1.0, gamma='scale'
# Evaluate and print metrics
# Your code here...

# Task 4: Train Polynomial SVM
print("\n" + "="*60)
print("Task 4: Train Polynomial SVM")
print("="*60)
# Train SVM with kernel='poly', degree=3, C=1.0
# Evaluate and print metrics
# Your code here...

# Task 5: Compare all three kernels
print("\n" + "="*60)
print("Task 5: Compare kernels")
print("="*60)
# Create a comparison table or visualization
# Show which kernel performs best
# Your code here...

# Task 6: Tune C parameter for RBF kernel
print("\n" + "="*60)
print("Task 6: Tune C parameter for RBF")
print("="*60)
# Try different C values: [0.1, 1.0, 10.0, 100.0]
# Find the best C value
# Your code here...

# Task 7: (Optional) Tune gamma parameter for RBF
print("\n" + "="*60)
print("Task 7: (Optional) Tune gamma parameter")
print("="*60)
# Try different gamma values: ['scale', 'auto', 0.01, 0.1, 1.0]
# Find the best gamma value
# Your code here...

print("\n" + "="*60)
print("Exercise 3 Complete!")
print("="*60)
# Out:
# Dataset loaded!
# Shape: (569, 31)
# Source: Wisconsin Diagnostic Breast Cancer study (real biopsies)
#
# Class distribution (1 = malignant, 0 = benign):
# target
# 0    357
# 1    212
# Name: count, dtype: int64
#
# Why scaling matters here — the real feature ranges:
#                        min        max
# mean radius         6.9810    28.1100
# mean texture        9.7100    39.2800
# mean perimeter     43.7900   188.5000
# mean area         143.5000  2501.0000
# mean smoothness     0.0526     0.1634
# mean compactness    0.0194     0.3454
#
# ============================================================
# Task 1: Split and scale data
# ============================================================
#
# ============================================================
# Task 2: Train Linear SVM
# ============================================================
#
# ============================================================
# Task 3: Train RBF SVM
# ============================================================
#
# ============================================================
# Task 4: Train Polynomial SVM
# ============================================================
#
# ============================================================
# Task 5: Compare kernels
# ============================================================
#
# ============================================================
# Task 6: Tune C parameter for RBF
# ============================================================
#
# ============================================================
# Task 7: (Optional) Tune gamma parameter
# ============================================================
#
# ============================================================
# Exercise 3 Complete!
# ============================================================
