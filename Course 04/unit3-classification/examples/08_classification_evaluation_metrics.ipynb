# %% [markdown]
# # Evaluating Classification Models (Confusion Matrix, ROC, Precision, Recall)
#
# ## 📚 Learning Objectives
#
# By completing this notebook, you will:
# - Build confusion matrices
# - Plot ROC curves
# - Compute precision and recall
# - Compute F1 score
# - Analyze classification performance
#
# ## 🔗 Prerequisites
#
# - ✅ Understanding of classification
# - ✅ Understanding of evaluation metrics
# - ✅ Scikit-learn knowledge
#
# ---
#
# ## Official Structure Reference
#
# This notebook covers practical activities from **Course 04, Unit 3**:
# - Evaluating classification models using confusion matrices, ROC curves, and analyzing precision and recall
# - **Source:** `DETAILED_UNIT_DESCRIPTIONS.md` - Unit 3 Practical Content
#
# ---
#
# ## Introduction
#
# **Classification evaluation metrics** provide comprehensive insights into model performance, helping identify strengths and weaknesses in classification models.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np
import matplotlib.pyplot as plt
from sklearn.metrics import confusion_matrix, roc_curve, auc, precision_recall_curve
from sklearn.metrics import precision_score, recall_score, f1_score, accuracy_score
import seaborn as sns_
print("✅ Libraries imported!")
print("\nClassification Evaluation Metrics")
print("=" * 60)

print("\nConfusion Matrix:")
print("  - True Positives, True Negatives")
print("  - False Positives, False Negatives")
print("  - Visual representation")

print("\nROC Curve:")
print("  - True Positive Rate vs False Positive Rate")
print("  - AUC score")
print("  - Threshold selection")

print("\nPrecision and Recall:")
print("  - Precision: TP\n(TP + FP))\nprint(  - Recall: TP\n(TP + FN))\nprint(  - F1: Harmonic mean")

print("\n✅ Classification metrics concepts understood!")
# Out:
# ✅ Libraries imported!
#
# Classification Evaluation Metrics
# ...
#
# Confusion Matrix:
#   - True Positives, True Negatives
#   - False Positives, False Negatives
#   - Visual representation
#
# ROC Curve:
#   - True Positive Rate vs False Positive Rate
#   - AUC score
#   - Threshold selection
#
# Precision and Recall:
#   - Precision: TP
# (TP + FP))
# print(  - Recall: TP
# (TP + FN))
# print(  - F1: Harmonic mean
#
# ✅ Classification metrics concepts understood!
