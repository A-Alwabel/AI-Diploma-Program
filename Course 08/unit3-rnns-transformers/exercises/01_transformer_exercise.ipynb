# %% [markdown]
# # Exercise: Machine Translation
# ## AIAT 122 - Deep Learning
#
# ## Learning Objectives
#
# - Implement transformer for translation
# - Train sequence-to-sequence model
# - Evaluate translation quality
# - Apply to real-world translation
#
# ## Real-World Context
#
# Build translation system for multilingual communication.
#
# **Task**: Translate between language pairs.
#
# **Theory → Practice:** This exercise applies the theory and code patterns from `04_transformer_attention.ipynb` and `05_bert_finetuning.ipynb`. Complete those examples first if you haven't.
#
# ---
#
# ## Task 1: Transformer Architecture (35 points)
#
# Implement transformer encoder-decoder:
# 1. Encoder with attention
# 2. Decoder with attention
# 3. Positional encoding

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# **Expected:** When complete, you should see model architecture, training progress, and translation or sequence metrics. Compare with the instructor solution after the deadline.
#
# ---

# %%
# %pip install torch transformers -q
import torch
import torch.nn as nn
import math

# ── Task 1: Transformer Architecture ────────────────────────────────────────
# Hint: Use nn.TransformerEncoderLayer / nn.TransformerEncoder as a starting point,
# or build a simple encoder-decoder with nn.Transformer.
# Reference: example 04_transformer_attention.ipynb

class TranslationModel(nn.Module):
    def __init__(self, vocab_size=10000, d_model=256, nhead=4, num_layers=2, max_len=100):
        super().__init__()
        # TODO: Embedding + positional encoding
        # self.embedding = nn.Embedding(vocab_size, d_model, padding_idx=0)
        # Positional encoding can be a simple lookup table:
        # self.pos_embedding = nn.Embedding(max_len, d_model)

        # TODO: Transformer encoder-decoder
        # self.transformer = nn.Transformer(d_model=d_model, nhead=nhead,
        #                                   num_encoder_layers=num_layers,
        #                                   num_decoder_layers=num_layers,
        #                                   batch_first=True)

        # TODO: Output linear projection to vocabulary
        # self.out_proj = nn.Linear(d_model, vocab_size)
        pass

    def forward(self, src, tgt):
        # TODO: embed src and tgt, apply transformer, project to vocab
        # src_emb = self.embedding(src) + self.pos_embedding(torch.arange(src.size(1)))
        # tgt_emb = self.embedding(tgt) + self.pos_embedding(torch.arange(tgt.size(1)))
        # out = self.transformer(src_emb, tgt_emb)
        # return self.out_proj(out)
        pass

# Sanity check
model = TranslationModel()
print(model)
src = torch.randint(1, 100, (2, 10))   # (batch=2, seq_len=10)
tgt = torch.randint(1, 100, (2,  8))   # (batch=2, seq_len= 8)
try:
    out = model(src, tgt)
    print("Output shape:", out.shape)   # expect (2, 8, 10000)
except Exception as e:
    print("Implement forward() first:", e)
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# ## Task 2: Training (30 points)
#
# Train translation model:
# 1. Prepare parallel corpus
# 2. Train encoder-decoder
# 3. Evaluate with BLEU score

# %%
import torch.optim as optim

# ── Task 2: Training ─────────────────────────────────────────────────────
# Hint: Use teacher forcing during training (feed ground-truth tokens as decoder input).
# Reference: example 04_transformer_attention.ipynb (training loop)

# TODO: Define loss and optimizer
# criterion = nn.CrossEntropyLoss(ignore_index=0)   # 0 = padding token
# optimizer = optim.Adam(model.parameters(), lr=1e-4)

# TODO: Simple training loop
NUM_EPOCHS = 5

# for epoch in range(NUM_EPOCHS):
#     model.train()
#     total_loss = 0
#     for src_batch, tgt_batch in train_loader:      # replace with your DataLoader
#         optimizer.zero_grad()
#         # Teacher forcing: feed tgt[:-1] as input, predict tgt[1:]
#         logits = model(src_batch, tgt_batch[:, :-1])   # (B, T-1, vocab)
#         logits = logits.reshape(-1, logits.size(-1))    # (B*(T-1), vocab)
#         targets = tgt_batch[:, 1:].reshape(-1)           # (B*(T-1),)
#         loss = criterion(logits, targets)
#         loss.backward()
#         optimizer.step()
#         total_loss += loss.item()
#     print(f'Epoch {epoch+1}  Loss: {total_loss:.4f}')

# YOUR CODE HERE
print('Task 2 scaffold ready ✅')

# %% [markdown]
# ## Task 3: Real-World Application (35 points)
#
# Apply your trained model to a real translation or sequence task.
#
# **Requirements:**
# - Run inference on at least 5 new sentences
# - Compute BLEU score (or character error rate) on a small test set
# - Show side-by-side: source sentence | model output | reference translation
# - Write 2–3 sentences: what worked well, what you would improve
#
# **Submission**: Complete notebook with translation system.
#
# **Grading**: 100 points total

# %%
# ── Task 3: Real-World Application ─────────────────────────────────────────
# Hint: For inference use greedy decoding: start with <SOS>, predict token by token.
# Reference: example 05_bert_finetuning.ipynb (inference section)

def greedy_decode(model, src, max_len=50, sos_idx=1, eos_idx=2):
    """
    Generate a translation token by token (greedy).
    Replace sos_idx / eos_idx with your tokenizer's actual values.
    """
    model.eval()
    with torch.no_grad():
        tgt = torch.tensor([[sos_idx]])      # start token
        for _ in range(max_len):
            # TODO: call model(src, tgt), take argmax of last token
            # logits = model(src, tgt)
            # next_token = logits[:, -1, :].argmax(-1, keepdim=True)
            # if next_token.item() == eos_idx: break
            # tgt = torch.cat([tgt, next_token], dim=1)
            break  # remove this once implemented
    return tgt

# TODO: Run greedy_decode on 5 test sentences and display results
# YOUR CODE HERE

# ── Short written analysis ───────────────────────────────────────────────
print('What worked well:')
print('  ...')
print('What I would improve next (e.g. beam search, larger model, more data):')
print('  ...')
