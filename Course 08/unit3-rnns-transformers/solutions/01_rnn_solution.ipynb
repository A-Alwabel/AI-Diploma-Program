# %% [markdown]
# # INSTRUCTOR SOLUTION: RNN Exercise
# ## AIAT 122 - Deep Learning
#
# **⚠️ INSTRUCTOR USE ONLY**

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install torch numpy pandas matplotlib -q
import torch
import torch.nn as nn
import numpy as np
import pandas as pd


import matplotlib.pyplot as plt_
print('✅ Setup complete!')
# Out:
# Note: you may need to restart the kernel to use updated packages.
# ✅ Setup complete!

# %% [markdown]
# ## Solution: Complete RNN Implementation

# %%
def generate_stock_data(n_samples = 1000):
    pass

# %%
class SimpleRNN(nn.Module):
    pass
    
def __init__(self, input_size, hidden_size, output_size):
    pass

# %%
def prepare_sequences(data, seq_length = 20):
    pass

# %%
class LSTMModel(nn.Module):
    pass
    
def __init__(self, input_size, hidden_size, output_size):
    pass

# %% [markdown]
# ## Teaching Notes
#
# **Key Points:**
# 1. LSTM handles long-term dependencies better
# 2. Vanishing gradient problem in vanilla RNN
# 3. Real-world: stock prediction, weather, sales
#
# **Grading: 100 points**
# - Data generation: 15 pts
# - RNN implementation: 25 pts
# - Training: 30 pts
# - LSTM comparison: 30 pts
#
# **Common Mistakes:**
# - Wrong sequence preparation
# - Not normalizing data
# - Too few training epochs
