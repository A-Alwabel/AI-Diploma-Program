# %% [markdown]
# # INSTRUCTOR SOLUTION: Object Detection
# ## AIAT 122 - Deep Learning
#
# **⚠️ INSTRUCTOR USE ONLY**
#
# Complete CNN solution with transfer learning.

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# %pip install torch torchvision -q_
import torch.nn as nn
from torchvision import models

# Transfer learning approach_model = models.resnet18(pretrained=True)
# Replace final layer_model.fc = nn.Linear(model.fc.in_features, num_classes)

print('✅ Transfer learning solution')
print('\nTeaching Notes: Use pre-trained ResNet, fine-tune for object detection')
print('Grading: Task 1 (30pts), Task 2 (35pts), Task 3 (35pts)')
# Out:
# Usage:
#   /opt/anaconda3/envs/course2/bin/python -m pip install [options] <requirement specifier> [package-index-options] ...
#   /opt/anaconda3/envs/course2/bin/python -m pip install [options] -r <requirements file> [package-index-options] ...
#   /opt/anaconda3/envs/course2/bin/python -m pip install [options] [-e] <vcs project url> ...
#   /opt/anaconda3/envs/course2/bin/python -m pip install [options] [-e] <local project path> ...
#   /opt/anaconda3/envs/course2/bin/python -m pip install [options] <archive url/path> ...
#
# no such option: -_
# Note: you may need to restart the kernel to use updated packages.
# ✅ Transfer learning solution
#
# Teaching Notes: Use pre-trained ResNet, fine-tune for object detection
# Grading: Task 1 (30pts), Task 2 (35pts), Task 3 (35pts)
