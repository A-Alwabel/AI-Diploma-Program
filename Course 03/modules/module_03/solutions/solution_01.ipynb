# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Exercise 01
#
# **Module 03**
#
# ---

# %% [markdown]
# Exercise 01: Optimization AlgorithmsThis exercise helps you understand different optimization algorithmsused in machine learning.Instructions:1. Implement different optimizers2. Compare their performance3. Understand when to use each

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `pass` statements
# 2. ✅ Replace `pass` with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %% [markdown]
# Complete solution:pass# import numpy as npclass SimpleGDOptimizer:

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %% [markdown]
# Complete solution:# if __name__ == "__main__":    print("Testing Exercise 01: Optimization Algorithms")    print("=" * 60)        # Test 1: Simple GD    print("\n1. Testing SimpleGDOptimizer:")    def loss(x):        return (x - 3)**2        def grad(x):        return 2 * (x - 3)        optimizer = SimpleGDOptimizer(lr=0.1)    x = 5.0    for i in range(20):        g = grad(x)        x = optimizer.update(x, g)        print(f"   Starting: 5.0, Final: {x:.4f}, Target: 3.0")    assert abs(x - 3) < 0.5, "Should converge close to 3"    print("   ✅ Passed!")        # Test 2: Momentum    print("\n2. Testing MomentumOptimizer:")    momentum_opt = MomentumOptimizer(lr=0.1, momentum=0.9)    x = 5.0    for i in range(20):        g = grad(x)        x = momentum_opt.update(x, g)        print(f"   Starting: 5.0, Final: {x:.4f}, Target: 3.0")    assert abs(x - 3) < 0.5, "Should converge close to 3"    print("   ✅ Passed!")        print("\n" + "=" * 60)    print("🎉 All tests passed!")

# %% [markdown]
# ---
#
# ## ✅ Check Solution
#
# Compare with: `exercises/solutions/solution_01.ipynb`
#
# **💡 Try solving it yourself first!**

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
