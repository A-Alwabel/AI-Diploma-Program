# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Exercise 01
#
# **Module 04**
#
# ---

# %% [markdown]
# Exercise 01: Principal Component Analysis (PCA)This exercise helps you understand and implement PCA, a fundamentaldimensionality reduction technique.Instructions:1. Implement PCA from scratch2. Understand how eigenvalues are used3. Apply to reduce dimensions

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `pass` statements
# 2. ✅ Replace `pass` with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Complete solution:
pass
# import numpy as np
def compute_covariance_matrix(data):
    # # SOLUTION: Compute covariance matrix
    # Hint: Center data first (subtract mean), then compute covariance
    pass

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %% [markdown]
# Complete solution:# if __name__ == "__main__":    print("Testing Exercise 01: PCA")    print("=" * 60)        # Create sample data    np.random.seed(42)    data = np.random.randn(100, 10)        # Test 1: Covariance matrix    print("\n1. Testing compute_covariance_matrix:")    cov = compute_covariance_matrix(data)    print(f"   Data shape: {data.shape}")    print(f"   Covariance shape: {cov.shape}")    assert cov.shape == (10, 10), "Covariance should be square"    assert np.allclose(cov, cov.T), "Covariance should be symmetric"    print("   ✅ Passed!")        # Test 2: PCA    print("\n2. Testing pca_from_scratch:")    reduced, variance_ratio = pca_from_scratch(data, n_components=2)    print(f"   Original shape: {data.shape}")    print(f"   Reduced shape: {reduced.shape}")    print(f"   Variance explained: {variance_ratio:.2%}")    assert reduced.shape == (100, 2), "Should reduce to 2 dimensions"    assert 0 <= variance_ratio <= 1, "Variance ratio should be between 0 and 1"    print("   ✅ Passed!")        print("\n" + "=" * 60)    print("🎉 All tests passed!")

# %% [markdown]
# ---
#
# ## ✅ Check Solution
#
# Compare with: `exercises/solutions/solution_01.ipynb`
#
# **💡 Try solving it yourself first!**

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
