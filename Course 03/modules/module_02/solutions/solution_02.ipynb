# %% [markdown]
# # Solution: Exercise 02
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Exercise 02
#
# **Module 02**
#
# ---

# %% [markdown]
# Exercise 02: Gradient Descent ImplementationThis exercise helps you implement gradient descent, the fundamentaloptimization algorithm used in machine learning.Instructions:1. Implement gradient descent from scratch2. Understand how learning rate affects convergence3. Visualize the optimization process

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `pass` statements
# 2. ✅ Replace `pass` with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Complete solution:
# import numpy as np
def gradient_descent(func, gradient_func, initial_x, learning_rate=0.1, iterations=100):
    x = initial_x
    history = [x]
    # # SOLUTION: Implement gradient descent loop
    # For each iteration:
    #   1. Compute gradient at current point
    #   2. Update: x = x - learning_rate * gradient
    #   3. Store x in history
    return x, history

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %% [markdown]
# Complete solution:# if __name__ == "__main__":   print("Testing Exercise 02: Gradient Descent")print("=" * 60)        # Test 1: Gradient descent   print("\n1. Testing gradient_descent:")def f(x):        return (x - 3)**2  # Minimum at x = 3        def grad_f(x):        return 2 * (x - 3)  # Gradient of (x-3)²        initial_x = 5.0   final_x, history = gradient_descent(f, grad_f, initial_x, learning_rate=0.1, iterations=20)print(f"   Function: f(x) = (x - 3)² (minimum at x = 3)")    print(f"   Starting at: {initial_x}")print(f"   Final value: {final_x:.4f}")print(f"   Expected: close to 3.0")print(f"   Converged: {abs(final_x - 3) < 0.1}")    assert abs(final_x - 3) < 0.5, "Should converge close to minimum"    print("   ✅ Passed!")        # Test 2: Learning rate analysis   print("\n2. Testing analyze_learning_rate:")learning_rates = [0.01, 0.1, 0.5, 1.0]    results = analyze_learning_rate(f, grad_f, initial_x, learning_rates, iterations=30)print(f"   Learning Rate Analysis:")for lr, final_val in results.items():        converged = abs(final_val - 3) < 0.5        status = "✅ Converged" if converged else "❌ Diverged"        print(f"   LR = {lr:.2f}: Final x = {final_val:.4f} {status}")print("\n" + "=" * 60)print("🎉 All tests passed!")

# %% [markdown]
# ---
#
# ## ✅ Check Solution
#
# Compare with: `exercises/solutions/solution_02.ipynb`
#
# **💡 Try solving it yourself first!**

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
