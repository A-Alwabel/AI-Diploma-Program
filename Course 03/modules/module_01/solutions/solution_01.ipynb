# %% [markdown]
# # Solution: Exercise 01
#
# ## 📚 Instructor Solution
#
# This notebook contains the complete solution to the exercise.
#
# **Grading Notes:**
# - Review student solutions against this reference
# - Check for correct logic and implementation
# - Verify code quality and documentation

# %% [markdown]
# # Exercise 01
#
# **Module 01**
#
# ---

# %% [markdown]
# Exercise 01: Vector and Matrix OperationsThis exercise helps you practice fundamental linear algebra operations that areessential for machine learning.Instructions:1. Complete the functions below2. Test your solutions with the provided test cases3. Compare with the solution in solutions/solution_01.ipynb

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `pass` statements
# 2. ✅ Replace `pass` with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs | المدخلات والمخرجات
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# Complete solution:
pass
# import numpy as np
def create_data_matrix(samples, features):
    # # SOLUTION: Create a matrix with the specified shape
    # Use np.random.randn() to generate random values
    pass

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %%
import numpy as np
# Complete solution:# if __name__ == "__main__":    print("Testing Exercise 01: Vector and Matrix Operations")    print("=" * 60)        # Test 1: Create data matrix    print("\n1. Testing create_data_matrix:")    data = create_data_matrix(5, 3)    if data is None:        print("   ❌ ERROR: create_data_matrix() returned None!")        print("   💡 SOLUTION: Replace 'pass' with: return np.random.randn(samples, features)")        raise NotImplementedError("Please implement create_data_matrix() first!")    print(f"   Created matrix shape: {data.shape}")    print(f"   Expected: (5, 3)")    assert data.shape == (5, 3), "Shape should be (5, 3)"    print("   ✅ Passed!")        # Test 2: Dot product    print("\n2. Testing compute_dot_product:")    v1 = np.array([1, 2, 3])    v2 = np.array([4, 5, 6])    result = compute_dot_product(v1, v2)    if result is None:        print("   ❌ ERROR: compute_dot_product() returned None!")        print("   💡 SOLUTION: Replace 'pass' with: return np.dot(v1, v2)")        raise NotImplementedError("Please implement compute_dot_product() first!")    expected = 32  # 1*4 + 2*5 + 3*6 = 4 + 10 + 18 = 32    print(f"   Result: {result}")    print(f"   Expected: {expected}")    assert result == expected, f"Expected {expected}, got {result}"    print("   ✅ Passed!")        # Test 3: Matrix multiplication    print("\n3. Testing matrix_multiplication:")    A = np.array([[1, 2], [3, 4]])    B = np.array([[5, 6], [7, 8]])    result = matrix_multiplication(A, B)    if result is None:        print("   ❌ ERROR: matrix_multiplication() returned None!")        print("   💡 SOLUTION: Replace 'pass' with: return np.dot(A, B)")        raise NotImplementedError("Please implement matrix_multiplication() first!")    expected = np.array([[19, 22], [43, 50]])    print(f"   Result:\n{result}")    print(f"   Expected:\n{expected}")    assert np.allclose(result, expected), "Matrix multiplication incorrect"    print("   ✅ Passed!")        # Test 4: Transpose    print("\n4. Testing compute_transpose:")    matrix = np.array([[1, 2, 3], [4, 5, 6]])    result = compute_transpose(matrix)    if result is None:        print("   ❌ ERROR: compute_transpose() returned None!")        print("   💡 SOLUTION: Replace 'pass' with: return matrix.T")        raise NotImplementedError("Please implement compute_transpose() first!")    expected = np.array([[1, 4], [2, 5], [3, 6]])    print(f"   Original shape: {matrix.shape}")    print(f"   Transposed shape: {result.shape}")    assert np.allclose(result, expected), "Transpose incorrect"    print("   ✅ Passed!")        print("\n" + "=" * 60)    print("🎉 All tests passed! Great job!")

# %% [markdown]
# ---
#
# ## ✅ Check Solution
#
# Compare with: `exercises/solutions/solution_01.ipynb`
#
# **💡 Try solving it yourself first!**

# %% [markdown]
# ---
#
# ## Teaching Notes
#
# **Common Mistakes:**
# - Students may struggle with [concept]
# - Watch for [common error]
#
# **Key Concepts:**
# - [Key concept 1]
# - [Key concept 2]
