# %% [markdown]
# # Exercise 02
#
# **Module 01**
#
# ---

# %% [markdown]
# Exercise 02: Matrix Properties and Operations
#
# This exercise focuses on understanding matrix properties that are important
# for machine learning, such as determinants, inverses, and eigenvalues.
#
# Instructions:
# 1. Complete the functions below
# 2. Understand what each property means for ML
# 3. Test your solutions

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `pass` statements
# 2. ✅ Replace `pass` with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# YOUR TASK: implement the four matrix-property functions by replacing each `pass`.
# The test cell below checks them on small matrices with hand-checkable answers.

import numpy as np


def compute_determinant(matrix):
    """Return the determinant of a square matrix.

    Hint: use np.linalg.det()
    """
    # TODO: Compute and return the determinant
    pass


def compute_inverse(matrix):
    """Return the inverse of a square matrix (assume it is invertible).

    Hint: use np.linalg.inv()
    """
    # TODO: Compute and return the inverse matrix
    pass


def compute_eigenvalues(matrix):
    """Return the eigenvalues of a square matrix as a 1-D array.

    Hint: np.linalg.eig() returns a pair (eigenvalues, eigenvectors)
    """
    # TODO: Return only the eigenvalues
    pass


def is_invertible(matrix, tol=1e-10):
    """Return True if the matrix is invertible, False otherwise.

    Hint: a matrix is invertible when abs(determinant) > tol
    """
    # TODO: Use the determinant to decide; return True or False
    pass

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %%
# Test harness: checks determinant, inverse, eigenvalues, and invertibility on small matrices
# with hand-checkable answers. Run it after each change to see which functions pass.

if __name__ == "__main__":
    print("Testing Exercise 02: Matrix Properties")
    print("=" * 60)

    # Helper: sorts/flattens arrays so eigenvalue order doesn't matter, then compares.
    def check(name, got, expected):
        if got is None:
            print(f"⚠️ {name}: returned None — did you replace `pass` with an implementation?")
        elif np.allclose(np.sort(np.atleast_1d(got).ravel()), np.sort(np.atleast_1d(expected).ravel())):
            print(f"✅ {name}: correct")
        else:
            print(f"❌ {name}: got {got!r}, expected {expected!r}")

    # Fixed inputs: det(A) = 5 with a known inverse; the second matrix is singular by construction.
    A = np.array([[2.0, 1.0], [1.0, 3.0]])
    singular = np.array([[1.0, 2.0], [2.0, 4.0]])  # det = 0

    check("compute_determinant([[2,1],[1,3]])", compute_determinant(A), 5.0)
    check("compute_inverse([[2,1],[1,3]])", compute_inverse(A),
          np.array([[0.6, -0.2], [-0.2, 0.4]]))
    check("compute_eigenvalues(diag(2,3))",
          compute_eigenvalues(np.diag([2.0, 3.0])), np.array([2.0, 3.0]))

    # is_invertible must separate the regular matrix (True) from the singular one (False).
    inv_result = is_invertible(A)
    sing_result = is_invertible(singular)
    if inv_result is None or sing_result is None:
        print("⚠️ is_invertible: returned None — did you replace `pass` with an implementation?")
    elif bool(inv_result) and not bool(sing_result):
        print("✅ is_invertible: correct on both an invertible and a singular matrix")
    else:
        print(f"❌ is_invertible: expected (True, False), got ({inv_result}, {sing_result})")
# Out:
# Testing Exercise 02: Matrix Properties
# ...
# ⚠️ compute_determinant([[2,1],[1,3]]): returned None — did you replace `pass` with an implementation?
# ⚠️ compute_inverse([[2,1],[1,3]]): returned None — did you replace `pass` with an implementation?
# ⚠️ compute_eigenvalues(diag(2,3)): returned None — did you replace `pass` with an implementation?
# ⚠️ is_invertible: returned None — did you replace `pass` with an implementation?

# %% [markdown]
# ---
#
# ## ✅ Check Your Work
#
# The test cell above checks each function and prints ✅ when it is correct.
#
# **💡 If a check prints a hint instead, revisit the TODO comments in the implementation cell and try again.**
