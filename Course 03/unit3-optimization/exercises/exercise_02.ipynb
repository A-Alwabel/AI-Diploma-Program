# %% [markdown]
# # Exercise 02
#
# **Module 03**
#
# ---

# %% [markdown]
# Exercise 02: Statistical Measures and Model Evaluation
#
# This exercise helps you understand statistical measures used to
# evaluate machine learning models.
#
# Instructions:
# 1. Implement statistical evaluation functions
# 2. Understand different metrics
# 3. Apply to model evaluation

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `pass` statements
# 2. ✅ Replace `pass` with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# YOUR TASK: implement the four regression metrics from their formulas by replacing each `pass`.
# The test cell below compares your numbers with the standard values.

import numpy as np


def compute_mse(y_true, y_pred):
    """Mean Squared Error: the mean of (y_true - y_pred)²"""
    # TODO: Compute and return the MSE
    pass


def compute_mae(y_true, y_pred):
    """Mean Absolute Error: the mean of |y_true - y_pred|"""
    # TODO: Compute and return the MAE
    pass


def compute_rmse(y_true, y_pred):
    """Root Mean Squared Error: the square root of the MSE"""
    # TODO: Compute and return the RMSE (hint: reuse compute_mse)
    pass


def compute_r2(y_true, y_pred):
    """R² score: 1 - SS_res / SS_tot

    SS_res = sum of (y_true - y_pred)²
    SS_tot = sum of (y_true - mean(y_true))²
    """
    # TODO: Compute and return R²
    pass

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %%
# Test harness: evaluates your metrics on a tiny fixed dataset with known answers
# (MSE 0.375, MAE 0.5, RMSE 0.6124, R² 0.9486), plus a perfect-prediction sanity check.

if __name__ == "__main__":
    print("Testing Exercise 02: Statistical Measures")
    print("=" * 60)

    # Helper: compare one metric against its expected value within tolerance.
    def check(name, got, expected, tol=1e-4):
        if got is None:
            print(f"⚠️ {name}: returned None — did you replace `pass` with an implementation?")
        elif np.isclose(got, expected, atol=tol):
            print(f"✅ {name}: correct ({got:.4f})")
        else:
            print(f"❌ {name}: got {got}, expected {expected}")

    # Small fixed vectors keep every expected value hand-checkable.
    y_true = np.array([3.0, -0.5, 2.0, 7.0])
    y_pred = np.array([2.5, 0.0, 2.0, 8.0])

    check("compute_mse", compute_mse(y_true, y_pred), 0.375)
    check("compute_mae", compute_mae(y_true, y_pred), 0.5)
    check("compute_rmse", compute_rmse(y_true, y_pred), 0.6124)
    check("compute_r2", compute_r2(y_true, y_pred), 0.9486)

    # Sanity check: perfect predictions
    perfect = compute_r2(y_true, y_true)
    if perfect is not None:
        check("compute_r2 on perfect predictions", perfect, 1.0)
# Out:
# Testing Exercise 02: Statistical Measures
# ...
# ⚠️ compute_mse: returned None — did you replace `pass` with an implementation?
# ⚠️ compute_mae: returned None — did you replace `pass` with an implementation?
# ⚠️ compute_rmse: returned None — did you replace `pass` with an implementation?
# ⚠️ compute_r2: returned None — did you replace `pass` with an implementation?

# %% [markdown]
# ---
#
# ## ✅ Check Your Work
#
# The test cell above checks each function and prints ✅ when it is correct.
#
# **💡 If a check prints a hint instead, revisit the TODO comments in the implementation cell and try again.**
