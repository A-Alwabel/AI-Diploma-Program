# %% [markdown]
# # Exercise 01
#
# **Module 02**
#
# ---

# %% [markdown]
# Exercise 01: Derivatives and Gradients
#
# This exercise helps you understand how derivatives and gradients work,
# which are fundamental for training machine learning models.
#
# Instructions:
# 1. Complete the functions below
# 2. Understand how derivatives relate to optimization
# 3. Test your solutions

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `pass` statements
# 2. ✅ Replace `pass` with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
# YOUR TASK: implement numerical differentiation — a single-variable derivative and a full gradient.
# Replace each `pass`; the test cell below checks your results against exact calculus answers.

import numpy as np
from scipy.optimize import approx_fprime
# Note: scipy.misc.derivative was removed from SciPy — we use finite differences instead


def compute_derivative(func, x, h=1e-6):
    """Return the numerical derivative of func at the point x.

    Use the central difference formula:
        f'(x) ≈ (f(x + h) - f(x - h)) / (2h)
    """
    # TODO: Implement the central difference formula
    pass


def compute_gradient(func, point):
    """Return the gradient (a NumPy array) of a multivariable function at `point`.

    `func` takes a NumPy array and returns a scalar.
    Hint: use approx_fprime(point, func, epsilon=1e-8), or apply the central
    difference formula one coordinate at a time.
    """
    # TODO: Compute and return the gradient vector
    pass

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %%
# Test harness: compares your numerical derivatives with exact calculus results.
# Run it after each change — the ✅/❌ lines show exactly which function still needs work.

if __name__ == "__main__":
    print("Testing Exercise 01: Derivatives and Gradients")
    print("=" * 60)

    def check(name, got, expected, tol=1e-3):
        if got is None:
            print(f"⚠️ {name}: returned None — did you replace `pass` with an implementation?")
        elif np.allclose(got, expected, atol=tol):
            print(f"✅ {name}: correct (got {np.round(got, 4)})")
        else:
            print(f"❌ {name}: got {got}, expected ≈ {expected}")

    # d/dx x² at x = 3 is 6
    check("compute_derivative of x² at x=3", compute_derivative(lambda x: x ** 2, 3.0), 6.0)
    # d/dx sin(x) at x = 0 is 1
    check("compute_derivative of sin(x) at x=0", compute_derivative(np.sin, 0.0), 1.0)
    # ∇(x² + y²) at (1, 2) is (2, 4)
    check("compute_gradient of x²+y² at (1,2)",
          compute_gradient(lambda p: p[0] ** 2 + p[1] ** 2, np.array([1.0, 2.0])),
          np.array([2.0, 4.0]))
# Out:
# Testing Exercise 01: Derivatives and Gradients
# ...
# ⚠️ compute_derivative of x² at x=3: returned None — did you replace `pass` with an implementation?
# ⚠️ compute_derivative of sin(x) at x=0: returned None — did you replace `pass` with an implementation?
# ⚠️ compute_gradient of x²+y² at (1,2): returned None — did you replace `pass` with an implementation?

# %% [markdown]
# ---
#
# ## ✅ Check Your Work
#
# The test cell above checks each function and prints ✅ when it is correct.
#
# **💡 If a check prints a hint instead, revisit the TODO comments in the implementation cell and try again.**
