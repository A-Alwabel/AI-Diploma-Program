# %% [markdown]
# # Exercise 02
#
# **Module 02**
#
# ---

# %% [markdown]
# Exercise 02: Gradient Descent Implementation
#
# This exercise helps you implement gradient descent, the fundamental
# optimization algorithm used in machine learning.
#
# Instructions:
# 1. Implement gradient descent from scratch
# 2. Understand how learning rate affects convergence
# 3. Visualize the optimization process

# %% [markdown]
# ---
#
# ## ⚠️ Important: Implement Functions First!
#
# **Before running tests**, complete all function implementations:
#
# 1. ✅ Find all functions with `# TODO` comments
# 2. ✅ Replace each TODO with your implementation
# 3. ✅ Make sure functions return values (not None)
#
# **The test code will give helpful hints if you forget!**

# %% [markdown]
# ---
#
# ## 📝 Your Implementation
#
# Complete the functions below. Replace `pass` with your code:

# %% [markdown]
# ## 📥 Inputs & 📤 Outputs
#
# **Inputs:** What we use in this notebook
#
# - Libraries and concepts as introduced in this notebook; see prerequisites and code comments.
#
# **Outputs:** What you'll see when you run the cells
#
# - Printed results, figures, and summaries as shown when you run the cells.
#
# ---

# %%
import numpy as np


def gradient_descent(func, gradient_func, initial_x, learning_rate=0.1, iterations=100):
    """Minimize func starting from initial_x; return (final_x, history)."""
    x = initial_x
    history = [x]

    # TODO: Implement the gradient descent loop.
    # For each iteration:
    #   1. Compute the gradient at the current point: gradient_func(x)
    #   2. Update: x = x - learning_rate * gradient
    #   3. Append x to history

    return x, history


def analyze_learning_rate(func, gradient_func, initial_x, learning_rates, iterations=50):
    """Run gradient_descent once per learning rate; return {learning_rate: final_x}."""
    results = {}

    # TODO: For each learning rate in learning_rates, run gradient_descent
    #       and store the final x in results[learning_rate]

    return results


# Test your solution

# %% [markdown]
# ---
#
# ## 🧪 Test Your Solution
#
# **Run this after implementing all functions above:**

# %%
if __name__ == "__main__":
    print("Testing Exercise 02: Gradient Descent")
    print("=" * 60)

    func = lambda x: x ** 2
    grad = lambda x: 2 * x

    x_final, history = gradient_descent(func, grad, initial_x=5.0, learning_rate=0.1, iterations=100)
    if len(history) <= 1:
        print("⚠️ gradient_descent: history holds only the starting point — did you implement the loop?")
    elif abs(x_final) < 1e-3:
        print(f"✅ gradient_descent: converged to {x_final:.6f} (expected ≈ 0 for f(x) = x²)")
    else:
        print(f"❌ gradient_descent: final x = {x_final} — expected ≈ 0 for f(x) = x²")

    results = analyze_learning_rate(func, grad, initial_x=5.0,
                                    learning_rates=[0.01, 0.1, 0.5], iterations=50)
    if results is None:
        print("⚠️ analyze_learning_rate: returned None — make sure it returns the results dictionary")
    elif len(results) == 0:
        print("⚠️ analyze_learning_rate: empty dictionary — did you implement the loop?")
    elif set(results) == {0.01, 0.1, 0.5}:
        print(f"✅ analyze_learning_rate: one entry per learning rate: {sorted(results)}")
    else:
        print(f"❌ analyze_learning_rate: expected keys [0.01, 0.1, 0.5], got {sorted(results)}")

    # Visualize the optimization path (once gradient_descent is implemented)
    if len(history) > 1:
        import matplotlib.pyplot as plt
        xs = np.array(history)
        plt.figure(figsize=(8, 4))
        plt.plot(range(len(xs)), func(xs), "b-o", markersize=3)
        plt.xlabel("Iteration")
        plt.ylabel("f(x) = x²")
        plt.title("Gradient Descent Convergence")
        plt.grid(True, alpha=0.3)
        plt.show()
# Out:
# Testing Exercise 02: Gradient Descent
# ...
# ⚠️ gradient_descent: history holds only the starting point — did you implement the loop?
# ⚠️ analyze_learning_rate: empty dictionary — did you implement the loop?

# %% [markdown]
# ---
#
# ## ✅ Check Your Work
#
# The test cell above checks each function and prints ✅ when it is correct.
#
# **💡 If a check prints a hint instead, revisit the TODO comments in the implementation cell and try again.**
